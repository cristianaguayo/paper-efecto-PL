# %% [markdown]
# # Aleatoriedad en asignación de dificultades

# %%
import numpy as np
import pandas as pd
import os
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy import stats

# %%
def LeerBasesRegresion(datadir, ligas, column_condition):
    dfs = []
    # Primer caso:
    archivo = ligas[0] + '.xlsx'
    df = pd.read_excel(os.path.join(datadir, archivo))
    columns_filter = [i for i in df.columns if column_condition(i)]
    columns_to_keep = ['equipo','Torneo'] + columns_filter
    df = df[columns_to_keep]
    dfs.append(df)
    try:
        for liga in ligas[1:]:
            archivo = liga + '.xlsx'
            df = pd.read_excel(os.path.join(datadir, archivo))
            columns_to_keep = ['equipo','Torneo'] + [i for i in df.columns if column_condition(i)]
            df = df[columns_to_keep]
            dfs.append(df)
    except:
        pass
    return dfs, columns_filter

# %%
def SignificanciaVariablesManual(coef, se, pval, replace_spaces = True):
    coef = "%.3f" % (np.round(coef, decimals = 3))
    se = "%.3f" % (np.round(se, decimals = 3))
    if coef > 0:
        output = '_' + str(coef) + ' (' + str(se) + ')'                    
    else:
        output = str(coef) + ' (' + str(se) + ')'
    pval = np.round(pval, 3)
    if pval < 0.01:
        output = output + '***'
    elif pval < 0.05 and pval >= 0.01:
        output = output + '**_'
    elif pval < 0.1 and pval >=0.05:
        output = output + '*__'
    else:
        output = output + '___'
    if replace_spaces:
        output = output.replace("_"," ")
    return output

# %%
def ANOVA1ViaIndicadores(datadir, ligas, column_condition):
    dict_replaces = {'_mean': '',
                     '_':' ',
                     'dificil':'Difícil',
                     'dificl' : 'Difícil',
                     'facil': 'Fácil',
                     'regular' : 'Regular',
                     'prom': 'Promedio',
                     'posicion': 'Posición',
                     'primer' : 'Primer',
                     'ronda' : 'Ronda',
                     'gral': 'Gral.',
                     'elo' : 'ELO',
                     'categoria': 'Categoría',
                     'local': 'Local',
                     'visita': 'Visita',
                     'general' : 'Gral.',
                     'corr' : 'Correg.',
                     'perc' : 'Frac.',
                     ' h' : ' Ant. ',
                     ' p': ' Primeros ',
                     ' c': ' Corte ',
                     'lv' : 'LV',
                     'Primer Fácil C': 'Primer Fácil LV C',
                     'Primer Difícil C': 'Primer Difícil LV C'}
    dfs, columns_filter = LeerBasesRegresion(datadir,
                                             ligas,
                                             column_condition)
    columns_facil = [i for i in columns_filter if 'facil' in i]
    columns_dificil = [i for i in columns_filter if 'dificil' in i]
    dictresumen_l = {'Indicador' : columns_facil}
    dfs_resumen = []
    # Columnas de facil
    for i in range(len(ligas)):
        liga = ligas[i]
        resultados = []
        for var in columns_facil:
            formula = var + ' ~ C(equipo)'
            model = ols(formula,
                        data = dfs[i]).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            resultados.append(np.round(aov_table['PR(>F)'][0], decimals = 3))
        dictresumen_l[liga] = resultados
    df_facil = pd.DataFrame(data = dictresumen_l)
    df_facil['Indicador'] = df_facil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_facil)
    dictresumen_v = {'Indicador' : columns_dificil}
    for i in range(len(ligas)):
        liga = ligas[i]
        resultados = []
        for var in columns_dificil:
            formula = var + ' ~ C(equipo)'
            model = ols(formula,
                        data = dfs[i]).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            resultados.append(np.round(aov_table['PR(>F)'][0], decimals = 3))
        dictresumen_v[liga] = resultados
    df_dificil = pd.DataFrame(data = dictresumen_v)
    df_dificil['Indicador'] = df_dificil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_dificil)
    return dfs_resumen

# %% [markdown]
# ## Aleatoriedad para indicadores según puntaje ELO

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia']
outputdir = os.path.join(os.path.pardir,'resultados','aleatoriedad-inicio')
dfs_resumen_elo = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       lambda x: 'perc' in x and 'elo' in x)

outputfile = 'aleatoriedad-elo.xlsx'
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_elo, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_elo[0]
# Out:
#                              Indicador  Alemania  Espana  Francia  Inglaterra  \
# 0   Frac. Fácil ELO Primeros 4 Corte 3     0.121   0.105    0.341       0.532
# 1   Frac. Fácil ELO Primeros 5 Corte 3     0.067   0.264    0.381       0.743
# 2   Frac. Fácil ELO Primeros 6 Corte 3     0.240   0.015    0.593       0.790
# 3   Frac. Fácil ELO Primeros 7 Corte 3     0.048   0.019    0.451       0.891
# 4   Frac. Fácil ELO Primeros 4 Corte 4     0.309   0.215    0.537       0.793
# 5   Frac. Fácil ELO Primeros 5 Corte 4     0.095   0.234    0.488       0.946
# 6   Frac. Fácil ELO Primeros 6 Corte 4     0.406   0.026    0.759       0.989
# 7   Frac. Fácil ELO Primeros 7 Corte 4     0.080   0.034    0.315       0.993
# 8   Frac. Fácil ELO Primeros 4 Corte 5     0.365   0.012    0.507       0.632
# 9   Frac. Fácil ELO Primeros 5 Corte 5     0.169   0.020    0.551       0.783
# 10  Frac. Fácil ELO Primeros 6 Corte 5     0.562   0.001    0.652       0.750
# 11  Frac. Fácil ELO Primeros 7 Corte 5     0.265   0.000    0.289       0.830
#
#     Italia
# 0    0.646
# 1    0.664
# 2    0.844
# 3    0.848
# 4    0.055
# 5    0.113
# 6    0.129
# 7    0.279
# 8    0.190
# 9    0.040
# 10   0.053
# 11   0.231

# %%
dfs_resumen_elo[1]
# Out:
#                                Indicador  Alemania  Espana  Francia  \
# 0   Frac. Difícil ELO Primeros 4 Corte 3     0.810   0.001    0.090
# 1   Frac. Difícil ELO Primeros 5 Corte 3     0.489   0.000    0.064
# 2   Frac. Difícil ELO Primeros 6 Corte 3     0.374   0.000    0.087
# 3   Frac. Difícil ELO Primeros 7 Corte 3     0.309   0.001    0.049
# 4   Frac. Difícil ELO Primeros 4 Corte 4     0.777   0.002    0.009
# 5   Frac. Difícil ELO Primeros 5 Corte 4     0.359   0.000    0.003
# 6   Frac. Difícil ELO Primeros 6 Corte 4     0.291   0.000    0.043
# 7   Frac. Difícil ELO Primeros 7 Corte 4     0.140   0.001    0.043
# 8   Frac. Difícil ELO Primeros 4 Corte 5     0.956   0.000    0.021
# 9   Frac. Difícil ELO Primeros 5 Corte 5     0.653   0.000    0.002
# 10  Frac. Difícil ELO Primeros 6 Corte 5     0.726   0.000    0.022
# 11  Frac. Difícil ELO Primeros 7 Corte 5     0.521   0.000    0.022
#
#     Inglaterra  Italia
# 0        0.788   0.009
# 1        0.264   0.000
# 2        0.076   0.006
# 3        0.088   0.010
# 4        0.680   0.206
# 5        0.170   0.003
# 6        0.067   0.145
# 7        0.040   0.305
# 8        0.203   0.248
# 9        0.138   0.037
# 10       0.106   0.068
# 11       0.125   0.110

# %% [markdown]
# ## Aleatoriedad para indicadores según definición general

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia']
dfs_resumen_general = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       lambda x: 'perc' in x and 'general' in x)

outputfile = 'aleatoriedad-general.xlsx'
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_general, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_general[0]
# Out:
#                                       Indicador  Alemania  Espana  Francia  \
# 0   Frac. Fácil Gral. Ant. 1 Primeros 4 Corte 3     0.603   0.557    0.403
# 1   Frac. Fácil Gral. Ant. 1 Primeros 5 Corte 3     0.248   0.333    0.619
# 2   Frac. Fácil Gral. Ant. 1 Primeros 6 Corte 3     0.563   0.188    0.871
# 3   Frac. Fácil Gral. Ant. 1 Primeros 7 Corte 3     0.474   0.086    0.693
# 4   Frac. Fácil Gral. Ant. 1 Primeros 4 Corte 4     0.300   0.411    0.674
# 5   Frac. Fácil Gral. Ant. 1 Primeros 5 Corte 4     0.182   0.213    0.695
# 6   Frac. Fácil Gral. Ant. 1 Primeros 6 Corte 4     0.704   0.052    0.869
# 7   Frac. Fácil Gral. Ant. 1 Primeros 7 Corte 4     0.414   0.047    0.866
# 8   Frac. Fácil Gral. Ant. 1 Primeros 4 Corte 5     0.730   0.041    0.679
# 9   Frac. Fácil Gral. Ant. 1 Primeros 5 Corte 5     0.689   0.045    0.851
# 10  Frac. Fácil Gral. Ant. 1 Primeros 6 Corte 5     0.936   0.025    0.952
# 11  Frac. Fácil Gral. Ant. 1 Primeros 7 Corte 5     0.549   0.005    0.984
# 12  Frac. Fácil Gral. Ant. 2 Primeros 4 Corte 3     0.333   0.351    0.458
# 13  Frac. Fácil Gral. Ant. 2 Primeros 5 Corte 3     0.055   0.296    0.865
# 14  Frac. Fácil Gral. Ant. 2 Primeros 6 Corte 3     0.429   0.055    0.907
# 15  Frac. Fácil Gral. Ant. 2 Primeros 7 Corte 3     0.601   0.339    0.401
# 16  Frac. Fácil Gral. Ant. 2 Primeros 4 Corte 4     0.034   0.365    0.646
# 17  Frac. Fácil Gral. Ant. 2 Primeros 5 Corte 4     0.024   0.351    0.948
# 18  Frac. Fácil Gral. Ant. 2 Primeros 6 Corte 4     0.109   0.161    0.604
# 19  Frac. Fácil Gral. Ant. 2 Primeros 7 Corte 4     0.187   0.203    0.429
# 20  Frac. Fácil Gral. Ant. 2 Primeros 4 Corte 5     0.090   0.298    0.594
# 52  Frac. Fácil Gral. Ant. 5 Primeros 4 Corte 4     0.493   0.766    0.489
# 53  Frac. Fácil Gral. Ant. 5 Primeros 5 Corte 4     0.810   0.480    0.560
# 54  Frac. Fácil Gral. Ant. 5 Primeros 6 Corte 4     0.177   0.242    0.761
# 55  Frac. Fácil Gral. Ant. 5 Primeros 7 Corte 4     0.223   0.087    0.707
# 56  Frac. Fácil Gral. Ant. 5 Primeros 4 Corte 5     0.501   0.854    0.387
# 57  Frac. Fácil Gral. Ant. 5 Primeros 5 Corte 5     0.747   0.565    0.420
# 58  Frac. Fácil Gral. Ant. 5 Primeros 6 Corte 5     0.165   0.369    0.672
# 59  Frac. Fácil Gral. Ant. 5 Primeros 7 Corte 5     0.258   0.141    0.534
#
#     Inglaterra  Italia
# 0        0.713   0.481
# 1        0.885   0.306
# 2        0.987   0.412
# 3        0.985   0.710
# 4        0.807   0.300
# 5        0.873   0.081
# 6        0.981   0.171
# 7        0.969   0.715
# 8        0.402   0.149
# 9        0.692   0.021
# 10       0.797   0.024
# 11       0.807   0.189
# 12       0.310   0.236
# 13       0.422   0.577
# 14       0.478   0.669
# 15       0.955   0.559
# 16       0.322   0.411
# 17       0.774   0.380
# 18       0.667   0.590
# 19       0.853   0.553
# 20       0.175   0.693
# 21       0.626   0.646
# 22       0.516   0.614
# 23       0.826   0.642
# 24       0.606   0.641
# 25       0.726   0.572
# 26       0.573   0.813
# 27       0.860   0.844
# 28       0.337   0.648
# 29       0.444   0.584
# 30       0.279   0.693
# 31       0.743   0.794
# 32       0.625   0.801
# 33       0.796   0.621
# 34       0.781   0.758
# 35       0.930   0.672
# 36       0.036   0.193
# 37       0.023   0.533
# 38       0.042   0.772
# 39       0.078   0.672
# 40       0.060   0.205
# 41       0.095   0.318
# 42       0.152   0.848
# 43       0.211   0.776
# 44       0.105   0.234
# 45       0.308   0.201
# 46       0.432   0.733
# 47       0.675   0.672
# 48       0.444   0.212
# 49       0.270   0.226
# 50       0.390   0.523
# 51       0.498   0.307
# 52       0.555   0.521
# 53       0.221   0.207
# 54       0.384   0.637
# 55       0.453   0.418
# 56       0.449   0.358
# 57       0.234   0.474
# 58       0.425   0.894
# 59       0.647   0.645

# %%
dfs_resumen_general[1]
# Out:
#                                         Indicador  Alemania  Espana  Francia  \
# 0   Frac. Difícil Gral. Ant. 1 Primeros 4 Corte 3     0.861   0.005    0.135
# 1   Frac. Difícil Gral. Ant. 1 Primeros 5 Corte 3     0.933   0.000    0.183
# 2   Frac. Difícil Gral. Ant. 1 Primeros 6 Corte 3     0.733   0.000    0.406
# 3   Frac. Difícil Gral. Ant. 1 Primeros 7 Corte 3     0.672   0.006    0.237
# 4   Frac. Difícil Gral. Ant. 1 Primeros 4 Corte 4     0.762   0.003    0.027
# 5   Frac. Difícil Gral. Ant. 1 Primeros 5 Corte 4     0.646   0.002    0.027
# 6   Frac. Difícil Gral. Ant. 1 Primeros 6 Corte 4     0.798   0.001    0.084
# 38  Frac. Difícil Gral. Ant. 4 Primeros 6 Corte 3     0.127   0.325    0.692
# 39  Frac. Difícil Gral. Ant. 4 Primeros 7 Corte 3     0.047   0.653    0.369
# 40  Frac. Difícil Gral. Ant. 4 Primeros 4 Corte 4     0.539   0.296    0.655
# 41  Frac. Difícil Gral. Ant. 4 Primeros 5 Corte 4     0.510   0.239    0.493
# 42  Frac. Difícil Gral. Ant. 4 Primeros 6 Corte 4     0.288   0.246    0.830
# 43  Frac. Difícil Gral. Ant. 4 Primeros 7 Corte 4     0.421   0.338    0.363
# 44  Frac. Difícil Gral. Ant. 4 Primeros 4 Corte 5     0.918   0.307    0.728
# 45  Frac. Difícil Gral. Ant. 4 Primeros 5 Corte 5     0.892   0.124    0.659
# 46  Frac. Difícil Gral. Ant. 4 Primeros 6 Corte 5     0.648   0.094    0.854
# 47  Frac. Difícil Gral. Ant. 4 Primeros 7 Corte 5     0.571   0.297    0.219
# 48  Frac. Difícil Gral. Ant. 5 Primeros 4 Corte 3     0.211   0.098    0.533
# 49  Frac. Difícil Gral. Ant. 5 Primeros 5 Corte 3     0.345   0.030    0.666
# 50  Frac. Difícil Gral. Ant. 5 Primeros 6 Corte 3     0.211   0.633    0.442
# 51  Frac. Difícil Gral. Ant. 5 Primeros 7 Corte 3     0.067   0.485    0.511
# 52  Frac. Difícil Gral. Ant. 5 Primeros 4 Corte 4     0.229   0.019    0.215
# 53  Frac. Difícil Gral. Ant. 5 Primeros 5 Corte 4     0.401   0.029    0.310
# 54  Frac. Difícil Gral. Ant. 5 Primeros 6 Corte 4     0.163   0.354    0.243
# 55  Frac. Difícil Gral. Ant. 5 Primeros 7 Corte 4     0.073   0.118    0.305
# 56  Frac. Difícil Gral. Ant. 5 Primeros 4 Corte 5     0.386   0.490    0.471
# 57  Frac. Difícil Gral. Ant. 5 Primeros 5 Corte 5     0.371   0.240    0.646
# 58  Frac. Difícil Gral. Ant. 5 Primeros 6 Corte 5     0.039   0.371    0.307
# 59  Frac. Difícil Gral. Ant. 5 Primeros 7 Corte 5     0.027   0.160    0.199
#
#     Inglaterra  Italia
# 0        0.854   0.025
# 1        0.209   0.000
# 2        0.060   0.014
# 3        0.019   0.007
# 4        0.909   0.404
# 5        0.358   0.105
# 6        0.331   0.371
# 7        0.178   0.180
# 8        0.542   0.232
# 9        0.212   0.052
# 10       0.121   0.190
# 11       0.148   0.231
# 12       0.522   0.183
# 13       0.387   0.005
# 14       0.132   0.047
# 15       0.060   0.225
# 16       0.569   0.081
# 17       0.314   0.001
# 18       0.263   0.003
# 19       0.098   0.006
# 20       0.128   0.186
# 21       0.086   0.041
# 22       0.298   0.039
# 23       0.138   0.017
# 24       0.531   0.170
# 25       0.116   0.001
# 26       0.042   0.002
# 27       0.006   0.007
# 28       0.178   0.038
# 29       0.123   0.001
# 30       0.222   0.013
# 31       0.190   0.007
# 32       0.062   0.088
# 33       0.030   0.006
# 34       0.061   0.024
# 35       0.125   0.089
# 36       0.984   0.231
# 37       0.931   0.405
# 38       0.940   0.270
# 39       0.898   0.214
# 40       0.848   0.482
# 41       0.871   0.344
# 42       0.834   0.253
# 43       0.710   0.328
# 44       0.745   0.442
# 45       0.645   0.536
# 46       0.765   0.478
# 47       0.654   0.467
# 48       0.538   0.386
# 49       0.484   0.618
# 50       0.090   0.643
# 51       0.359   0.681
# 52       0.934   0.690
# 53       0.833   0.834
# 54       0.639   0.870
# 55       0.845   0.888
# 56       0.831   0.738
# 57       0.859   0.730
# 58       0.859   0.399
# 59       0.947   0.715

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia']
dfs_resumen_lv = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       lambda x: 'perc' in x and 'lv' in x)

outputfile = 'aleatoriedad-localvisita.xlsx'
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_lv, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_lv[0]
# Out:
#                                    Indicador  Alemania  Espana  Francia  \
# 0   Frac. Fácil LV Ant. 1 Primeros 4 Corte 3     0.014   0.319    0.111
# 1   Frac. Fácil LV Ant. 1 Primeros 5 Corte 3     0.061   0.129    0.217
# 2   Frac. Fácil LV Ant. 1 Primeros 6 Corte 3     0.254   0.093    0.444
# 3   Frac. Fácil LV Ant. 1 Primeros 7 Corte 3     0.341   0.087    0.261
# 4   Frac. Fácil LV Ant. 1 Primeros 4 Corte 4     0.370   0.134    0.389
# 5   Frac. Fácil LV Ant. 1 Primeros 5 Corte 4     0.521   0.048    0.183
# 6   Frac. Fácil LV Ant. 1 Primeros 6 Corte 4     0.653   0.038    0.488
# 7   Frac. Fácil LV Ant. 1 Primeros 7 Corte 4     0.549   0.035    0.633
# 8   Frac. Fácil LV Ant. 1 Primeros 4 Corte 5     0.726   0.141    0.430
# 9   Frac. Fácil LV Ant. 1 Primeros 5 Corte 5     0.806   0.092    0.149
# 10  Frac. Fácil LV Ant. 1 Primeros 6 Corte 5     0.840   0.153    0.410
# 11  Frac. Fácil LV Ant. 1 Primeros 7 Corte 5     0.846   0.182    0.564
# 12  Frac. Fácil LV Ant. 2 Primeros 4 Corte 3     0.571   0.155    0.136
# 13  Frac. Fácil LV Ant. 2 Primeros 5 Corte 3     0.574   0.067    0.131
# 14  Frac. Fácil LV Ant. 2 Primeros 6 Corte 3     0.870   0.011    0.290
# 15  Frac. Fácil LV Ant. 2 Primeros 7 Corte 3     0.880   0.017    0.019
# 16  Frac. Fácil LV Ant. 2 Primeros 4 Corte 4     0.299   0.207    0.217
# 17  Frac. Fácil LV Ant. 2 Primeros 5 Corte 4     0.621   0.149    0.098
# 18  Frac. Fácil LV Ant. 2 Primeros 6 Corte 4     0.961   0.113    0.252
# 19  Frac. Fácil LV Ant. 2 Primeros 7 Corte 4     0.924   0.153    0.034
# 20  Frac. Fácil LV Ant. 2 Primeros 4 Corte 5     0.591   0.305    0.443
# 21  Frac. Fácil LV Ant. 2 Primeros 5 Corte 5     0.555   0.144    0.220
# 22  Frac. Fácil LV Ant. 2 Primeros 6 Corte 5     0.886   0.113    0.247
# 55  Frac. Fácil LV Ant. 5 Primeros 7 Corte 4     0.906   0.123    0.012
# 56  Frac. Fácil LV Ant. 5 Primeros 4 Corte 5     0.394   0.156    0.063
# 57  Frac. Fácil LV Ant. 5 Primeros 5 Corte 5     0.656   0.057    0.066
# 58  Frac. Fácil LV Ant. 5 Primeros 6 Corte 5     0.656   0.094    0.160
# 59  Frac. Fácil LV Ant. 5 Primeros 7 Corte 5     0.713   0.167    0.005
#
#     Inglaterra  Italia
# 0        0.140   0.811
# 1        0.362   0.705
# 2        0.287   0.598
# 3        0.346   0.630
# 4        0.075   0.782
# 5        0.121   0.612
# 6        0.237   0.545
# 7        0.324   0.648
# 8        0.160   0.447
# 9        0.360   0.242
# 10       0.556   0.189
# 11       0.575   0.303
# 12       0.302   0.182
# 13       0.906   0.364
# 14       0.805   0.543
# 15       0.955   0.417
# 16       0.449   0.229
# 17       0.905   0.227
# 18       0.647   0.642
# 19       0.886   0.561
# 20       0.246   0.624
# 21       0.615   0.266
# 22       0.560   0.485
# 23       0.868   0.447
# 24       0.180   0.777
# 25       0.773   0.590
# 26       0.592   0.807
# 27       0.729   0.629
# 28       0.486   0.735
# 29       0.782   0.517
# 30       0.542   0.781
# 31       0.849   0.646
# 32       0.366   0.411
# 33       0.671   0.215
# 34       0.682   0.407
# 35       0.908   0.526
# 36       0.066   0.556
# 37       0.240   0.168
# 38       0.260   0.288
# 39       0.428   0.482
# 40       0.061   0.379
# 41       0.238   0.153
# 42       0.089   0.132
# 43       0.285   0.196
# 44       0.081   0.320
# 45       0.229   0.187
# 46       0.104   0.396
# 47       0.581   0.525
# 48       0.207   0.309
# 49       0.497   0.330
# 50       0.506   0.561
# 51       0.640   0.641
# 52       0.249   0.482
# 53       0.428   0.278
# 54       0.584   0.669
# 55       0.706   0.777
# 56       0.117   0.569
# 57       0.382   0.316
# 58       0.435   0.416
# 59       0.562   0.705

# %%
dfs_resumen_lv[1]
# Out:
#                                      Indicador  Alemania  Espana  Francia  \
# 0   Frac. Difícil LV Ant. 1 Primeros 4 Corte 3     0.743   0.087    0.083
# 1   Frac. Difícil LV Ant. 1 Primeros 5 Corte 3     0.958   0.003    0.050
# 2   Frac. Difícil LV Ant. 1 Primeros 6 Corte 3     0.953   0.001    0.334
# 3   Frac. Difícil LV Ant. 1 Primeros 7 Corte 3     0.859   0.084    0.277
# 4   Frac. Difícil LV Ant. 1 Primeros 4 Corte 4     0.932   0.000    0.079
# 5   Frac. Difícil LV Ant. 1 Primeros 5 Corte 4     0.729   0.000    0.017
# 6   Frac. Difícil LV Ant. 1 Primeros 6 Corte 4     0.665   0.002    0.157
# 7   Frac. Difícil LV Ant. 1 Primeros 7 Corte 4     0.480   0.035    0.145
# 8   Frac. Difícil LV Ant. 1 Primeros 4 Corte 5     0.482   0.032    0.117
# 9   Frac. Difícil LV Ant. 1 Primeros 5 Corte 5     0.244   0.007    0.018
# 10  Frac. Difícil LV Ant. 1 Primeros 6 Corte 5     0.291   0.050    0.357
# 11  Frac. Difícil LV Ant. 1 Primeros 7 Corte 5     0.188   0.133    0.296
# 12  Frac. Difícil LV Ant. 2 Primeros 4 Corte 3     0.521   0.222    0.103
# 13  Frac. Difícil LV Ant. 2 Primeros 5 Corte 3     0.337   0.045    0.208
# 14  Frac. Difícil LV Ant. 2 Primeros 6 Corte 3     0.163   0.053    0.394
# 15  Frac. Difícil LV Ant. 2 Primeros 7 Corte 3     0.111   0.334    0.566
# 16  Frac. Difícil LV Ant. 2 Primeros 4 Corte 4     0.266   0.085    0.091
# 17  Frac. Difícil LV Ant. 2 Primeros 5 Corte 4     0.252   0.032    0.357
# 18  Frac. Difícil LV Ant. 2 Primeros 6 Corte 4     0.227   0.076    0.635
# 19  Frac. Difícil LV Ant. 2 Primeros 7 Corte 4     0.264   0.464    0.419
# 20  Frac. Difícil LV Ant. 2 Primeros 4 Corte 5     0.206   0.099    0.128
# 21  Frac. Difícil LV Ant. 2 Primeros 5 Corte 5     0.415   0.170    0.309
# 22  Frac. Difícil LV Ant. 2 Primeros 6 Corte 5     0.551   0.540    0.473
# 23  Frac. Difícil LV Ant. 2 Primeros 7 Corte 5     0.758   0.664    0.231
# 24  Frac. Difícil LV Ant. 3 Primeros 4 Corte 3     0.814   0.080    0.237
# 25  Frac. Difícil LV Ant. 3 Primeros 5 Corte 3     0.550   0.009    0.142
# 26  Frac. Difícil LV Ant. 3 Primeros 6 Corte 3     0.166   0.041    0.157
# 27  Frac. Difícil LV Ant. 3 Primeros 7 Corte 3     0.085   0.067    0.072
# 28  Frac. Difícil LV Ant. 3 Primeros 4 Corte 4     0.747   0.511    0.093
# 29  Frac. Difícil LV Ant. 3 Primeros 5 Corte 4     0.518   0.424    0.033
# 30  Frac. Difícil LV Ant. 3 Primeros 6 Corte 4     0.337   0.547    0.097
# 31  Frac. Difícil LV Ant. 3 Primeros 7 Corte 4     0.187   0.642    0.054
# 32  Frac. Difícil LV Ant. 3 Primeros 4 Corte 5     0.918   0.402    0.152
# 33  Frac. Difícil LV Ant. 3 Primeros 5 Corte 5     0.520   0.196    0.189
# 34  Frac. Difícil LV Ant. 3 Primeros 6 Corte 5     0.422   0.282    0.084
# 35  Frac. Difícil LV Ant. 3 Primeros 7 Corte 5     0.267   0.461    0.080
# 36  Frac. Difícil LV Ant. 4 Primeros 4 Corte 3     0.619   0.031    0.193
# 37  Frac. Difícil LV Ant. 4 Primeros 5 Corte 3     0.486   0.009    0.046
# 38  Frac. Difícil LV Ant. 4 Primeros 6 Corte 3     0.213   0.022    0.283
# 39  Frac. Difícil LV Ant. 4 Primeros 7 Corte 3     0.116   0.047    0.038
# 40  Frac. Difícil LV Ant. 4 Primeros 4 Corte 4     0.677   0.158    0.427
# 41  Frac. Difícil LV Ant. 4 Primeros 5 Corte 4     0.541   0.163    0.155
# 42  Frac. Difícil LV Ant. 4 Primeros 6 Corte 4     0.111   0.149    0.066
# 43  Frac. Difícil LV Ant. 4 Primeros 7 Corte 4     0.087   0.181    0.013
# 44  Frac. Difícil LV Ant. 4 Primeros 4 Corte 5     0.349   0.066    0.177
# 45  Frac. Difícil LV Ant. 4 Primeros 5 Corte 5     0.053   0.042    0.114
# 46  Frac. Difícil LV Ant. 4 Primeros 6 Corte 5     0.019   0.101    0.043
# 47  Frac. Difícil LV Ant. 4 Primeros 7 Corte 5     0.016   0.162    0.078
# 48  Frac. Difícil LV Ant. 5 Primeros 4 Corte 3     0.822   0.093    0.241
# 49  Frac. Difícil LV Ant. 5 Primeros 5 Corte 3     0.766   0.010    0.017
# 50  Frac. Difícil LV Ant. 5 Primeros 6 Corte 3     0.625   0.092    0.113
# 51  Frac. Difícil LV Ant. 5 Primeros 7 Corte 3     0.166   0.079    0.014
# 52  Frac. Difícil LV Ant. 5 Primeros 4 Corte 4     0.830   0.106    0.337
# 53  Frac. Difícil LV Ant. 5 Primeros 5 Corte 4     0.524   0.036    0.014
# 54  Frac. Difícil LV Ant. 5 Primeros 6 Corte 4     0.202   0.087    0.182
# 55  Frac. Difícil LV Ant. 5 Primeros 7 Corte 4     0.118   0.070    0.100
# 56  Frac. Difícil LV Ant. 5 Primeros 4 Corte 5     0.627   0.061    0.069
# 57  Frac. Difícil LV Ant. 5 Primeros 5 Corte 5     0.425   0.009    0.011
# 58  Frac. Difícil LV Ant. 5 Primeros 6 Corte 5     0.074   0.008    0.079
# 59  Frac. Difícil LV Ant. 5 Primeros 7 Corte 5     0.072   0.011    0.084
#
#     Inglaterra  Italia
# 0        0.468   0.030
# 1        0.250   0.000
# 2        0.111   0.008
# 3        0.056   0.000
# 4        0.163   0.127
# 5        0.010   0.005
# 6        0.032   0.127
# 7        0.044   0.018
# 8        0.099   0.029
# 9        0.006   0.001
# 10       0.009   0.013
# 11       0.020   0.020
# 12       0.408   0.041
# 13       0.117   0.000
# 14       0.081   0.005
# 15       0.035   0.005
# 16       0.161   0.062
# 17       0.000   0.000
# 18       0.003   0.018
# 19       0.010   0.092
# 20       0.056   0.017
# 21       0.000   0.000
# 22       0.021   0.000
# 23       0.009   0.001
# 24       0.561   0.026
# 25       0.057   0.000
# 26       0.103   0.002
# 27       0.050   0.004
# 28       0.234   0.105
# 29       0.006   0.000
# 30       0.049   0.004
# 31       0.053   0.020
# 32       0.019   0.024
# 33       0.001   0.000
# 34       0.017   0.000
# 35       0.025   0.000
# 36       0.306   0.007
# 37       0.018   0.000
# 38       0.016   0.015
# 39       0.005   0.016
# 40       0.252   0.021
# 41       0.021   0.000
# 42       0.034   0.017
# 43       0.048   0.036
# 44       0.096   0.038
# 45       0.006   0.000
# 46       0.066   0.000
# 47       0.178   0.001
# 48       0.601   0.004
# 49       0.226   0.000
# 50       0.292   0.018
# 51       0.364   0.072
# 52       0.337   0.004
# 53       0.012   0.000
# 54       0.015   0.003
# 55       0.007   0.023
# 56       0.032   0.019
# 57       0.002   0.000
# 58       0.003   0.000
# 59       0.010   0.001
