# %% [markdown]
# # Aleatoriedad en asignación de dificultades

# %%
import numpy as np
import pandas as pd
import os
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy import stats

# %%
def LeerBasesRegresion(datadir, ligas, column_condition):
    dfs = []
    # Primer caso:
    archivo = ligas[0] + '.xlsx'
    df = pd.read_excel(os.path.join(datadir, archivo))
    columns_filter = [i for i in df.columns if column_condition(i)]
    columns_to_keep = ['equipo','Torneo'] + columns_filter
    df = df[columns_to_keep]
    dfs.append(df)
    try:
        for liga in ligas[1:]:
            archivo = liga + '.xlsx'
            df = pd.read_excel(os.path.join(datadir, archivo))
            columns_to_keep = ['equipo','Torneo'] + [i for i in df.columns if column_condition(i)]
            df = df[columns_to_keep]
            dfs.append(df)
    except:
        pass
    return dfs, columns_filter

# %%
# def FiltrarRegulares(df, defin, c, h):
#     if defin == 'elo':
#         col = 'categoria_%s_c%s' % (defin, c)
#         df_filter = df[df[col] == 'regular']
#     elif defin == 'general':
#         col = 'categoria_%s_h%s_c%s' % (defin, h, c)
#         df_filter = df[df[col] == 'regular']
#     else:
#         col1 = 'categoria_local_h%s_c%s' % (h,c)
#         col2 = 'categoria_visita_h%s_c%s' % (h,c)
#         df_filter = df[(df[col1] == 'regular') & 
#                        (df[col2] == 'regular')]
#     return df_filter
def FiltrarRegulares(df, defin, c, h, filt):
    cats = ['facil','regular','dificil']
    if filt == '' or filt == "":
        pass
    elif filt == 'regular':
        cats = [filt]
    else:
        cats = [c for c in cats if c != filt]
    if defin == 'elo':
        col = 'categoria_%s_c%s' % (defin, c)
        df_filter = df[df[col].isin(cats)]
    elif defin == 'general':
        col = 'categoria_%s_h%s_c%s' % (defin, h, c)
        df_filter = df[df[col].isin(cats)]
    else:
        col1 = 'categoria_local_h%s_c%s' % (h,c)
        col2 = 'categoria_visita_h%s_c%s' % (h,c)
        df_filter = df[(df[col1].isin(cats)) & 
                       (df[col2].isin(cats))]
    return df_filter

# %%
def SignificanciaVariablesManual(coef, se, pval, replace_spaces = True):
    coef = "%.3f" % (np.round(coef, decimals = 3))
    se = "%.3f" % (np.round(se, decimals = 3))
    if coef > 0:
        output = '_' + str(coef) + ' (' + str(se) + ')'                    
    else:
        output = str(coef) + ' (' + str(se) + ')'
    pval = np.round(pval, 3)
    if pval < 0.01:
        output = output + '***'
    elif pval < 0.05 and pval >= 0.01:
        output = output + '**_'
    elif pval < 0.1 and pval >=0.05:
        output = output + '*__'
    else:
        output = output + '___'
    if replace_spaces:
        output = output.replace("_"," ")
    return output

# %%
def ANOVA1ViaIndicadores(datadir, ligas, defin, filtro):
    dict_replaces = {'_mean': '',
                     '_':' ',
                     'dificil':'Difícil',
                     'dificl' : 'Difícil',
                     'facil': 'Fácil',
                     'regular' : 'Regular',
                     'prom': 'Promedio',
                     'posicion': 'Posición',
                     'primer' : 'Primer',
                     'ronda' : 'Ronda',
                     'gral': 'Gral.',
                     'elo' : 'ELO',
                     'categoria': 'Categoría',
                     'local': 'Local',
                     'visita': 'Visita',
                     'general' : 'Gral.',
                     'corr' : 'Correg.',
                     'perc' : 'Frac.',
                     ' h' : ' Ant. ',
                     ' p': ' Primeros ',
                     ' c': ' Corte ',
                     'lv' : 'LV',
                     'Primer Fácil C': 'Primer Fácil LV C',
                     'Primer Difícil C': 'Primer Difícil LV C'}
    if defin != 'lv':
        dfs, columns_filter = LeerBasesRegresion(datadir,
                                                 ligas,
                                                 lambda x: defin in x)
    else:
        dfs, columns_filter = LeerBasesRegresion(datadir,
                                                 ligas,
                                                 lambda x: defin in x or 'local' in x or 'visita' in x)
    columns_facil = [i for i in columns_filter if 'facil' in i and 'perc' in i]
    columns_dificil = [i for i in columns_filter if 'dificil' in i and 'perc' in i]
    dictresumen_l = {'Indicador' : columns_facil}
    dfs_resumen = []
    # Columnas de facil
    for i in range(len(ligas)):
        liga = ligas[i]
        if liga != 'All':
            df_liga = dfs[i]
        else:
            df_liga = pd.concat(dfs, ignore_index = True)
        resultados = []
        for var in columns_facil:
            if filtro != 'regular':
                if 'facil' in var:
                    filt = 'facil'
                else:
                    filt = 'dificil'
            else:
                filt = filtro
            if defin != 'elo':
                aux = var.split('_h')[1].split('_p')
                h, c = aux[0], aux[1].split('_c')[1]
            else:
                h, c = None, var.split('_c')[1]
            formula = var + ' ~ C(equipo)'
            if len(filtro) > 0:
                df_anova = FiltrarRegulares(df_liga, defin, c, h, filt)
            else:
                df_anova = df_liga.copy()
            n_obs = df_anova.shape[0]
            model = ols(formula,
                        data =  df_anova).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            out = '%s (N = %s)' % (np.round(aov_table['PR(>F)'][0], decimals = 3), n_obs)
            resultados.append(out)
        dictresumen_l[liga] = resultados
    df_facil = pd.DataFrame(data = dictresumen_l)
    df_facil['Indicador'] = df_facil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_facil)
    dictresumen_v = {'Indicador' : columns_dificil}
    for i in range(len(ligas)):
        liga = ligas[i]
        liga = ligas[i]
        if liga != 'All':
            df_liga = dfs[i]
        else:
            df_liga = pd.concat(dfs, ignore_index = True)
        resultados = []
        for var in columns_dificil:
            if filtro != 'regular':
                if 'facil' in var:
                    filt = 'facil'
                else:
                    filt = 'dificil'
            else:
                filt = filtro
            if defin != 'elo':
                aux = var.split('_h')[1].split('_p')
                h, c = aux[0], aux[1].split('_c')[1]
            else:
                h, c = None, var.split('_c')[1]
            formula = var + ' ~ C(equipo)'
            df_anova = FiltrarRegulares(df_liga, defin, c, h, filt)
            n_obs = df_anova.shape[0]
            model = ols(formula,
                        data = df_anova).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            out = '%s (N = %s)' % (np.round(aov_table['PR(>F)'][0], decimals = 3), n_obs)
            resultados.append(out)
        dictresumen_v[liga] = resultados
    df_dificil = pd.DataFrame(data = dictresumen_v)
    df_dificil['Indicador'] = df_dificil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_dificil)
    return dfs_resumen

# %% [markdown]
# ## Aleatoriedad para indicadores según puntaje ELO

# %%
filtro = ''

# %%
# %%time
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
outputdir = os.path.join(os.path.pardir,'resultados','aleatoriedad-inicio')
dfs_resumen_elo = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       defin = 'elo',
                                       filtro = filtro)

outputfile = 'aleatoriedad-elo-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_elo, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()
# Out:
# CPU times: user 16.8 s, sys: 182 ms, total: 17 s
# Wall time: 7.28 s

# %%
dfs_resumen_elo[0]
# Out:
#                 Indicador         Alemania           Espana          Francia  \
# 0   Frac. Fácil ELO p3 c3  0.238 (N = 270)  0.265 (N = 300)  0.424 (N = 200)
# 1   Frac. Fácil ELO p4 c3  0.121 (N = 270)  0.105 (N = 300)  0.341 (N = 200)
# 2   Frac. Fácil ELO p5 c3  0.067 (N = 270)  0.264 (N = 300)  0.381 (N = 200)
# 3   Frac. Fácil ELO p6 c3   0.24 (N = 270)  0.015 (N = 300)  0.593 (N = 200)
# 4   Frac. Fácil ELO p3 c4  0.398 (N = 270)  0.495 (N = 300)  0.541 (N = 200)
# 5   Frac. Fácil ELO p4 c4  0.309 (N = 270)  0.215 (N = 300)  0.537 (N = 200)
# 6   Frac. Fácil ELO p5 c4  0.095 (N = 270)  0.234 (N = 300)  0.488 (N = 200)
# 7   Frac. Fácil ELO p6 c4  0.406 (N = 270)  0.026 (N = 300)  0.759 (N = 200)
# 8   Frac. Fácil ELO p3 c5  0.222 (N = 270)  0.164 (N = 300)  0.472 (N = 200)
# 9   Frac. Fácil ELO p4 c5  0.365 (N = 270)  0.012 (N = 300)  0.507 (N = 200)
# 10  Frac. Fácil ELO p5 c5  0.169 (N = 270)   0.02 (N = 300)  0.551 (N = 200)
# 11  Frac. Fácil ELO p6 c5  0.562 (N = 270)  0.001 (N = 300)  0.652 (N = 200)
# 12  Frac. Fácil ELO p3 c6  0.095 (N = 270)  0.351 (N = 300)  0.634 (N = 200)
# 13  Frac. Fácil ELO p4 c6  0.276 (N = 270)  0.017 (N = 300)   0.63 (N = 200)
# 14  Frac. Fácil ELO p5 c6  0.328 (N = 270)  0.121 (N = 300)  0.816 (N = 200)
# 15  Frac. Fácil ELO p6 c6  0.789 (N = 270)  0.008 (N = 300)  0.822 (N = 200)
#
#          Inglaterra           Italia               All
# 0    0.08 (N = 504)  0.628 (N = 298)  0.134 (N = 1572)
# 1   0.532 (N = 504)  0.646 (N = 298)  0.149 (N = 1572)
# 2   0.743 (N = 504)  0.664 (N = 298)  0.277 (N = 1572)
# 3    0.79 (N = 504)  0.844 (N = 298)   0.33 (N = 1572)
# 4   0.237 (N = 504)  0.087 (N = 298)  0.177 (N = 1572)
# 5   0.793 (N = 504)  0.055 (N = 298)  0.196 (N = 1572)
# 6   0.946 (N = 504)  0.113 (N = 298)  0.192 (N = 1572)
# 7   0.989 (N = 504)  0.129 (N = 298)  0.259 (N = 1572)
# 8   0.405 (N = 504)  0.229 (N = 298)  0.124 (N = 1572)
# 9   0.632 (N = 504)   0.19 (N = 298)  0.071 (N = 1572)
# 10  0.783 (N = 504)   0.04 (N = 298)  0.041 (N = 1572)
# 11   0.75 (N = 504)  0.053 (N = 298)  0.023 (N = 1572)
# 12  0.198 (N = 504)  0.118 (N = 298)  0.074 (N = 1572)
# 13   0.39 (N = 504)  0.223 (N = 298)   0.06 (N = 1572)
# 14  0.765 (N = 504)  0.076 (N = 298)  0.266 (N = 1572)
# 15  0.361 (N = 504)   0.03 (N = 298)  0.042 (N = 1572)

# %%
dfs_resumen_elo[1]
# Out:
#                   Indicador         Alemania           Espana  \
# 0   Frac. Difícil ELO p3 c3  0.848 (N = 225)  0.037 (N = 255)
# 1   Frac. Difícil ELO p4 c3  0.951 (N = 225)  0.082 (N = 255)
# 2   Frac. Difícil ELO p5 c3   0.58 (N = 225)  0.036 (N = 255)
# 3   Frac. Difícil ELO p6 c3  0.628 (N = 225)  0.041 (N = 255)
# 4   Frac. Difícil ELO p3 c4  0.067 (N = 210)  0.044 (N = 240)
# 5   Frac. Difícil ELO p4 c4  0.536 (N = 210)  0.043 (N = 240)
# 6   Frac. Difícil ELO p5 c4  0.122 (N = 210)  0.056 (N = 240)
# 7   Frac. Difícil ELO p6 c4  0.104 (N = 210)  0.013 (N = 240)
# 8   Frac. Difícil ELO p3 c5   0.09 (N = 195)  0.066 (N = 225)
# 9   Frac. Difícil ELO p4 c5   0.45 (N = 195)  0.032 (N = 225)
# 10  Frac. Difícil ELO p5 c5  0.218 (N = 195)  0.149 (N = 225)
# 11  Frac. Difícil ELO p6 c5  0.519 (N = 195)  0.061 (N = 225)
# 12  Frac. Difícil ELO p3 c6  0.195 (N = 180)  0.178 (N = 210)
# 13  Frac. Difícil ELO p4 c6   0.39 (N = 180)  0.069 (N = 210)
# 14  Frac. Difícil ELO p5 c6  0.364 (N = 180)  0.129 (N = 210)
# 15  Frac. Difícil ELO p6 c6   0.63 (N = 180)  0.021 (N = 210)
#
#             Francia       Inglaterra           Italia               All
# 0   0.592 (N = 170)  0.647 (N = 429)  0.742 (N = 253)  0.595 (N = 1332)
# 1   0.366 (N = 170)  0.953 (N = 429)  0.445 (N = 253)  0.792 (N = 1332)
# 2   0.439 (N = 170)  0.405 (N = 429)  0.068 (N = 253)  0.072 (N = 1332)
# 3   0.152 (N = 170)  0.136 (N = 429)  0.353 (N = 253)  0.044 (N = 1332)
# 4   0.235 (N = 160)  0.763 (N = 404)  0.938 (N = 238)  0.345 (N = 1252)
# 5     0.1 (N = 160)  0.948 (N = 404)  0.732 (N = 238)  0.603 (N = 1252)
# 6   0.137 (N = 160)   0.43 (N = 404)  0.153 (N = 238)  0.033 (N = 1252)
# 7   0.134 (N = 160)  0.202 (N = 404)  0.649 (N = 238)  0.027 (N = 1252)
# 8   0.611 (N = 150)  0.316 (N = 379)  0.877 (N = 223)  0.298 (N = 1172)
# 9   0.505 (N = 150)  0.717 (N = 379)  0.761 (N = 223)  0.537 (N = 1172)
# 10   0.42 (N = 150)  0.425 (N = 379)  0.394 (N = 223)  0.229 (N = 1172)
# 11  0.308 (N = 150)  0.323 (N = 379)  0.324 (N = 223)  0.145 (N = 1172)
# 12  0.792 (N = 140)  0.194 (N = 354)  0.749 (N = 208)  0.396 (N = 1092)
# 13  0.832 (N = 140)  0.536 (N = 354)  0.866 (N = 208)   0.67 (N = 1092)
# 14  0.764 (N = 140)  0.394 (N = 354)  0.683 (N = 208)   0.48 (N = 1092)
# 15  0.673 (N = 140)  0.328 (N = 354)  0.498 (N = 208)  0.229 (N = 1092)

# %% [markdown]
# ## Aleatoriedad para indicadores según definición general

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
dfs_resumen_general = ANOVA1ViaIndicadores(datadir,
                                           ligas,
                                           defin = 'general',
                                           filtro = filtro)
outputfile = 'aleatoriedad-general-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_general, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_general[0]
# Out:
#                      Indicador         Alemania           Espana  \
# 0   Frac. Fácil Gral. h1 p3 c3  0.785 (N = 270)  0.759 (N = 300)
# 1   Frac. Fácil Gral. h1 p4 c3  0.603 (N = 270)  0.562 (N = 300)
# 2   Frac. Fácil Gral. h1 p5 c3  0.248 (N = 270)  0.341 (N = 300)
# 3   Frac. Fácil Gral. h1 p6 c3  0.563 (N = 270)  0.198 (N = 300)
# 4   Frac. Fácil Gral. h1 p3 c4  0.657 (N = 270)  0.576 (N = 300)
# 5   Frac. Fácil Gral. h1 p4 c4    0.3 (N = 270)  0.417 (N = 300)
# 6   Frac. Fácil Gral. h1 p5 c4  0.182 (N = 270)   0.22 (N = 300)
# 7   Frac. Fácil Gral. h1 p6 c4  0.704 (N = 270)  0.054 (N = 300)
# 8   Frac. Fácil Gral. h1 p3 c5  0.577 (N = 270)  0.188 (N = 300)
# 9   Frac. Fácil Gral. h1 p4 c5   0.73 (N = 270)  0.042 (N = 300)
# 10  Frac. Fácil Gral. h1 p5 c5  0.689 (N = 270)  0.047 (N = 300)
# 11  Frac. Fácil Gral. h1 p6 c5  0.936 (N = 270)  0.026 (N = 300)
# 12  Frac. Fácil Gral. h2 p3 c3  0.562 (N = 270)  0.644 (N = 300)
# 13  Frac. Fácil Gral. h2 p4 c3  0.333 (N = 270)  0.358 (N = 300)
# 14  Frac. Fácil Gral. h2 p5 c3  0.055 (N = 270)  0.294 (N = 300)
# 15  Frac. Fácil Gral. h2 p6 c3  0.429 (N = 270)  0.054 (N = 300)
# 16  Frac. Fácil Gral. h2 p3 c4  0.072 (N = 270)  0.454 (N = 300)
# 17  Frac. Fácil Gral. h2 p4 c4  0.034 (N = 270)  0.369 (N = 300)
# 18  Frac. Fácil Gral. h2 p5 c4  0.024 (N = 270)  0.346 (N = 300)
# 19  Frac. Fácil Gral. h2 p6 c4  0.109 (N = 270)   0.16 (N = 300)
# 20  Frac. Fácil Gral. h2 p3 c5  0.144 (N = 270)  0.216 (N = 300)
# 21  Frac. Fácil Gral. h2 p4 c5   0.09 (N = 270)  0.297 (N = 300)
# 22  Frac. Fácil Gral. h2 p5 c5  0.046 (N = 270)  0.292 (N = 300)
# 23  Frac. Fácil Gral. h2 p6 c5  0.218 (N = 270)  0.109 (N = 300)
# 24  Frac. Fácil Gral. h3 p3 c3  0.373 (N = 270)  0.541 (N = 300)
# 25  Frac. Fácil Gral. h3 p4 c3  0.446 (N = 270)  0.309 (N = 300)
# 26  Frac. Fácil Gral. h3 p5 c3  0.343 (N = 270)   0.24 (N = 300)
# 27  Frac. Fácil Gral. h3 p6 c3  0.617 (N = 270)  0.079 (N = 300)
# 28  Frac. Fácil Gral. h3 p3 c4  0.611 (N = 270)  0.139 (N = 300)
# 29  Frac. Fácil Gral. h3 p4 c4  0.457 (N = 270)  0.131 (N = 300)
# 30  Frac. Fácil Gral. h3 p5 c4  0.425 (N = 270)  0.114 (N = 300)
# 31  Frac. Fácil Gral. h3 p6 c4  0.452 (N = 270)  0.112 (N = 300)
# 32  Frac. Fácil Gral. h3 p3 c5  0.299 (N = 270)  0.134 (N = 300)
# 33  Frac. Fácil Gral. h3 p4 c5  0.187 (N = 270)  0.151 (N = 300)
# 34  Frac. Fácil Gral. h3 p5 c5   0.08 (N = 270)  0.142 (N = 300)
# 35  Frac. Fácil Gral. h3 p6 c5  0.154 (N = 270)  0.214 (N = 300)
# 36  Frac. Fácil Gral. h4 p3 c3  0.896 (N = 270)  0.889 (N = 300)
# 37  Frac. Fácil Gral. h4 p4 c3  0.804 (N = 270)  0.865 (N = 300)
# 38  Frac. Fácil Gral. h4 p5 c3  0.709 (N = 270)  0.922 (N = 300)
# 39  Frac. Fácil Gral. h4 p6 c3  0.635 (N = 270)  0.719 (N = 300)
# 40  Frac. Fácil Gral. h4 p3 c4  0.741 (N = 270)  0.802 (N = 300)
# 41  Frac. Fácil Gral. h4 p4 c4    0.6 (N = 270)  0.812 (N = 300)
# 42  Frac. Fácil Gral. h4 p5 c4   0.62 (N = 270)  0.766 (N = 300)
# 43  Frac. Fácil Gral. h4 p6 c4  0.436 (N = 270)  0.436 (N = 300)
# 44  Frac. Fácil Gral. h4 p3 c5  0.493 (N = 270)  0.958 (N = 300)
# 45  Frac. Fácil Gral. h4 p4 c5  0.514 (N = 270)  0.906 (N = 300)
# 46  Frac. Fácil Gral. h4 p5 c5   0.72 (N = 270)  0.855 (N = 300)
# 47  Frac. Fácil Gral. h4 p6 c5  0.659 (N = 270)  0.485 (N = 300)
# 48  Frac. Fácil Gral. h5 p3 c3  0.309 (N = 270)  0.538 (N = 300)
# 49  Frac. Fácil Gral. h5 p4 c3  0.951 (N = 270)  0.871 (N = 300)
# 50  Frac. Fácil Gral. h5 p5 c3  0.932 (N = 270)  0.821 (N = 300)
# 51  Frac. Fácil Gral. h5 p6 c3  0.654 (N = 270)  0.862 (N = 300)
# 52  Frac. Fácil Gral. h5 p3 c4  0.063 (N = 270)  0.552 (N = 300)
# 53  Frac. Fácil Gral. h5 p4 c4  0.493 (N = 270)  0.742 (N = 300)
# 54  Frac. Fácil Gral. h5 p5 c4   0.81 (N = 270)  0.429 (N = 300)
# 55  Frac. Fácil Gral. h5 p6 c4  0.177 (N = 270)  0.217 (N = 300)
# 56  Frac. Fácil Gral. h5 p3 c5  0.184 (N = 270)  0.619 (N = 300)
# 57  Frac. Fácil Gral. h5 p4 c5  0.501 (N = 270)  0.848 (N = 300)
# 58  Frac. Fácil Gral. h5 p5 c5  0.747 (N = 270)  0.496 (N = 300)
# 59  Frac. Fácil Gral. h5 p6 c5  0.165 (N = 270)  0.313 (N = 300)
#
#             Francia       Inglaterra           Italia               All
# 0   0.131 (N = 200)  0.583 (N = 504)  0.549 (N = 298)  0.651 (N = 1572)
# 1   0.403 (N = 200)  0.695 (N = 504)  0.481 (N = 298)  0.686 (N = 1572)
# 2   0.619 (N = 200)  0.876 (N = 504)  0.306 (N = 298)   0.57 (N = 1572)
# 3   0.871 (N = 200)  0.986 (N = 504)  0.412 (N = 298)  0.874 (N = 1572)
# 4   0.219 (N = 200)  0.631 (N = 504)  0.398 (N = 298)  0.549 (N = 1572)
# 5   0.674 (N = 200)  0.801 (N = 504)    0.3 (N = 298)  0.609 (N = 1572)
# 6   0.695 (N = 200)  0.871 (N = 504)  0.081 (N = 298)  0.342 (N = 1572)
# 7   0.869 (N = 200)  0.981 (N = 504)  0.171 (N = 298)  0.675 (N = 1572)
# 8   0.292 (N = 200)   0.33 (N = 504)  0.342 (N = 298)  0.219 (N = 1572)
# 9   0.679 (N = 200)  0.421 (N = 504)  0.149 (N = 298)   0.21 (N = 1572)
# 10  0.851 (N = 200)   0.71 (N = 504)  0.021 (N = 298)  0.216 (N = 1572)
# 11  0.952 (N = 200)  0.801 (N = 504)  0.024 (N = 298)   0.36 (N = 1572)
# 12  0.273 (N = 200)  0.043 (N = 504)  0.383 (N = 298)  0.166 (N = 1572)
# 13  0.458 (N = 200)  0.268 (N = 504)  0.236 (N = 298)  0.169 (N = 1572)
# 14  0.865 (N = 200)  0.376 (N = 504)  0.577 (N = 298)  0.273 (N = 1572)
# 15  0.907 (N = 200)  0.449 (N = 504)  0.669 (N = 298)  0.399 (N = 1572)
# 16  0.283 (N = 200)  0.025 (N = 504)  0.573 (N = 298)  0.047 (N = 1572)
# 17  0.646 (N = 200)  0.324 (N = 504)  0.411 (N = 298)  0.146 (N = 1572)
# 18  0.948 (N = 200)   0.77 (N = 504)   0.38 (N = 298)   0.39 (N = 1572)
# 19  0.604 (N = 200)  0.669 (N = 504)   0.59 (N = 298)   0.24 (N = 1572)
# 20    0.3 (N = 200)  0.045 (N = 504)  0.921 (N = 298)  0.115 (N = 1572)
# 21  0.594 (N = 200)  0.186 (N = 504)  0.693 (N = 298)  0.193 (N = 1572)
# 22  0.827 (N = 200)  0.631 (N = 504)  0.646 (N = 298)  0.391 (N = 1572)
# 23  0.427 (N = 200)  0.526 (N = 504)  0.614 (N = 298)  0.231 (N = 1572)
# 24  0.561 (N = 200)  0.077 (N = 504)  0.754 (N = 298)  0.364 (N = 1572)
# 25   0.78 (N = 200)  0.584 (N = 504)  0.641 (N = 298)  0.638 (N = 1572)
# 26  0.956 (N = 200)  0.702 (N = 504)  0.572 (N = 298)  0.656 (N = 1572)
# 27  0.947 (N = 200)  0.545 (N = 504)  0.813 (N = 298)  0.656 (N = 1572)
# 28  0.348 (N = 200)  0.017 (N = 504)  0.614 (N = 298)    0.1 (N = 1572)
# 29  0.721 (N = 200)  0.338 (N = 504)  0.648 (N = 298)    0.4 (N = 1572)
# 30  0.837 (N = 200)  0.439 (N = 504)  0.584 (N = 298)  0.423 (N = 1572)
# 31  0.823 (N = 200)  0.269 (N = 504)  0.693 (N = 298)  0.355 (N = 1572)
# 32  0.287 (N = 200)  0.035 (N = 504)  0.708 (N = 298)  0.071 (N = 1572)
# 33  0.779 (N = 200)  0.626 (N = 504)  0.801 (N = 298)  0.513 (N = 1572)
# 34  0.847 (N = 200)  0.789 (N = 504)  0.621 (N = 298)  0.411 (N = 1572)
# 35  0.608 (N = 200)   0.78 (N = 504)  0.758 (N = 298)  0.451 (N = 1572)
# 36  0.085 (N = 200)  0.054 (N = 504)  0.439 (N = 298)  0.305 (N = 1572)
# 37  0.503 (N = 200)  0.034 (N = 504)  0.193 (N = 298)  0.303 (N = 1572)
# 38  0.112 (N = 200)  0.023 (N = 504)  0.533 (N = 298)   0.22 (N = 1572)
# 39  0.351 (N = 200)  0.041 (N = 504)  0.772 (N = 298)  0.347 (N = 1572)
# 40  0.179 (N = 200)  0.045 (N = 504)  0.366 (N = 298)  0.246 (N = 1572)
# 41  0.663 (N = 200)   0.05 (N = 504)  0.205 (N = 298)  0.312 (N = 1572)
# 42  0.521 (N = 200)  0.086 (N = 504)  0.318 (N = 298)  0.349 (N = 1572)
# 43  0.798 (N = 200)  0.123 (N = 504)  0.848 (N = 298)  0.502 (N = 1572)
# 44  0.483 (N = 200)  0.043 (N = 504)  0.636 (N = 298)  0.518 (N = 1572)
# 45  0.491 (N = 200)  0.103 (N = 504)  0.234 (N = 298)  0.379 (N = 1572)
# 46  0.344 (N = 200)  0.309 (N = 504)  0.201 (N = 298)  0.517 (N = 1572)
# 47  0.826 (N = 200)  0.417 (N = 504)  0.733 (N = 298)  0.788 (N = 1572)
# 48  0.068 (N = 200)  0.078 (N = 504)  0.335 (N = 298)  0.045 (N = 1572)
# 49  0.518 (N = 200)  0.477 (N = 504)  0.212 (N = 298)  0.782 (N = 1572)
# 50  0.417 (N = 200)  0.305 (N = 504)  0.226 (N = 298)  0.609 (N = 1572)
# 51  0.672 (N = 200)  0.418 (N = 504)  0.523 (N = 298)  0.766 (N = 1572)
# 52  0.033 (N = 200)  0.071 (N = 504)  0.216 (N = 298)  0.013 (N = 1572)
# 53  0.489 (N = 200)  0.595 (N = 504)  0.521 (N = 298)  0.764 (N = 1572)
# 54   0.56 (N = 200)  0.248 (N = 504)  0.207 (N = 298)  0.405 (N = 1572)
# 55  0.761 (N = 200)  0.408 (N = 504)  0.637 (N = 298)  0.409 (N = 1572)
# 56  0.103 (N = 200)  0.029 (N = 504)  0.199 (N = 298)  0.029 (N = 1572)
# 57  0.387 (N = 200)  0.483 (N = 504)  0.358 (N = 298)  0.626 (N = 1572)
# 58   0.42 (N = 200)  0.254 (N = 504)  0.474 (N = 298)  0.491 (N = 1572)
# 59  0.672 (N = 200)  0.441 (N = 504)  0.894 (N = 298)   0.54 (N = 1572)

# %%
dfs_resumen_general[1]
# Out:
#                        Indicador         Alemania           Espana  \
# 0   Frac. Difícil Gral. h1 p3 c3   0.77 (N = 225)  0.008 (N = 255)
# 1   Frac. Difícil Gral. h1 p4 c3  0.736 (N = 225)  0.068 (N = 255)
# 2   Frac. Difícil Gral. h1 p5 c3  0.488 (N = 225)  0.037 (N = 255)
# 3   Frac. Difícil Gral. h1 p6 c3  0.429 (N = 225)  0.037 (N = 255)
# 4   Frac. Difícil Gral. h1 p3 c4  0.288 (N = 210)  0.181 (N = 240)
# 5   Frac. Difícil Gral. h1 p4 c4  0.452 (N = 210)  0.157 (N = 240)
# 6   Frac. Difícil Gral. h1 p5 c4  0.172 (N = 210)  0.305 (N = 240)
# 7   Frac. Difícil Gral. h1 p6 c4  0.422 (N = 210)  0.176 (N = 240)
# 8   Frac. Difícil Gral. h1 p3 c5  0.473 (N = 195)  0.036 (N = 225)
# 9   Frac. Difícil Gral. h1 p4 c5  0.429 (N = 195)  0.008 (N = 225)
# 10  Frac. Difícil Gral. h1 p5 c5  0.248 (N = 195)  0.044 (N = 225)
# 11  Frac. Difícil Gral. h1 p6 c5  0.432 (N = 195)  0.062 (N = 225)
# 12  Frac. Difícil Gral. h2 p3 c3  0.344 (N = 225)  0.043 (N = 255)
# 13  Frac. Difícil Gral. h2 p4 c3  0.707 (N = 225)  0.108 (N = 255)
# 14  Frac. Difícil Gral. h2 p5 c3  0.052 (N = 225)  0.037 (N = 255)
# 15  Frac. Difícil Gral. h2 p6 c3  0.323 (N = 225)  0.121 (N = 255)
# 16  Frac. Difícil Gral. h2 p3 c4  0.552 (N = 210)  0.251 (N = 240)
# 17  Frac. Difícil Gral. h2 p4 c4  0.676 (N = 210)  0.176 (N = 240)
# 18  Frac. Difícil Gral. h2 p5 c4  0.432 (N = 210)  0.114 (N = 240)
# 19  Frac. Difícil Gral. h2 p6 c4  0.167 (N = 210)  0.146 (N = 240)
# 20  Frac. Difícil Gral. h2 p3 c5  0.067 (N = 195)  0.218 (N = 225)
# 21  Frac. Difícil Gral. h2 p4 c5   0.45 (N = 195)  0.215 (N = 225)
# 22  Frac. Difícil Gral. h2 p5 c5  0.264 (N = 195)  0.439 (N = 225)
# 23  Frac. Difícil Gral. h2 p6 c5  0.457 (N = 195)  0.383 (N = 225)
# 24  Frac. Difícil Gral. h3 p3 c3   0.59 (N = 225)  0.493 (N = 255)
# 25  Frac. Difícil Gral. h3 p4 c3  0.555 (N = 225)   0.13 (N = 255)
# 26  Frac. Difícil Gral. h3 p5 c3  0.122 (N = 225)  0.168 (N = 255)
# 27  Frac. Difícil Gral. h3 p6 c3  0.076 (N = 225)  0.345 (N = 255)
# 28  Frac. Difícil Gral. h3 p3 c4  0.014 (N = 210)  0.128 (N = 240)
# 29  Frac. Difícil Gral. h3 p4 c4  0.341 (N = 210)  0.016 (N = 240)
# 30  Frac. Difícil Gral. h3 p5 c4  0.049 (N = 210)  0.011 (N = 240)
# 31  Frac. Difícil Gral. h3 p6 c4  0.022 (N = 210)  0.045 (N = 240)
# 32  Frac. Difícil Gral. h3 p3 c5  0.288 (N = 195)  0.341 (N = 225)
# 33  Frac. Difícil Gral. h3 p4 c5  0.661 (N = 195)  0.105 (N = 225)
# 34  Frac. Difícil Gral. h3 p5 c5  0.218 (N = 195)  0.085 (N = 225)
# 35  Frac. Difícil Gral. h3 p6 c5  0.128 (N = 195)  0.267 (N = 225)
# 36  Frac. Difícil Gral. h4 p3 c3  0.453 (N = 225)  0.493 (N = 254)
# 37  Frac. Difícil Gral. h4 p4 c3  0.707 (N = 225)  0.706 (N = 254)
# 38  Frac. Difícil Gral. h4 p5 c3  0.445 (N = 225)  0.404 (N = 254)
# 39  Frac. Difícil Gral. h4 p6 c3  0.156 (N = 225)  0.612 (N = 254)
# 40  Frac. Difícil Gral. h4 p3 c4  0.339 (N = 210)  0.109 (N = 239)
# 41  Frac. Difícil Gral. h4 p4 c4  0.643 (N = 210)  0.355 (N = 239)
# 42  Frac. Difícil Gral. h4 p5 c4  0.651 (N = 210)  0.105 (N = 239)
# 43  Frac. Difícil Gral. h4 p6 c4    0.5 (N = 210)  0.173 (N = 239)
# 44  Frac. Difícil Gral. h4 p3 c5  0.498 (N = 195)  0.212 (N = 224)
# 45  Frac. Difícil Gral. h4 p4 c5  0.941 (N = 195)  0.445 (N = 224)
# 46  Frac. Difícil Gral. h4 p5 c5  0.929 (N = 195)  0.064 (N = 224)
# 47  Frac. Difícil Gral. h4 p6 c5  0.747 (N = 195)  0.048 (N = 224)
# 48  Frac. Difícil Gral. h5 p3 c3   0.28 (N = 225)  0.122 (N = 254)
# 49  Frac. Difícil Gral. h5 p4 c3  0.358 (N = 225)  0.145 (N = 254)
# 50  Frac. Difícil Gral. h5 p5 c3  0.562 (N = 225)  0.024 (N = 254)
# 51  Frac. Difícil Gral. h5 p6 c3  0.355 (N = 225)  0.482 (N = 254)
# 52  Frac. Difícil Gral. h5 p3 c4  0.294 (N = 210)  0.095 (N = 239)
# 53  Frac. Difícil Gral. h5 p4 c4  0.149 (N = 210)  0.082 (N = 239)
# 54  Frac. Difícil Gral. h5 p5 c4  0.138 (N = 210)  0.053 (N = 239)
# 55  Frac. Difícil Gral. h5 p6 c4   0.11 (N = 210)   0.25 (N = 239)
# 56  Frac. Difícil Gral. h5 p3 c5  0.573 (N = 195)  0.474 (N = 224)
# 57  Frac. Difícil Gral. h5 p4 c5  0.478 (N = 195)  0.529 (N = 224)
# 58  Frac. Difícil Gral. h5 p5 c5  0.311 (N = 195)  0.347 (N = 224)
# 59  Frac. Difícil Gral. h5 p6 c5   0.05 (N = 195)  0.369 (N = 224)
#
#             Francia       Inglaterra           Italia               All
# 0   0.458 (N = 170)  0.772 (N = 427)  0.743 (N = 253)  0.426 (N = 1330)
# 1   0.526 (N = 170)  0.981 (N = 427)  0.389 (N = 253)  0.711 (N = 1330)
# 2   0.726 (N = 170)  0.426 (N = 427)  0.048 (N = 253)  0.096 (N = 1330)
# 3   0.693 (N = 170)  0.193 (N = 427)  0.156 (N = 253)  0.072 (N = 1330)
# 4   0.429 (N = 160)  0.942 (N = 402)   0.95 (N = 238)  0.828 (N = 1250)
# 5   0.455 (N = 160)  0.995 (N = 402)   0.86 (N = 238)    0.9 (N = 1250)
# 6   0.535 (N = 160)  0.639 (N = 402)  0.567 (N = 238)  0.387 (N = 1250)
# 7   0.549 (N = 160)  0.517 (N = 402)  0.742 (N = 238)  0.467 (N = 1250)
# 8   0.641 (N = 150)  0.699 (N = 377)  0.825 (N = 223)  0.536 (N = 1170)
# 9   0.833 (N = 150)  0.846 (N = 377)  0.803 (N = 223)  0.627 (N = 1170)
# 10   0.66 (N = 150)  0.421 (N = 377)   0.44 (N = 223)  0.178 (N = 1170)
# 11  0.639 (N = 150)  0.285 (N = 377)  0.526 (N = 223)  0.226 (N = 1170)
# 12  0.684 (N = 170)  0.433 (N = 427)  0.727 (N = 253)  0.367 (N = 1330)
# 13  0.432 (N = 170)  0.912 (N = 427)  0.697 (N = 253)  0.778 (N = 1330)
# 14  0.381 (N = 170)  0.698 (N = 427)  0.231 (N = 253)  0.082 (N = 1330)
# 15  0.368 (N = 170)  0.296 (N = 427)  0.589 (N = 253)   0.17 (N = 1330)
# 16  0.757 (N = 160)   0.82 (N = 402)  0.889 (N = 238)  0.895 (N = 1250)
# 17  0.539 (N = 160)  0.861 (N = 402)  0.741 (N = 238)  0.808 (N = 1250)
# 18  0.559 (N = 160)  0.586 (N = 402)  0.144 (N = 238)  0.235 (N = 1250)
# 19  0.527 (N = 160)  0.501 (N = 402)  0.222 (N = 238)  0.169 (N = 1250)
# 20  0.447 (N = 150)  0.534 (N = 377)  0.726 (N = 223)  0.377 (N = 1170)
# 21  0.356 (N = 150)  0.412 (N = 377)  0.645 (N = 223)  0.434 (N = 1170)
# 22   0.39 (N = 150)  0.176 (N = 377)  0.572 (N = 223)  0.257 (N = 1170)
# 23  0.165 (N = 150)  0.327 (N = 377)  0.611 (N = 223)  0.274 (N = 1170)
# 24  0.816 (N = 170)  0.404 (N = 427)  0.294 (N = 253)  0.628 (N = 1330)
# 25  0.975 (N = 170)  0.867 (N = 427)  0.505 (N = 253)  0.817 (N = 1330)
# 26  0.989 (N = 170)   0.38 (N = 427)  0.043 (N = 253)  0.158 (N = 1330)
# 27  0.577 (N = 170)  0.182 (N = 427)  0.063 (N = 253)  0.051 (N = 1330)
# 28  0.257 (N = 160)  0.152 (N = 403)  0.434 (N = 238)  0.028 (N = 1251)
# 29  0.811 (N = 160)  0.498 (N = 403)  0.336 (N = 238)  0.137 (N = 1251)
# 30  0.618 (N = 160)  0.237 (N = 403)  0.046 (N = 238)  0.004 (N = 1251)
# 31   0.07 (N = 160)  0.256 (N = 403)  0.154 (N = 238)  0.003 (N = 1251)
# 32   0.47 (N = 150)  0.099 (N = 378)  0.483 (N = 223)  0.217 (N = 1171)
# 33  0.752 (N = 150)  0.269 (N = 378)  0.698 (N = 223)  0.428 (N = 1171)
# 34   0.45 (N = 150)  0.103 (N = 378)  0.464 (N = 223)  0.054 (N = 1171)
# 35  0.064 (N = 150)  0.127 (N = 378)  0.767 (N = 223)  0.065 (N = 1171)
# 36  0.985 (N = 170)  0.869 (N = 427)  0.416 (N = 253)   0.88 (N = 1329)
# 37  0.912 (N = 170)  0.968 (N = 427)  0.431 (N = 253)  0.969 (N = 1329)
# 38  0.773 (N = 170)  0.899 (N = 427)  0.788 (N = 253)  0.874 (N = 1329)
# 39  0.705 (N = 170)   0.93 (N = 427)  0.592 (N = 253)  0.753 (N = 1329)
# 40  0.967 (N = 160)  0.654 (N = 403)  0.599 (N = 238)  0.641 (N = 1250)
# 41  0.763 (N = 160)  0.673 (N = 403)  0.489 (N = 238)  0.743 (N = 1250)
# 42  0.737 (N = 160)   0.64 (N = 403)  0.566 (N = 238)  0.581 (N = 1250)
# 43  0.799 (N = 160)  0.477 (N = 403)  0.456 (N = 238)  0.397 (N = 1250)
# 44  0.851 (N = 150)   0.77 (N = 378)  0.793 (N = 223)  0.802 (N = 1170)
# 45   0.63 (N = 150)  0.614 (N = 378)  0.699 (N = 223)  0.881 (N = 1170)
# 46  0.671 (N = 150)  0.492 (N = 378)   0.69 (N = 223)  0.612 (N = 1170)
# 47  0.669 (N = 150)  0.587 (N = 378)  0.521 (N = 223)  0.441 (N = 1170)
# 48  0.194 (N = 170)  0.956 (N = 428)  0.436 (N = 253)  0.444 (N = 1330)
# 49  0.545 (N = 170)  0.841 (N = 428)  0.338 (N = 253)  0.464 (N = 1330)
# 50  0.645 (N = 170)  0.782 (N = 428)    0.5 (N = 253)  0.469 (N = 1330)
# 51  0.501 (N = 170)   0.17 (N = 428)  0.366 (N = 253)  0.214 (N = 1330)
# 52  0.252 (N = 160)  0.979 (N = 403)  0.461 (N = 238)  0.503 (N = 1250)
# 53  0.299 (N = 160)  0.992 (N = 403)  0.346 (N = 238)  0.421 (N = 1250)
# 54  0.414 (N = 160)  0.991 (N = 403)  0.473 (N = 238)  0.457 (N = 1250)
# 55  0.431 (N = 160)   0.92 (N = 403)  0.537 (N = 238)  0.428 (N = 1250)
# 56  0.548 (N = 150)  0.792 (N = 378)  0.891 (N = 223)  0.889 (N = 1170)
# 57  0.631 (N = 150)  0.952 (N = 378)  0.727 (N = 223)  0.896 (N = 1170)
# 58  0.713 (N = 150)  0.975 (N = 378)  0.617 (N = 223)  0.778 (N = 1170)
# 59  0.364 (N = 150)  0.974 (N = 378)  0.386 (N = 223)   0.22 (N = 1170)

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
dfs_resumen_lv = ANOVA1ViaIndicadores(datadir,
                                      ligas,
                                      defin = 'lv',
                                      filtro = filtro)

outputfile = 'aleatoriedad-localvisita-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_lv, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_lv[0]
# Out:
#                   Indicador         Alemania           Espana  \
# 0   Frac. Fácil LV h1 p3 c3   0.05 (N = 270)  0.833 (N = 300)
# 1   Frac. Fácil LV h1 p4 c3  0.014 (N = 270)  0.324 (N = 300)
# 2   Frac. Fácil LV h1 p5 c3  0.061 (N = 270)  0.131 (N = 300)
# 3   Frac. Fácil LV h1 p6 c3  0.254 (N = 270)  0.095 (N = 300)
# 4   Frac. Fácil LV h1 p3 c4  0.666 (N = 270)  0.532 (N = 300)
# 5   Frac. Fácil LV h1 p4 c4   0.37 (N = 270)  0.131 (N = 300)
# 6   Frac. Fácil LV h1 p5 c4  0.521 (N = 270)  0.044 (N = 300)
# 7   Frac. Fácil LV h1 p6 c4  0.653 (N = 270)  0.033 (N = 300)
# 8   Frac. Fácil LV h1 p3 c5  0.764 (N = 270)  0.682 (N = 300)
# 9   Frac. Fácil LV h1 p4 c5  0.726 (N = 270)  0.147 (N = 300)
# 10  Frac. Fácil LV h1 p5 c5  0.806 (N = 270)  0.096 (N = 300)
# 11  Frac. Fácil LV h1 p6 c5   0.84 (N = 270)  0.157 (N = 300)
# 12  Frac. Fácil LV h2 p3 c3  0.823 (N = 270)  0.152 (N = 300)
# 13  Frac. Fácil LV h2 p4 c3  0.571 (N = 270)   0.16 (N = 300)
# 14  Frac. Fácil LV h2 p5 c3  0.574 (N = 270)  0.067 (N = 300)
# 15  Frac. Fácil LV h2 p6 c3   0.87 (N = 270)  0.011 (N = 300)
# 16  Frac. Fácil LV h2 p3 c4  0.787 (N = 270)  0.369 (N = 300)
# 17  Frac. Fácil LV h2 p4 c4  0.299 (N = 270)  0.208 (N = 300)
# 18  Frac. Fácil LV h2 p5 c4  0.621 (N = 270)  0.137 (N = 300)
# 19  Frac. Fácil LV h2 p6 c4  0.961 (N = 270)  0.104 (N = 300)
# 20  Frac. Fácil LV h2 p3 c5  0.847 (N = 270)  0.477 (N = 300)
# 21  Frac. Fácil LV h2 p4 c5  0.591 (N = 270)  0.305 (N = 300)
# 22  Frac. Fácil LV h2 p5 c5  0.555 (N = 270)  0.127 (N = 300)
# 23  Frac. Fácil LV h2 p6 c5  0.886 (N = 270)  0.097 (N = 300)
# 24  Frac. Fácil LV h3 p3 c3  0.618 (N = 270)  0.419 (N = 300)
# 25  Frac. Fácil LV h3 p4 c3  0.394 (N = 270)  0.265 (N = 300)
# 26  Frac. Fácil LV h3 p5 c3  0.561 (N = 270)  0.098 (N = 300)
# 27  Frac. Fácil LV h3 p6 c3   0.93 (N = 270)  0.024 (N = 300)
# 28  Frac. Fácil LV h3 p3 c4  0.246 (N = 270)  0.658 (N = 300)
# 29  Frac. Fácil LV h3 p4 c4   0.22 (N = 270)  0.429 (N = 300)
# 30  Frac. Fácil LV h3 p5 c4  0.217 (N = 270)  0.201 (N = 300)
# 31  Frac. Fácil LV h3 p6 c4  0.612 (N = 270)  0.055 (N = 300)
# 32  Frac. Fácil LV h3 p3 c5  0.647 (N = 270)  0.819 (N = 300)
# 33  Frac. Fácil LV h3 p4 c5  0.658 (N = 270)  0.688 (N = 300)
# 34  Frac. Fácil LV h3 p5 c5   0.73 (N = 270)  0.655 (N = 300)
# 35  Frac. Fácil LV h3 p6 c5  0.935 (N = 270)  0.296 (N = 300)
# 36  Frac. Fácil LV h4 p3 c3  0.188 (N = 270)   0.38 (N = 300)
# 37  Frac. Fácil LV h4 p4 c3   0.16 (N = 270)  0.345 (N = 300)
# 38  Frac. Fácil LV h4 p5 c3  0.581 (N = 270)  0.245 (N = 300)
# 39  Frac. Fácil LV h4 p6 c3  0.874 (N = 270)  0.234 (N = 300)
# 40  Frac. Fácil LV h4 p3 c4  0.084 (N = 270)  0.261 (N = 300)
# 41  Frac. Fácil LV h4 p4 c4  0.092 (N = 270)  0.095 (N = 300)
# 42  Frac. Fácil LV h4 p5 c4  0.189 (N = 270)  0.037 (N = 300)
# 43  Frac. Fácil LV h4 p6 c4  0.389 (N = 270)  0.022 (N = 300)
# 44  Frac. Fácil LV h4 p3 c5  0.273 (N = 270)  0.234 (N = 300)
# 45  Frac. Fácil LV h4 p4 c5  0.376 (N = 270)  0.121 (N = 300)
# 46  Frac. Fácil LV h4 p5 c5  0.292 (N = 270)  0.073 (N = 300)
# 47  Frac. Fácil LV h4 p6 c5  0.482 (N = 270)  0.036 (N = 300)
# 48  Frac. Fácil LV h5 p3 c3  0.736 (N = 270)  0.741 (N = 300)
# 49  Frac. Fácil LV h5 p4 c3  0.706 (N = 270)  0.313 (N = 300)
# 50  Frac. Fácil LV h5 p5 c3  0.868 (N = 270)  0.065 (N = 300)
# 51  Frac. Fácil LV h5 p6 c3  0.909 (N = 270)  0.163 (N = 300)
# 52  Frac. Fácil LV h5 p3 c4  0.552 (N = 270)  0.219 (N = 300)
# 53  Frac. Fácil LV h5 p4 c4  0.518 (N = 270)   0.06 (N = 300)
# 54  Frac. Fácil LV h5 p5 c4  0.957 (N = 270)  0.009 (N = 300)
# 55  Frac. Fácil LV h5 p6 c4  0.922 (N = 270)  0.038 (N = 300)
# 56  Frac. Fácil LV h5 p3 c5  0.428 (N = 270)  0.349 (N = 300)
# 57  Frac. Fácil LV h5 p4 c5  0.394 (N = 270)  0.147 (N = 300)
# 58  Frac. Fácil LV h5 p5 c5  0.656 (N = 270)  0.049 (N = 300)
# 59  Frac. Fácil LV h5 p6 c5  0.656 (N = 270)   0.08 (N = 300)
#
#             Francia       Inglaterra           Italia               All
# 0   0.015 (N = 200)  0.164 (N = 504)  0.611 (N = 298)  0.106 (N = 1572)
# 1   0.111 (N = 200)  0.095 (N = 504)  0.811 (N = 298)  0.035 (N = 1572)
# 2   0.217 (N = 200)  0.303 (N = 504)  0.705 (N = 298)  0.087 (N = 1572)
# 3   0.444 (N = 200)  0.254 (N = 504)  0.598 (N = 298)  0.154 (N = 1572)
# 4   0.244 (N = 200)   0.14 (N = 504)  0.483 (N = 298)  0.337 (N = 1572)
# 5   0.389 (N = 200)  0.049 (N = 504)  0.782 (N = 298)  0.144 (N = 1572)
# 6   0.183 (N = 200)  0.094 (N = 504)  0.612 (N = 298)  0.081 (N = 1572)
# 7   0.488 (N = 200)  0.203 (N = 504)  0.545 (N = 298)  0.195 (N = 1572)
# 8   0.326 (N = 200)  0.147 (N = 504)  0.402 (N = 298)  0.456 (N = 1572)
# 9    0.43 (N = 200)  0.141 (N = 504)  0.447 (N = 298)  0.244 (N = 1572)
# 10  0.149 (N = 200)  0.346 (N = 504)  0.242 (N = 298)  0.211 (N = 1572)
# 11   0.41 (N = 200)  0.543 (N = 504)  0.189 (N = 298)  0.398 (N = 1572)
# 12  0.015 (N = 200)  0.148 (N = 504)  0.122 (N = 298)  0.017 (N = 1572)
# 13  0.136 (N = 200)    0.3 (N = 504)  0.182 (N = 298)  0.059 (N = 1572)
# 14  0.131 (N = 200)  0.909 (N = 504)  0.364 (N = 298)  0.181 (N = 1572)
# 15   0.29 (N = 200)  0.816 (N = 504)  0.543 (N = 298)   0.28 (N = 1572)
# 16  0.046 (N = 200)  0.139 (N = 504)  0.257 (N = 298)  0.088 (N = 1572)
# 17  0.217 (N = 200)  0.454 (N = 504)  0.229 (N = 298)  0.108 (N = 1572)
# 18  0.098 (N = 200)  0.909 (N = 504)  0.227 (N = 298)  0.239 (N = 1572)
# 19  0.252 (N = 200)  0.668 (N = 504)  0.642 (N = 298)  0.599 (N = 1572)
# 20  0.188 (N = 200)  0.381 (N = 504)  0.474 (N = 298)  0.483 (N = 1572)
# 21  0.443 (N = 200)  0.255 (N = 504)  0.624 (N = 298)  0.406 (N = 1572)
# 22   0.22 (N = 200)  0.603 (N = 504)  0.266 (N = 298)  0.194 (N = 1572)
# 23  0.247 (N = 200)  0.555 (N = 504)  0.485 (N = 298)   0.45 (N = 1572)
# 24  0.123 (N = 200)  0.109 (N = 504)  0.782 (N = 298)  0.242 (N = 1572)
# 25  0.378 (N = 200)  0.181 (N = 504)  0.777 (N = 298)   0.29 (N = 1572)
# 26  0.267 (N = 200)  0.776 (N = 504)   0.59 (N = 298)  0.356 (N = 1572)
# 27  0.279 (N = 200)  0.623 (N = 504)  0.807 (N = 298)  0.469 (N = 1572)
# 28  0.352 (N = 200)  0.159 (N = 504)   0.53 (N = 298)  0.264 (N = 1572)
# 29  0.463 (N = 200)  0.489 (N = 504)  0.735 (N = 298)  0.458 (N = 1572)
# 30  0.475 (N = 200)  0.763 (N = 504)  0.517 (N = 298)  0.338 (N = 1572)
# 31  0.474 (N = 200)  0.537 (N = 504)  0.781 (N = 298)  0.395 (N = 1572)
# 32  0.673 (N = 200)  0.077 (N = 504)   0.27 (N = 298)  0.449 (N = 1572)
# 33  0.777 (N = 200)  0.374 (N = 504)  0.411 (N = 298)  0.715 (N = 1572)
# 34  0.828 (N = 200)  0.659 (N = 504)  0.215 (N = 298)   0.77 (N = 1572)
# 35  0.746 (N = 200)  0.684 (N = 504)  0.407 (N = 298)  0.744 (N = 1572)
# 36  0.139 (N = 200)  0.054 (N = 504)  0.296 (N = 298)  0.026 (N = 1572)
# 37  0.123 (N = 200)  0.064 (N = 504)  0.556 (N = 298)  0.043 (N = 1572)
# 38  0.336 (N = 200)  0.214 (N = 504)  0.168 (N = 298)  0.101 (N = 1572)
# 39  0.598 (N = 200)   0.25 (N = 504)  0.288 (N = 298)  0.296 (N = 1572)
# 40  0.105 (N = 200)  0.024 (N = 504)  0.338 (N = 298)  0.009 (N = 1572)
# 41  0.116 (N = 200)  0.062 (N = 504)  0.379 (N = 298)  0.007 (N = 1572)
# 42  0.148 (N = 200)  0.213 (N = 504)  0.153 (N = 298)  0.011 (N = 1572)
# 43  0.227 (N = 200)  0.084 (N = 504)  0.132 (N = 298)  0.008 (N = 1572)
# 44  0.412 (N = 200)  0.019 (N = 504)  0.142 (N = 298)  0.022 (N = 1572)
# 45  0.639 (N = 200)  0.084 (N = 504)   0.32 (N = 298)  0.101 (N = 1572)
# 46  0.528 (N = 200)  0.215 (N = 504)  0.187 (N = 298)  0.079 (N = 1572)
# 47  0.472 (N = 200)  0.103 (N = 504)  0.396 (N = 298)  0.074 (N = 1572)
# 48  0.104 (N = 200)  0.029 (N = 504)  0.166 (N = 298)  0.092 (N = 1572)
# 49  0.112 (N = 200)    0.2 (N = 504)  0.309 (N = 298)  0.159 (N = 1572)
# 50  0.157 (N = 200)  0.497 (N = 504)   0.33 (N = 298)  0.193 (N = 1572)
# 51  0.267 (N = 200)  0.529 (N = 504)  0.561 (N = 298)  0.463 (N = 1572)
# 52  0.124 (N = 200)  0.192 (N = 504)  0.501 (N = 298)  0.189 (N = 1572)
# 53  0.161 (N = 200)  0.251 (N = 504)  0.482 (N = 298)  0.099 (N = 1572)
# 54  0.157 (N = 200)  0.411 (N = 504)  0.278 (N = 298)  0.131 (N = 1572)
# 55  0.272 (N = 200)  0.577 (N = 504)  0.669 (N = 298)  0.414 (N = 1572)
# 56  0.068 (N = 200)  0.034 (N = 504)  0.713 (N = 298)  0.084 (N = 1572)
# 57  0.063 (N = 200)   0.12 (N = 504)  0.569 (N = 298)  0.055 (N = 1572)
# 58  0.066 (N = 200)  0.366 (N = 504)  0.316 (N = 298)  0.089 (N = 1572)
# 59   0.16 (N = 200)  0.427 (N = 504)  0.416 (N = 298)  0.187 (N = 1572)

# %%
dfs_resumen_lv[1]
# Out:
#                     Indicador         Alemania           Espana  \
# 0   Frac. Difícil LV h1 p3 c3  0.521 (N = 204)  0.533 (N = 242)
# 1   Frac. Difícil LV h1 p4 c3  0.415 (N = 204)  0.683 (N = 242)
# 2   Frac. Difícil LV h1 p5 c3  0.871 (N = 204)   0.32 (N = 242)
# 3   Frac. Difícil LV h1 p6 c3  0.899 (N = 204)  0.158 (N = 242)
# 4   Frac. Difícil LV h1 p3 c4  0.859 (N = 187)  0.097 (N = 218)
# 5   Frac. Difícil LV h1 p4 c4  0.906 (N = 187)  0.034 (N = 218)
# 6   Frac. Difícil LV h1 p5 c4  0.525 (N = 187)   0.07 (N = 218)
# 7   Frac. Difícil LV h1 p6 c4  0.616 (N = 187)   0.13 (N = 218)
# 8   Frac. Difícil LV h1 p3 c5  0.792 (N = 170)  0.598 (N = 197)
# 9   Frac. Difícil LV h1 p4 c5  0.878 (N = 170)  0.446 (N = 197)
# 10  Frac. Difícil LV h1 p5 c5  0.817 (N = 170)  0.493 (N = 197)
# 11  Frac. Difícil LV h1 p6 c5  0.867 (N = 170)  0.401 (N = 197)
# 12  Frac. Difícil LV h2 p3 c3  0.797 (N = 208)   0.34 (N = 246)
# 13  Frac. Difícil LV h2 p4 c3  0.842 (N = 208)  0.656 (N = 246)
# 14  Frac. Difícil LV h2 p5 c3  0.573 (N = 208)  0.239 (N = 246)
# 15  Frac. Difícil LV h2 p6 c3  0.646 (N = 208)  0.372 (N = 246)
# 16  Frac. Difícil LV h2 p3 c4  0.673 (N = 187)  0.589 (N = 226)
# 17  Frac. Difícil LV h2 p4 c4  0.587 (N = 187)  0.563 (N = 226)
# 18  Frac. Difícil LV h2 p5 c4  0.645 (N = 187)  0.572 (N = 226)
# 19  Frac. Difícil LV h2 p6 c4  0.822 (N = 187)  0.397 (N = 226)
# 20  Frac. Difícil LV h2 p3 c5  0.858 (N = 171)   0.66 (N = 204)
# 21  Frac. Difícil LV h2 p4 c5  0.527 (N = 171)   0.59 (N = 204)
# 22  Frac. Difícil LV h2 p5 c5  0.819 (N = 171)  0.857 (N = 204)
# 23  Frac. Difícil LV h2 p6 c5  0.595 (N = 171)  0.839 (N = 204)
# 24  Frac. Difícil LV h3 p3 c3  0.673 (N = 206)  0.195 (N = 249)
# 25  Frac. Difícil LV h3 p4 c3  0.969 (N = 206)  0.198 (N = 249)
# 26  Frac. Difícil LV h3 p5 c3  0.825 (N = 206)  0.069 (N = 249)
# 27  Frac. Difícil LV h3 p6 c3  0.759 (N = 206)  0.294 (N = 249)
# 28  Frac. Difícil LV h3 p3 c4  0.889 (N = 191)  0.866 (N = 228)
# 29  Frac. Difícil LV h3 p4 c4  0.876 (N = 191)  0.938 (N = 228)
# 30  Frac. Difícil LV h3 p5 c4  0.741 (N = 191)   0.95 (N = 228)
# 31  Frac. Difícil LV h3 p6 c4  0.644 (N = 191)  0.891 (N = 228)
# 32  Frac. Difícil LV h3 p3 c5  0.566 (N = 175)  0.908 (N = 204)
# 33  Frac. Difícil LV h3 p4 c5  0.893 (N = 175)  0.929 (N = 204)
# 34  Frac. Difícil LV h3 p5 c5   0.46 (N = 175)  0.777 (N = 204)
# 35  Frac. Difícil LV h3 p6 c5  0.643 (N = 175)  0.765 (N = 204)
# 36  Frac. Difícil LV h4 p3 c3  0.468 (N = 212)  0.167 (N = 250)
# 37  Frac. Difícil LV h4 p4 c3  0.742 (N = 212)  0.171 (N = 250)
# 38  Frac. Difícil LV h4 p5 c3  0.606 (N = 212)  0.079 (N = 250)
# 39  Frac. Difícil LV h4 p6 c3  0.487 (N = 212)    0.2 (N = 250)
# 40  Frac. Difícil LV h4 p3 c4   0.37 (N = 194)  0.807 (N = 233)
# 41  Frac. Difícil LV h4 p4 c4  0.677 (N = 194)  0.626 (N = 233)
# 42  Frac. Difícil LV h4 p5 c4  0.481 (N = 194)  0.667 (N = 233)
# 43  Frac. Difícil LV h4 p6 c4  0.217 (N = 194)  0.428 (N = 233)
# 44  Frac. Difícil LV h4 p3 c5  0.207 (N = 172)  0.753 (N = 209)
# 45  Frac. Difícil LV h4 p4 c5   0.51 (N = 172)  0.504 (N = 209)
# 46  Frac. Difícil LV h4 p5 c5  0.225 (N = 172)  0.355 (N = 209)
# 47  Frac. Difícil LV h4 p6 c5  0.182 (N = 172)    0.4 (N = 209)
# 48  Frac. Difícil LV h5 p3 c3  0.634 (N = 213)  0.679 (N = 247)
# 49  Frac. Difícil LV h5 p4 c3  0.894 (N = 213)  0.593 (N = 247)
# 50  Frac. Difícil LV h5 p5 c3  0.816 (N = 213)  0.289 (N = 247)
# 51  Frac. Difícil LV h5 p6 c3  0.611 (N = 213)  0.585 (N = 247)
# 52  Frac. Difícil LV h5 p3 c4  0.466 (N = 194)  0.602 (N = 229)
# 53  Frac. Difícil LV h5 p4 c4  0.883 (N = 194)  0.382 (N = 229)
# 54  Frac. Difícil LV h5 p5 c4  0.577 (N = 194)  0.246 (N = 229)
# 55  Frac. Difícil LV h5 p6 c4  0.294 (N = 194)  0.197 (N = 229)
# 56  Frac. Difícil LV h5 p3 c5  0.545 (N = 178)  0.825 (N = 215)
# 57  Frac. Difícil LV h5 p4 c5  0.794 (N = 178)  0.437 (N = 215)
# 58  Frac. Difícil LV h5 p5 c5  0.653 (N = 178)  0.306 (N = 215)
# 59  Frac. Difícil LV h5 p6 c5  0.429 (N = 178)  0.238 (N = 215)
#
#             Francia       Inglaterra           Italia               All
# 0   0.684 (N = 157)  0.952 (N = 399)  0.764 (N = 241)  0.947 (N = 1243)
# 1   0.492 (N = 157)  0.947 (N = 399)  0.389 (N = 241)  0.854 (N = 1243)
# 2   0.446 (N = 157)  0.844 (N = 399)  0.027 (N = 241)  0.472 (N = 1243)
# 3   0.619 (N = 157)  0.604 (N = 399)  0.072 (N = 241)  0.454 (N = 1243)
# 4   0.769 (N = 145)  0.935 (N = 368)  0.945 (N = 219)   0.93 (N = 1137)
# 5   0.649 (N = 145)  0.868 (N = 368)  0.812 (N = 219)  0.725 (N = 1137)
# 6   0.455 (N = 145)  0.473 (N = 368)  0.274 (N = 219)  0.136 (N = 1137)
# 7    0.35 (N = 145)  0.491 (N = 368)  0.763 (N = 219)  0.341 (N = 1137)
# 8   0.485 (N = 131)  0.981 (N = 336)  0.702 (N = 203)  0.964 (N = 1037)
# 9   0.531 (N = 131)  0.826 (N = 336)  0.586 (N = 203)  0.862 (N = 1037)
# 10  0.242 (N = 131)  0.346 (N = 336)  0.185 (N = 203)  0.291 (N = 1037)
# 11  0.308 (N = 131)   0.22 (N = 336)  0.377 (N = 203)  0.315 (N = 1037)
# 12    0.6 (N = 159)  0.893 (N = 406)  0.703 (N = 238)  0.931 (N = 1257)
# 13   0.45 (N = 159)  0.942 (N = 406)  0.348 (N = 238)   0.93 (N = 1257)
# 14   0.58 (N = 159)  0.538 (N = 406)  0.027 (N = 238)  0.245 (N = 1257)
# 15   0.53 (N = 159)  0.397 (N = 406)  0.121 (N = 238)  0.333 (N = 1257)
# 16  0.469 (N = 147)  0.966 (N = 373)  0.693 (N = 221)  0.946 (N = 1154)
# 17  0.646 (N = 147)  0.891 (N = 373)  0.535 (N = 221)   0.91 (N = 1154)
# 18  0.833 (N = 147)  0.073 (N = 373)  0.181 (N = 221)  0.382 (N = 1154)
# 19  0.818 (N = 147)  0.107 (N = 373)  0.386 (N = 221)  0.477 (N = 1154)
# 20  0.351 (N = 134)  0.523 (N = 349)  0.622 (N = 203)  0.772 (N = 1061)
# 21  0.591 (N = 134)  0.512 (N = 349)   0.56 (N = 203)  0.743 (N = 1061)
# 22  0.702 (N = 134)  0.027 (N = 349)  0.355 (N = 203)  0.432 (N = 1061)
# 23  0.709 (N = 134)  0.141 (N = 349)  0.101 (N = 203)  0.406 (N = 1061)
# 24  0.431 (N = 163)  0.946 (N = 406)  0.396 (N = 242)  0.793 (N = 1266)
# 25  0.695 (N = 163)   0.98 (N = 406)  0.349 (N = 242)  0.952 (N = 1266)
# 26  0.529 (N = 163)  0.328 (N = 406)  0.134 (N = 242)  0.238 (N = 1266)
# 27  0.118 (N = 163)  0.276 (N = 406)  0.255 (N = 242)  0.212 (N = 1266)
# 28  0.585 (N = 150)  0.565 (N = 383)  0.523 (N = 226)  0.935 (N = 1178)
# 29  0.675 (N = 150)  0.881 (N = 383)  0.566 (N = 226)  0.988 (N = 1178)
# 30  0.466 (N = 150)  0.087 (N = 383)  0.043 (N = 226)  0.365 (N = 1178)
# 31  0.112 (N = 150)   0.16 (N = 383)  0.043 (N = 226)  0.186 (N = 1178)
# 32  0.719 (N = 141)  0.171 (N = 349)  0.576 (N = 207)  0.749 (N = 1076)
# 33  0.869 (N = 141)  0.365 (N = 349)  0.664 (N = 207)  0.967 (N = 1076)
# 34   0.79 (N = 141)  0.062 (N = 349)  0.064 (N = 207)  0.257 (N = 1076)
# 35  0.142 (N = 141)  0.381 (N = 349)  0.057 (N = 207)  0.265 (N = 1076)
# 36  0.831 (N = 162)   0.52 (N = 406)  0.379 (N = 243)  0.506 (N = 1273)
# 37  0.817 (N = 162)  0.882 (N = 406)  0.251 (N = 243)   0.74 (N = 1273)
# 38  0.356 (N = 162)  0.173 (N = 406)  0.021 (N = 243)  0.032 (N = 1273)
# 39  0.342 (N = 162)  0.116 (N = 406)  0.441 (N = 243)  0.131 (N = 1273)
# 40  0.844 (N = 152)  0.445 (N = 384)  0.646 (N = 226)   0.87 (N = 1189)
# 41  0.935 (N = 152)  0.859 (N = 384)  0.322 (N = 226)  0.937 (N = 1189)
# 42  0.448 (N = 152)  0.133 (N = 384)  0.069 (N = 226)  0.222 (N = 1189)
# 43  0.082 (N = 152)  0.139 (N = 384)   0.39 (N = 226)  0.086 (N = 1189)
# 44  0.855 (N = 143)  0.528 (N = 353)  0.769 (N = 208)  0.853 (N = 1085)
# 45  0.743 (N = 143)  0.752 (N = 353)  0.627 (N = 208)  0.869 (N = 1085)
# 46  0.517 (N = 143)  0.126 (N = 353)  0.151 (N = 208)  0.105 (N = 1085)
# 47  0.179 (N = 143)  0.363 (N = 353)   0.28 (N = 208)  0.124 (N = 1085)
# 48  0.811 (N = 161)  0.695 (N = 408)  0.368 (N = 244)  0.869 (N = 1273)
# 49  0.728 (N = 161)  0.946 (N = 408)  0.294 (N = 244)  0.958 (N = 1273)
# 50  0.208 (N = 161)  0.595 (N = 408)  0.127 (N = 244)  0.351 (N = 1273)
# 51  0.227 (N = 161)  0.513 (N = 408)  0.626 (N = 244)  0.623 (N = 1273)
# 52  0.835 (N = 151)  0.741 (N = 385)  0.687 (N = 226)  0.906 (N = 1185)
# 53  0.596 (N = 151)  0.923 (N = 385)  0.326 (N = 226)  0.871 (N = 1185)
# 54  0.071 (N = 151)  0.168 (N = 385)  0.039 (N = 226)   0.03 (N = 1185)
# 55  0.187 (N = 151)   0.16 (N = 385)  0.146 (N = 226)  0.043 (N = 1185)
# 56  0.488 (N = 142)  0.114 (N = 352)  0.737 (N = 210)  0.642 (N = 1097)
# 57  0.367 (N = 142)  0.486 (N = 352)  0.759 (N = 210)  0.744 (N = 1097)
# 58  0.151 (N = 142)  0.077 (N = 352)  0.268 (N = 210)  0.092 (N = 1097)
# 59  0.128 (N = 142)    0.2 (N = 352)  0.277 (N = 210)  0.093 (N = 1097)

# %%
len("")
# Out:
# 0
