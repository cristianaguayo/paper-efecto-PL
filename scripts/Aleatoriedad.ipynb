# %% [markdown]
# # Aleatoriedad en asignación de dificultades

# %%
import numpy as np
import pandas as pd
import os
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy import stats

# %%
def LeerBasesRegresion(datadir, ligas, column_condition):
    dfs = []
    # Primer caso:
    archivo = ligas[0] + '.xlsx'
    df = pd.read_excel(os.path.join(datadir, archivo))
    columns_filter = [i for i in df.columns if column_condition(i)]
    columns_to_keep = ['equipo','Torneo'] + columns_filter
    df = df[columns_to_keep]
    dfs.append(df)
    try:
        for liga in ligas[1:]:
            archivo = liga + '.xlsx'
            df = pd.read_excel(os.path.join(datadir, archivo))
            columns_to_keep = ['equipo','Torneo'] + [i for i in df.columns if column_condition(i)]
            df = df[columns_to_keep]
            dfs.append(df)
    except:
        pass
    return dfs, columns_filter

# %%
# def FiltrarRegulares(df, defin, c, h):
#     if defin == 'elo':
#         col = 'categoria_%s_c%s' % (defin, c)
#         df_filter = df[df[col] == 'regular']
#     elif defin == 'general':
#         col = 'categoria_%s_h%s_c%s' % (defin, h, c)
#         df_filter = df[df[col] == 'regular']
#     else:
#         col1 = 'categoria_local_h%s_c%s' % (h,c)
#         col2 = 'categoria_visita_h%s_c%s' % (h,c)
#         df_filter = df[(df[col1] == 'regular') & 
#                        (df[col2] == 'regular')]
#     return df_filter
def FiltrarRegulares(df, defin, c, h, filt):
    cats = ['facil','regular','dificil']
    if filt not in  ['regular', ""]:
        cats = [c for c in cats if c != filt]
    elif filt == 'regular':
        cats = [filt]
    else:
        pass
    if defin == 'elo':
        col = 'categoria_%s_c%s' % (defin, c)
        df_filter = df[df[col].isin(cats)]
    elif defin == 'general':
        col = 'categoria_%s_h%s_c%s' % (defin, h, c)
        df_filter = df[df[col].isin(cats)]
    else:
        col1 = 'categoria_local_h%s_c%s' % (h,c)
        col2 = 'categoria_visita_h%s_c%s' % (h,c)
        df_filter = df[(df[col1].isin(cats)) & 
                       (df[col2].isin(cats))]
    return df_filter

# %%
def SignificanciaVariablesManual(coef, se, pval, replace_spaces = True):
    coef = "%.3f" % (np.round(coef, decimals = 3))
    se = "%.3f" % (np.round(se, decimals = 3))
    if coef > 0:
        output = '_' + str(coef) + ' (' + str(se) + ')'                    
    else:
        output = str(coef) + ' (' + str(se) + ')'
    pval = np.round(pval, 3)
    if pval < 0.01:
        output = output + '***'
    elif pval < 0.05 and pval >= 0.01:
        output = output + '**_'
    elif pval < 0.1 and pval >=0.05:
        output = output + '*__'
    else:
        output = output + '___'
    if replace_spaces:
        output = output.replace("_"," ")
    return output

# %%
def ANOVA1ViaIndicadores(datadir, ligas, defin, filtro):
    dict_replaces = {'_mean': '',
                     '_':' ',
                     'dificil':'Difícil',
                     'dificl' : 'Difícil',
                     'facil': 'Fácil',
                     'regular' : 'Regular',
                     'prom': 'Promedio',
                     'posicion': 'Posición',
                     'primer' : 'Primer',
                     'ronda' : 'Ronda',
                     'gral': 'Gral.',
                     'elo' : 'ELO',
                     'categoria': 'Categoría',
                     'local': 'Local',
                     'visita': 'Visita',
                     'general' : 'Gral.',
                     'corr' : 'Correg.',
                     'perc' : 'Frac.',
                     ' h' : ' Ant. ',
                     ' p': ' Primeros ',
                     ' c': ' Corte ',
                     'lv' : 'LV',
                     'Primer Fácil C': 'Primer Fácil LV C',
                     'Primer Difícil C': 'Primer Difícil LV C'}
    if defin != 'lv':
        dfs, columns_filter = LeerBasesRegresion(datadir,
                                                 ligas,
                                                 lambda x: defin in x)
    else:
        dfs, columns_filter = LeerBasesRegresion(datadir,
                                                 ligas,
                                                 lambda x: defin in x or 'local' in x or 'visita' in x)        
    columns_facil = [i for i in columns_filter if 'facil' in i and 'perc' in i]
    columns_dificil = [i for i in columns_filter if 'dificil' in i and 'perc' in i]
    dictresumen_l = {'Indicador' : columns_facil}
    dfs_resumen = []
    # Columnas de facil
    for i in range(len(ligas)):
        liga = ligas[i]
        if liga != 'All':
            df_liga = dfs[i]
        else:
            df_liga = pd.concat(dfs, ignore_index = True)
        resultados = []
        for var in columns_facil:
            if filtro != 'regular':
                if 'facil' in var:
                    filt = 'facil'
                else:
                    filt = 'dificil'
            else:
                filt = filtro
            if defin != 'elo':
                aux = var.split('_h')[1].split('_p')
                h, c = aux[0], aux[1].split('_c')[1]
            else:
                h, c = None, var.split('_c')[1]
            formula = var + ' ~ C(equipo)'
            df_anova = FiltrarRegulares(df_liga, defin, c, h, filt)
            n_obs = df_anova.shape[0]
            model = ols(formula,
                        data =  df_anova).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            out = '%s (N = %s)' % (np.round(aov_table['PR(>F)'][0], decimals = 3), n_obs)
            resultados.append(out)
        dictresumen_l[liga] = resultados
    df_facil = pd.DataFrame(data = dictresumen_l)
    df_facil['Indicador'] = df_facil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_facil)
    dictresumen_v = {'Indicador' : columns_dificil}
    for i in range(len(ligas)):
        liga = ligas[i]
        liga = ligas[i]
        if liga != 'All':
            df_liga = dfs[i]
        else:
            df_liga = pd.concat(dfs, ignore_index = True)
        resultados = []
        for var in columns_dificil:
            if filtro != 'regular':
                if 'facil' in var:
                    filt = 'facil'
                else:
                    filt = 'dificil'
            else:
                filt = filtro
            if defin != 'elo':
                aux = var.split('_h')[1].split('_p')
                h, c = aux[0], aux[1].split('_c')[1]
            else:
                h, c = None, var.split('_c')[1]
            formula = var + ' ~ C(equipo)'
            df_anova = FiltrarRegulares(df_liga, defin, c, h, filt)
            n_obs = df_anova.shape[0]
            model = ols(formula,
                        data = df_anova).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            out = '%s (N = %s)' % (np.round(aov_table['PR(>F)'][0], decimals = 3), n_obs)
            resultados.append(out)
        dictresumen_v[liga] = resultados
    df_dificil = pd.DataFrame(data = dictresumen_v)
    df_dificil['Indicador'] = df_dificil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_dificil)
    return dfs_resumen

# %% [markdown]
# ## Aleatoriedad para indicadores según puntaje ELO

# %%
filtro = 'regular'

# %%
# %%time
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
outputdir = os.path.join(os.path.pardir,'resultados','aleatoriedad-inicio')
dfs_resumen_elo = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       defin = 'elo',
                                       filtro = filtro)

outputfile = 'aleatoriedad-elo-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_elo, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()
# Out:
# CPU times: user 11.8 s, sys: 159 ms, total: 11.9 s
# Wall time: 5.94 s

# %%
dfs_resumen_elo[0]
# Out:
#                 Indicador         Alemania           Espana          Francia  \
# 0   Frac. Fácil ELO p4 c3  0.282 (N = 180)  0.028 (N = 210)  0.028 (N = 140)
# 1   Frac. Fácil ELO p5 c3   0.03 (N = 180)  0.161 (N = 210)  0.089 (N = 140)
# 2   Frac. Fácil ELO p6 c3  0.031 (N = 180)  0.064 (N = 210)  0.111 (N = 140)
# 3   Frac. Fácil ELO p7 c3  0.005 (N = 180)  0.065 (N = 210)  0.113 (N = 140)
# 4   Frac. Fácil ELO p4 c4  0.326 (N = 150)  0.094 (N = 180)  0.326 (N = 120)
# 5   Frac. Fácil ELO p5 c4  0.009 (N = 150)  0.342 (N = 180)  0.559 (N = 120)
# 6   Frac. Fácil ELO p6 c4  0.035 (N = 150)  0.092 (N = 180)   0.87 (N = 120)
# 7   Frac. Fácil ELO p7 c4    0.0 (N = 150)  0.072 (N = 180)  0.671 (N = 120)
# 8   Frac. Fácil ELO p4 c5   0.58 (N = 120)  0.049 (N = 150)  0.855 (N = 100)
# 9   Frac. Fácil ELO p5 c5  0.126 (N = 120)  0.061 (N = 150)  0.594 (N = 100)
# 10  Frac. Fácil ELO p6 c5  0.218 (N = 120)  0.009 (N = 150)  0.708 (N = 100)
# 11  Frac. Fácil ELO p7 c5   0.05 (N = 120)  0.012 (N = 150)  0.745 (N = 100)
#
#          Inglaterra           Italia               All
# 0   0.135 (N = 354)  0.902 (N = 208)  0.009 (N = 1092)
# 1    0.22 (N = 354)  0.953 (N = 208)  0.025 (N = 1092)
# 2   0.318 (N = 354)  0.866 (N = 208)  0.019 (N = 1092)
# 3   0.864 (N = 354)  0.524 (N = 208)   0.01 (N = 1092)
# 4   0.576 (N = 304)  0.351 (N = 178)    0.07 (N = 932)
# 5   0.519 (N = 304)  0.374 (N = 178)   0.027 (N = 932)
# 6   0.728 (N = 304)  0.458 (N = 178)   0.041 (N = 932)
# 7   0.758 (N = 304)  0.325 (N = 178)   0.001 (N = 932)
# 8   0.496 (N = 254)  0.235 (N = 148)   0.191 (N = 772)
# 9   0.582 (N = 254)  0.195 (N = 148)   0.051 (N = 772)
# 10  0.346 (N = 254)  0.409 (N = 148)   0.016 (N = 772)
# 11  0.669 (N = 254)  0.517 (N = 148)   0.013 (N = 772)

# %%
dfs_resumen_elo[1]
# Out:
#                   Indicador         Alemania           Espana  \
# 0   Frac. Difícil ELO p4 c3  0.998 (N = 180)  0.207 (N = 210)
# 1   Frac. Difícil ELO p5 c3  0.933 (N = 180)   0.03 (N = 210)
# 2   Frac. Difícil ELO p6 c3  0.806 (N = 180)  0.252 (N = 210)
# 3   Frac. Difícil ELO p7 c3  0.724 (N = 180)  0.143 (N = 210)
# 4   Frac. Difícil ELO p4 c4  0.757 (N = 150)  0.023 (N = 180)
# 5   Frac. Difícil ELO p5 c4  0.192 (N = 150)  0.013 (N = 180)
# 6   Frac. Difícil ELO p6 c4  0.408 (N = 150)  0.068 (N = 180)
# 7   Frac. Difícil ELO p7 c4  0.186 (N = 150)  0.044 (N = 180)
# 8   Frac. Difícil ELO p4 c5  0.403 (N = 120)  0.004 (N = 150)
# 9   Frac. Difícil ELO p5 c5  0.072 (N = 120)  0.025 (N = 150)
# 10  Frac. Difícil ELO p6 c5  0.379 (N = 120)   0.12 (N = 150)
# 11  Frac. Difícil ELO p7 c5  0.161 (N = 120)  0.054 (N = 150)
#
#             Francia       Inglaterra           Italia               All
# 0   0.472 (N = 140)  0.926 (N = 354)  0.159 (N = 208)  0.834 (N = 1092)
# 1   0.596 (N = 140)  0.933 (N = 354)  0.044 (N = 208)  0.356 (N = 1092)
# 2   0.379 (N = 140)   0.74 (N = 354)   0.34 (N = 208)  0.537 (N = 1092)
# 3   0.502 (N = 140)  0.572 (N = 354)  0.564 (N = 208)  0.445 (N = 1092)
# 4   0.015 (N = 120)  0.991 (N = 304)  0.215 (N = 178)   0.352 (N = 932)
# 5   0.162 (N = 120)  0.939 (N = 304)  0.091 (N = 178)   0.073 (N = 932)
# 6   0.082 (N = 120)  0.715 (N = 304)  0.419 (N = 178)   0.182 (N = 932)
# 7    0.32 (N = 120)  0.855 (N = 304)  0.697 (N = 178)   0.325 (N = 932)
# 8   0.289 (N = 100)  0.633 (N = 254)  0.166 (N = 148)   0.071 (N = 772)
# 9   0.596 (N = 100)  0.755 (N = 254)  0.103 (N = 148)   0.088 (N = 772)
# 10  0.463 (N = 100)  0.609 (N = 254)  0.074 (N = 148)   0.206 (N = 772)
# 11  0.291 (N = 100)  0.686 (N = 254)  0.053 (N = 148)   0.073 (N = 772)

# %% [markdown]
# ## Aleatoriedad para indicadores según definición general

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
dfs_resumen_general = ANOVA1ViaIndicadores(datadir,
                                           ligas,
                                           defin = 'general',
                                           filtro = filtro)
outputfile = 'aleatoriedad-general-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_general, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_general[0]
# Out:
#                      Indicador         Alemania           Espana  \
# 0   Frac. Fácil Gral. h1 p4 c3  0.679 (N = 157)  0.628 (N = 180)
# 1   Frac. Fácil Gral. h1 p5 c3  0.199 (N = 157)  0.486 (N = 180)
# 2   Frac. Fácil Gral. h1 p6 c3  0.472 (N = 157)  0.467 (N = 180)
# 3   Frac. Fácil Gral. h1 p7 c3  0.418 (N = 157)  0.272 (N = 180)
# 4   Frac. Fácil Gral. h1 p4 c4  0.248 (N = 127)  0.356 (N = 150)
# 5   Frac. Fácil Gral. h1 p5 c4  0.009 (N = 127)  0.387 (N = 150)
# 6   Frac. Fácil Gral. h1 p6 c4  0.054 (N = 127)  0.379 (N = 150)
# 7   Frac. Fácil Gral. h1 p7 c4  0.138 (N = 127)  0.367 (N = 150)
# 8   Frac. Fácil Gral. h1 p4 c5   0.891 (N = 97)  0.402 (N = 120)
# 9   Frac. Fácil Gral. h1 p5 c5    0.71 (N = 97)  0.253 (N = 120)
# 10  Frac. Fácil Gral. h1 p6 c5   0.952 (N = 97)  0.259 (N = 120)
# 11  Frac. Fácil Gral. h1 p7 c5   0.897 (N = 97)  0.113 (N = 120)
# 12  Frac. Fácil Gral. h2 p4 c3  0.401 (N = 172)  0.724 (N = 190)
# 13  Frac. Fácil Gral. h2 p5 c3   0.37 (N = 172)  0.498 (N = 190)
# 14  Frac. Fácil Gral. h2 p6 c3  0.821 (N = 172)  0.235 (N = 190)
# 15  Frac. Fácil Gral. h2 p7 c3  0.838 (N = 172)  0.494 (N = 190)
# 16  Frac. Fácil Gral. h2 p4 c4  0.143 (N = 142)   0.74 (N = 160)
# 17  Frac. Fácil Gral. h2 p5 c4  0.213 (N = 142)  0.677 (N = 160)
# 18  Frac. Fácil Gral. h2 p6 c4  0.219 (N = 142)  0.554 (N = 160)
# 19  Frac. Fácil Gral. h2 p7 c4   0.16 (N = 142)  0.365 (N = 160)
# 20  Frac. Fácil Gral. h2 p4 c5  0.022 (N = 112)  0.583 (N = 130)
# 21  Frac. Fácil Gral. h2 p5 c5  0.007 (N = 112)  0.616 (N = 130)
# 22  Frac. Fácil Gral. h2 p6 c5  0.068 (N = 112)  0.604 (N = 130)
# 23  Frac. Fácil Gral. h2 p7 c5  0.068 (N = 112)  0.355 (N = 130)
# 24  Frac. Fácil Gral. h3 p4 c3  0.768 (N = 176)  0.397 (N = 197)
# 25  Frac. Fácil Gral. h3 p5 c3  0.824 (N = 176)  0.254 (N = 197)
# 26  Frac. Fácil Gral. h3 p6 c3  0.882 (N = 176)  0.146 (N = 197)
# 27  Frac. Fácil Gral. h3 p7 c3  0.499 (N = 176)  0.361 (N = 197)
# 28  Frac. Fácil Gral. h3 p4 c4  0.702 (N = 146)  0.362 (N = 167)
# 29  Frac. Fácil Gral. h3 p5 c4  0.756 (N = 146)  0.461 (N = 167)
# 30  Frac. Fácil Gral. h3 p6 c4  0.558 (N = 146)  0.612 (N = 167)
# 31  Frac. Fácil Gral. h3 p7 c4  0.141 (N = 146)   0.81 (N = 167)
# 32  Frac. Fácil Gral. h3 p4 c5  0.528 (N = 116)  0.323 (N = 137)
# 33  Frac. Fácil Gral. h3 p5 c5   0.27 (N = 116)  0.306 (N = 137)
# 34  Frac. Fácil Gral. h3 p6 c5  0.449 (N = 116)  0.412 (N = 137)
# 35  Frac. Fácil Gral. h3 p7 c5    0.3 (N = 116)  0.675 (N = 137)
# 36  Frac. Fácil Gral. h4 p4 c3  0.634 (N = 177)   0.36 (N = 204)
# 37  Frac. Fácil Gral. h4 p5 c3  0.541 (N = 177)  0.659 (N = 204)
# 38  Frac. Fácil Gral. h4 p6 c3  0.301 (N = 177)  0.183 (N = 204)
# 39  Frac. Fácil Gral. h4 p7 c3  0.121 (N = 177)  0.137 (N = 204)
# 40  Frac. Fácil Gral. h4 p4 c4   0.51 (N = 147)  0.803 (N = 174)
# 41  Frac. Fácil Gral. h4 p5 c4  0.487 (N = 147)  0.857 (N = 174)
# 42  Frac. Fácil Gral. h4 p6 c4  0.617 (N = 147)  0.364 (N = 174)
# 43  Frac. Fácil Gral. h4 p7 c4  0.499 (N = 147)   0.36 (N = 174)
# 44  Frac. Fácil Gral. h4 p4 c5  0.472 (N = 117)  0.675 (N = 144)
# 45  Frac. Fácil Gral. h4 p5 c5  0.676 (N = 117)  0.679 (N = 144)
# 46  Frac. Fácil Gral. h4 p6 c5  0.891 (N = 117)  0.162 (N = 144)
# 47  Frac. Fácil Gral. h4 p7 c5  0.943 (N = 117)  0.406 (N = 144)
# 48  Frac. Fácil Gral. h5 p4 c3  0.941 (N = 178)  0.434 (N = 204)
# 49  Frac. Fácil Gral. h5 p5 c3  0.988 (N = 178)  0.681 (N = 204)
# 50  Frac. Fácil Gral. h5 p6 c3  0.829 (N = 178)  0.355 (N = 204)
# 51  Frac. Fácil Gral. h5 p7 c3  0.869 (N = 178)  0.146 (N = 204)
# 52  Frac. Fácil Gral. h5 p4 c4  0.906 (N = 148)   0.45 (N = 174)
# 53  Frac. Fácil Gral. h5 p5 c4  0.957 (N = 148)  0.655 (N = 174)
# 54  Frac. Fácil Gral. h5 p6 c4  0.559 (N = 148)  0.243 (N = 174)
# 55  Frac. Fácil Gral. h5 p7 c4  0.437 (N = 148)  0.183 (N = 174)
# 56  Frac. Fácil Gral. h5 p4 c5  0.347 (N = 118)  0.849 (N = 144)
# 57  Frac. Fácil Gral. h5 p5 c5  0.841 (N = 118)  0.802 (N = 144)
# 58  Frac. Fácil Gral. h5 p6 c5  0.671 (N = 118)  0.635 (N = 144)
# 59  Frac. Fácil Gral. h5 p7 c5  0.699 (N = 118)  0.301 (N = 144)
#
#             Francia       Inglaterra           Italia               All
# 0   0.518 (N = 120)  0.406 (N = 305)  0.161 (N = 174)   0.506 (N = 936)
# 1   0.471 (N = 120)  0.139 (N = 305)  0.153 (N = 174)    0.11 (N = 936)
# 2    0.74 (N = 120)  0.365 (N = 305)  0.349 (N = 174)   0.519 (N = 936)
# 3   0.601 (N = 120)  0.615 (N = 305)  0.349 (N = 174)   0.473 (N = 936)
# 4   0.427 (N = 100)   0.47 (N = 255)  0.511 (N = 144)   0.299 (N = 776)
# 5   0.552 (N = 100)  0.355 (N = 255)  0.257 (N = 144)   0.081 (N = 776)
# 6   0.866 (N = 100)  0.697 (N = 255)  0.432 (N = 144)   0.479 (N = 776)
# 7   0.866 (N = 100)  0.825 (N = 255)  0.338 (N = 144)   0.592 (N = 776)
# 8    0.382 (N = 80)  0.347 (N = 205)  0.226 (N = 114)   0.391 (N = 616)
# 9    0.563 (N = 80)   0.61 (N = 205)  0.118 (N = 114)   0.413 (N = 616)
# 10   0.929 (N = 80)  0.748 (N = 205)  0.219 (N = 114)    0.81 (N = 616)
# 11   0.911 (N = 80)  0.937 (N = 205)  0.557 (N = 114)   0.907 (N = 616)
# 12  0.296 (N = 125)  0.228 (N = 327)  0.239 (N = 190)  0.299 (N = 1004)
# 13   0.47 (N = 125)  0.079 (N = 327)  0.149 (N = 190)  0.132 (N = 1004)
# 14    0.6 (N = 125)  0.074 (N = 327)  0.216 (N = 190)  0.211 (N = 1004)
# 15  0.211 (N = 125)  0.366 (N = 327)  0.146 (N = 190)  0.317 (N = 1004)
# 16  0.537 (N = 105)  0.079 (N = 277)   0.19 (N = 160)   0.131 (N = 844)
# 17  0.682 (N = 105)  0.074 (N = 277)  0.034 (N = 160)   0.103 (N = 844)
# 18  0.674 (N = 105)  0.019 (N = 277)  0.112 (N = 160)   0.056 (N = 844)
# 19  0.673 (N = 105)  0.157 (N = 277)  0.205 (N = 160)   0.123 (N = 844)
# 20   0.342 (N = 85)  0.004 (N = 227)  0.178 (N = 130)   0.001 (N = 684)
# 21   0.771 (N = 85)  0.014 (N = 227)  0.167 (N = 130)   0.007 (N = 684)
# 22   0.588 (N = 85)  0.004 (N = 227)  0.239 (N = 130)   0.012 (N = 684)
# 23   0.383 (N = 85)  0.039 (N = 227)  0.378 (N = 130)   0.016 (N = 684)
# 24  0.813 (N = 128)  0.749 (N = 334)  0.244 (N = 193)  0.809 (N = 1028)
# 25  0.929 (N = 128)  0.452 (N = 334)  0.241 (N = 193)  0.665 (N = 1028)
# 26  0.899 (N = 128)  0.447 (N = 334)   0.11 (N = 193)  0.479 (N = 1028)
# 27  0.546 (N = 128)  0.839 (N = 334)  0.062 (N = 193)  0.384 (N = 1028)
# 28  0.445 (N = 108)  0.277 (N = 284)  0.251 (N = 163)    0.34 (N = 868)
# 29  0.592 (N = 108)  0.448 (N = 284)  0.275 (N = 163)   0.521 (N = 868)
# 30  0.448 (N = 108)   0.37 (N = 284)  0.382 (N = 163)   0.394 (N = 868)
# 31  0.127 (N = 108)  0.839 (N = 284)  0.363 (N = 163)   0.344 (N = 868)
# 32    0.98 (N = 88)  0.618 (N = 234)  0.652 (N = 133)   0.739 (N = 708)
# 33   0.991 (N = 88)  0.507 (N = 234)  0.483 (N = 133)   0.509 (N = 708)
# 34   0.953 (N = 88)  0.132 (N = 234)  0.553 (N = 133)   0.401 (N = 708)
# 35   0.716 (N = 88)  0.336 (N = 234)  0.473 (N = 133)   0.445 (N = 708)
# 36  0.364 (N = 130)  0.005 (N = 336)  0.628 (N = 197)  0.102 (N = 1044)
# 37  0.555 (N = 130)  0.018 (N = 336)  0.745 (N = 197)  0.269 (N = 1044)
# 38  0.616 (N = 130)  0.038 (N = 336)  0.912 (N = 197)  0.162 (N = 1044)
# 39  0.393 (N = 130)  0.068 (N = 336)  0.822 (N = 197)  0.072 (N = 1044)
# 40   0.42 (N = 110)  0.077 (N = 286)  0.721 (N = 167)   0.427 (N = 884)
# 41  0.795 (N = 110)   0.07 (N = 286)  0.635 (N = 167)   0.512 (N = 884)
# 42  0.896 (N = 110)  0.049 (N = 286)  0.911 (N = 167)    0.51 (N = 884)
# 43   0.25 (N = 110)  0.063 (N = 286)  0.919 (N = 167)   0.219 (N = 884)
# 44   0.914 (N = 90)  0.574 (N = 236)  0.736 (N = 137)   0.846 (N = 724)
# 45   0.974 (N = 90)  0.601 (N = 236)  0.724 (N = 137)   0.923 (N = 724)
# 46   0.985 (N = 90)  0.337 (N = 236)  0.945 (N = 137)   0.871 (N = 724)
# 47   0.513 (N = 90)  0.619 (N = 236)  0.975 (N = 137)     0.9 (N = 724)
# 48  0.278 (N = 131)  0.117 (N = 340)  0.315 (N = 199)  0.356 (N = 1052)
# 49  0.196 (N = 131)  0.175 (N = 340)  0.318 (N = 199)  0.515 (N = 1052)
# 50  0.548 (N = 131)  0.031 (N = 340)   0.31 (N = 199)  0.171 (N = 1052)
# 51  0.252 (N = 131)  0.193 (N = 340)  0.185 (N = 199)   0.16 (N = 1052)
# 52  0.306 (N = 111)  0.671 (N = 290)  0.267 (N = 169)   0.657 (N = 892)
# 53  0.574 (N = 111)  0.672 (N = 290)  0.127 (N = 169)   0.729 (N = 892)
# 54  0.867 (N = 111)  0.241 (N = 290)  0.183 (N = 169)   0.288 (N = 892)
# 55    0.5 (N = 111)  0.407 (N = 290)  0.098 (N = 169)   0.183 (N = 892)
# 56   0.059 (N = 91)  0.831 (N = 240)  0.398 (N = 139)   0.556 (N = 732)
# 57   0.164 (N = 91)  0.878 (N = 240)   0.18 (N = 139)    0.62 (N = 732)
# 58   0.469 (N = 91)  0.552 (N = 240)  0.206 (N = 139)   0.484 (N = 732)
# 59    0.27 (N = 91)   0.97 (N = 240)  0.292 (N = 139)   0.686 (N = 732)

# %%
dfs_resumen_general[1]
# Out:
#                        Indicador         Alemania           Espana  \
# 0   Frac. Difícil Gral. h1 p4 c3  0.926 (N = 157)  0.204 (N = 180)
# 1   Frac. Difícil Gral. h1 p5 c3  0.556 (N = 157)  0.025 (N = 180)
# 2   Frac. Difícil Gral. h1 p6 c3  0.312 (N = 157)  0.204 (N = 180)
# 3   Frac. Difícil Gral. h1 p7 c3   0.52 (N = 157)  0.149 (N = 180)
# 4   Frac. Difícil Gral. h1 p4 c4   0.88 (N = 127)  0.159 (N = 150)
# 5   Frac. Difícil Gral. h1 p5 c4  0.617 (N = 127)  0.366 (N = 150)
# 6   Frac. Difícil Gral. h1 p6 c4  0.948 (N = 127)  0.482 (N = 150)
# 7   Frac. Difícil Gral. h1 p7 c4  0.638 (N = 127)  0.318 (N = 150)
# 8   Frac. Difícil Gral. h1 p4 c5   0.732 (N = 97)  0.003 (N = 120)
# 9   Frac. Difícil Gral. h1 p5 c5   0.472 (N = 97)  0.013 (N = 120)
# 10  Frac. Difícil Gral. h1 p6 c5   0.797 (N = 97)    0.2 (N = 120)
# 11  Frac. Difícil Gral. h1 p7 c5    0.32 (N = 97)  0.111 (N = 120)
# 12  Frac. Difícil Gral. h2 p4 c3  0.844 (N = 172)  0.641 (N = 190)
# 13  Frac. Difícil Gral. h2 p5 c3  0.049 (N = 172)  0.064 (N = 190)
# 14  Frac. Difícil Gral. h2 p6 c3  0.295 (N = 172)  0.432 (N = 190)
# 15  Frac. Difícil Gral. h2 p7 c3  0.225 (N = 172)  0.484 (N = 190)
# 16  Frac. Difícil Gral. h2 p4 c4  0.902 (N = 142)  0.256 (N = 160)
# 17  Frac. Difícil Gral. h2 p5 c4  0.296 (N = 142)  0.204 (N = 160)
# 18  Frac. Difícil Gral. h2 p6 c4  0.166 (N = 142)  0.459 (N = 160)
# 19  Frac. Difícil Gral. h2 p7 c4  0.599 (N = 142)  0.304 (N = 160)
# 20  Frac. Difícil Gral. h2 p4 c5  0.375 (N = 112)  0.238 (N = 130)
# 21  Frac. Difícil Gral. h2 p5 c5  0.246 (N = 112)  0.443 (N = 130)
# 22  Frac. Difícil Gral. h2 p6 c5  0.548 (N = 112)  0.637 (N = 130)
# 23  Frac. Difícil Gral. h2 p7 c5  0.522 (N = 112)  0.267 (N = 130)
# 24  Frac. Difícil Gral. h3 p4 c3   0.68 (N = 176)  0.303 (N = 197)
# 25  Frac. Difícil Gral. h3 p5 c3  0.384 (N = 176)  0.357 (N = 197)
# 26  Frac. Difícil Gral. h3 p6 c3   0.24 (N = 176)  0.427 (N = 197)
# 27  Frac. Difícil Gral. h3 p7 c3  0.297 (N = 176)  0.156 (N = 197)
# 28  Frac. Difícil Gral. h3 p4 c4  0.318 (N = 146)  0.031 (N = 167)
# 29  Frac. Difícil Gral. h3 p5 c4  0.047 (N = 146)  0.033 (N = 167)
# 30  Frac. Difícil Gral. h3 p6 c4   0.02 (N = 146)  0.037 (N = 167)
# 31  Frac. Difícil Gral. h3 p7 c4   0.01 (N = 146)  0.016 (N = 167)
# 32  Frac. Difícil Gral. h3 p4 c5  0.569 (N = 116)  0.141 (N = 137)
# 33  Frac. Difícil Gral. h3 p5 c5  0.275 (N = 116)  0.152 (N = 137)
# 34  Frac. Difícil Gral. h3 p6 c5  0.055 (N = 116)   0.29 (N = 137)
# 35  Frac. Difícil Gral. h3 p7 c5  0.012 (N = 116)  0.093 (N = 137)
# 36  Frac. Difícil Gral. h4 p4 c3  0.763 (N = 177)  0.344 (N = 204)
# 37  Frac. Difícil Gral. h4 p5 c3  0.701 (N = 177)  0.134 (N = 204)
# 38  Frac. Difícil Gral. h4 p6 c3  0.633 (N = 177)  0.319 (N = 204)
# 39  Frac. Difícil Gral. h4 p7 c3  0.271 (N = 177)  0.399 (N = 204)
# 40  Frac. Difícil Gral. h4 p4 c4  0.337 (N = 147)  0.557 (N = 174)
# 41  Frac. Difícil Gral. h4 p5 c4  0.313 (N = 147)  0.207 (N = 174)
# 42  Frac. Difícil Gral. h4 p6 c4  0.585 (N = 147)   0.25 (N = 174)
# 43  Frac. Difícil Gral. h4 p7 c4  0.748 (N = 147)  0.235 (N = 174)
# 44  Frac. Difícil Gral. h4 p4 c5  0.601 (N = 117)  0.915 (N = 144)
# 45  Frac. Difícil Gral. h4 p5 c5  0.705 (N = 117)  0.573 (N = 144)
# 46  Frac. Difícil Gral. h4 p6 c5  0.827 (N = 117)  0.407 (N = 144)
# 47  Frac. Difícil Gral. h4 p7 c5  0.925 (N = 117)  0.456 (N = 144)
# 48  Frac. Difícil Gral. h5 p4 c3  0.491 (N = 178)  0.175 (N = 204)
# 49  Frac. Difícil Gral. h5 p5 c3  0.422 (N = 178)  0.044 (N = 204)
# 50  Frac. Difícil Gral. h5 p6 c3  0.557 (N = 178)  0.301 (N = 204)
# 51  Frac. Difícil Gral. h5 p7 c3  0.161 (N = 178)  0.247 (N = 204)
# 52  Frac. Difícil Gral. h5 p4 c4   0.41 (N = 148)  0.212 (N = 174)
# 53  Frac. Difícil Gral. h5 p5 c4  0.095 (N = 148)  0.279 (N = 174)
# 54  Frac. Difícil Gral. h5 p6 c4  0.118 (N = 148)  0.684 (N = 174)
# 55  Frac. Difícil Gral. h5 p7 c4   0.04 (N = 148)  0.326 (N = 174)
# 56  Frac. Difícil Gral. h5 p4 c5  0.511 (N = 118)   0.12 (N = 144)
# 57  Frac. Difícil Gral. h5 p5 c5  0.289 (N = 118)  0.232 (N = 144)
# 58  Frac. Difícil Gral. h5 p6 c5  0.053 (N = 118)  0.157 (N = 144)
# 59  Frac. Difícil Gral. h5 p7 c5  0.271 (N = 118)  0.033 (N = 144)
#
#             Francia       Inglaterra           Italia               All
# 0   0.687 (N = 120)  0.867 (N = 305)  0.817 (N = 174)   0.865 (N = 936)
# 1   0.792 (N = 120)  0.799 (N = 305)  0.157 (N = 174)    0.23 (N = 936)
# 2   0.807 (N = 120)  0.574 (N = 305)  0.556 (N = 174)   0.422 (N = 936)
# 3   0.646 (N = 120)  0.568 (N = 305)  0.589 (N = 174)   0.288 (N = 936)
# 4   0.613 (N = 100)  0.851 (N = 255)   0.72 (N = 144)   0.738 (N = 776)
# 5   0.559 (N = 100)  0.685 (N = 255)  0.407 (N = 144)   0.426 (N = 776)
# 6   0.561 (N = 100)   0.44 (N = 255)   0.34 (N = 144)   0.604 (N = 776)
# 7   0.618 (N = 100)  0.607 (N = 255)  0.159 (N = 144)   0.389 (N = 776)
# 8    0.875 (N = 80)   0.26 (N = 205)  0.533 (N = 114)   0.177 (N = 616)
# 9     0.91 (N = 80)  0.191 (N = 205)    0.4 (N = 114)   0.086 (N = 616)
# 10   0.882 (N = 80)  0.108 (N = 205)  0.571 (N = 114)   0.399 (N = 616)
# 11   0.811 (N = 80)  0.313 (N = 205)  0.584 (N = 114)   0.319 (N = 616)
# 12  0.761 (N = 125)  0.624 (N = 327)  0.568 (N = 190)  0.904 (N = 1004)
# 13  0.892 (N = 125)  0.557 (N = 327)  0.376 (N = 190)  0.218 (N = 1004)
# 14  0.903 (N = 125)  0.422 (N = 327)  0.388 (N = 190)  0.494 (N = 1004)
# 15  0.562 (N = 125)  0.646 (N = 327)  0.568 (N = 190)  0.534 (N = 1004)
# 16  0.843 (N = 105)   0.74 (N = 277)  0.215 (N = 160)   0.742 (N = 844)
# 17  0.911 (N = 105)  0.518 (N = 277)   0.04 (N = 160)   0.261 (N = 844)
# 18  0.933 (N = 105)  0.608 (N = 277)  0.097 (N = 160)   0.492 (N = 844)
# 19  0.448 (N = 105)  0.891 (N = 277)  0.219 (N = 160)   0.631 (N = 844)
# 20   0.888 (N = 85)  0.185 (N = 227)  0.212 (N = 130)    0.24 (N = 684)
# 21   0.901 (N = 85)  0.195 (N = 227)  0.203 (N = 130)   0.308 (N = 684)
# 22   0.881 (N = 85)  0.144 (N = 227)  0.252 (N = 130)   0.495 (N = 684)
# 23   0.731 (N = 85)  0.248 (N = 227)  0.278 (N = 130)   0.312 (N = 684)
# 24  0.935 (N = 128)  0.437 (N = 334)  0.696 (N = 193)  0.773 (N = 1028)
# 25   0.97 (N = 128)  0.481 (N = 334)  0.181 (N = 193)  0.481 (N = 1028)
# 26  0.855 (N = 128)  0.365 (N = 334)  0.123 (N = 193)  0.278 (N = 1028)
# 27  0.705 (N = 128)  0.499 (N = 334)  0.056 (N = 193)  0.099 (N = 1028)
# 28  0.926 (N = 108)   0.15 (N = 284)  0.275 (N = 163)   0.067 (N = 868)
# 29  0.967 (N = 108)  0.201 (N = 284)  0.047 (N = 163)   0.012 (N = 868)
# 30  0.911 (N = 108)  0.189 (N = 284)  0.078 (N = 163)   0.008 (N = 868)
# 31  0.721 (N = 108)  0.242 (N = 284)  0.039 (N = 163)   0.001 (N = 868)
# 32   0.912 (N = 88)   0.36 (N = 234)  0.579 (N = 133)   0.487 (N = 708)
# 33    0.43 (N = 88)  0.314 (N = 234)  0.305 (N = 133)   0.151 (N = 708)
# 34   0.396 (N = 88)  0.069 (N = 234)  0.546 (N = 133)   0.072 (N = 708)
# 35   0.422 (N = 88)  0.435 (N = 234)  0.406 (N = 133)   0.033 (N = 708)
# 36   0.81 (N = 130)  0.886 (N = 336)  0.635 (N = 197)   0.91 (N = 1044)
# 37  0.476 (N = 130)  0.791 (N = 336)  0.724 (N = 197)  0.661 (N = 1044)
# 38  0.561 (N = 130)  0.686 (N = 336)   0.42 (N = 197)  0.574 (N = 1044)
# 39  0.286 (N = 130)  0.854 (N = 336)  0.231 (N = 197)  0.307 (N = 1044)
# 40  0.578 (N = 110)   0.68 (N = 286)  0.379 (N = 167)   0.619 (N = 884)
# 41  0.623 (N = 110)  0.545 (N = 286)   0.59 (N = 167)   0.473 (N = 884)
# 42  0.785 (N = 110)    0.5 (N = 286)  0.227 (N = 167)    0.45 (N = 884)
# 43  0.233 (N = 110)   0.83 (N = 286)  0.244 (N = 167)   0.423 (N = 884)
# 44   0.641 (N = 90)  0.819 (N = 236)  0.178 (N = 137)   0.858 (N = 724)
# 45   0.439 (N = 90)  0.491 (N = 236)  0.106 (N = 137)   0.455 (N = 724)
# 46   0.502 (N = 90)  0.396 (N = 236)  0.033 (N = 137)   0.268 (N = 724)
# 47   0.019 (N = 90)  0.669 (N = 236)   0.14 (N = 137)   0.357 (N = 724)
# 48  0.465 (N = 131)  0.585 (N = 340)  0.116 (N = 199)  0.278 (N = 1052)
# 49  0.323 (N = 131)  0.619 (N = 340)  0.118 (N = 199)  0.151 (N = 1052)
# 50  0.335 (N = 131)  0.127 (N = 340)  0.015 (N = 199)   0.04 (N = 1052)
# 51  0.585 (N = 131)  0.306 (N = 340)  0.043 (N = 199)  0.079 (N = 1052)
# 52  0.168 (N = 111)  0.967 (N = 290)  0.746 (N = 169)   0.696 (N = 892)
# 53  0.176 (N = 111)  0.937 (N = 290)  0.608 (N = 169)   0.508 (N = 892)
# 54  0.272 (N = 111)  0.777 (N = 290)  0.449 (N = 169)   0.474 (N = 892)
# 55  0.538 (N = 111)  0.923 (N = 290)  0.367 (N = 169)   0.455 (N = 892)
# 56   0.347 (N = 91)  0.832 (N = 240)  0.414 (N = 139)    0.43 (N = 732)
# 57   0.106 (N = 91)  0.866 (N = 240)   0.16 (N = 139)   0.194 (N = 732)
# 58   0.109 (N = 91)  0.821 (N = 240)  0.057 (N = 139)   0.022 (N = 732)
# 59   0.278 (N = 91)  0.854 (N = 240)  0.115 (N = 139)   0.072 (N = 732)

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
dfs_resumen_lv = ANOVA1ViaIndicadores(datadir,
                                      ligas,
                                      defin = 'lv',
                                      filtro = filtro)

outputfile = 'aleatoriedad-localvisita-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_lv, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_lv[0]
# Out:
#                   Indicador         Alemania           Espana  \
# 0   Frac. Fácil LV h1 p4 c3  0.199 (N = 109)  0.587 (N = 140)
# 1   Frac. Fácil LV h1 p5 c3  0.144 (N = 109)  0.587 (N = 140)
# 2   Frac. Fácil LV h1 p6 c3  0.478 (N = 109)  0.328 (N = 140)
# 3   Frac. Fácil LV h1 p7 c3  0.341 (N = 109)  0.366 (N = 140)
# 4   Frac. Fácil LV h1 p4 c4   0.049 (N = 75)     0.1 (N = 95)
# 5   Frac. Fácil LV h1 p5 c4   0.064 (N = 75)   0.056 (N = 95)
# 6   Frac. Fácil LV h1 p6 c4   0.032 (N = 75)   0.049 (N = 95)
# 7   Frac. Fácil LV h1 p7 c4   0.002 (N = 75)   0.051 (N = 95)
# 8   Frac. Fácil LV h1 p4 c5   0.415 (N = 51)   0.099 (N = 62)
# 9   Frac. Fácil LV h1 p5 c5   0.469 (N = 51)   0.306 (N = 62)
# 10  Frac. Fácil LV h1 p6 c5   0.642 (N = 51)   0.252 (N = 62)
# 11  Frac. Fácil LV h1 p7 c5   0.165 (N = 51)   0.165 (N = 62)
# 12  Frac. Fácil LV h2 p4 c3  0.856 (N = 136)  0.721 (N = 158)
# 13  Frac. Fácil LV h2 p5 c3  0.616 (N = 136)  0.546 (N = 158)
# 14  Frac. Fácil LV h2 p6 c3  0.521 (N = 136)  0.339 (N = 158)
# 15  Frac. Fácil LV h2 p7 c3  0.407 (N = 136)  0.384 (N = 158)
# 16  Frac. Fácil LV h2 p4 c4   0.466 (N = 93)  0.295 (N = 115)
# 17  Frac. Fácil LV h2 p5 c4   0.457 (N = 93)  0.388 (N = 115)
# 18  Frac. Fácil LV h2 p6 c4   0.761 (N = 93)   0.48 (N = 115)
# 19  Frac. Fácil LV h2 p7 c4   0.511 (N = 93)  0.346 (N = 115)
# 20  Frac. Fácil LV h2 p4 c5   0.383 (N = 58)   0.402 (N = 76)
# 21  Frac. Fácil LV h2 p5 c5   0.653 (N = 58)   0.333 (N = 76)
# 22  Frac. Fácil LV h2 p6 c5   0.764 (N = 58)   0.674 (N = 76)
# 23  Frac. Fácil LV h2 p7 c5   0.652 (N = 58)   0.513 (N = 76)
# 24  Frac. Fácil LV h3 p4 c3  0.224 (N = 134)  0.369 (N = 171)
# 25  Frac. Fácil LV h3 p5 c3  0.173 (N = 134)  0.202 (N = 171)
# 26  Frac. Fácil LV h3 p6 c3  0.499 (N = 134)  0.279 (N = 171)
# 27  Frac. Fácil LV h3 p7 c3  0.507 (N = 134)  0.024 (N = 171)
# 28  Frac. Fácil LV h3 p4 c4   0.193 (N = 98)  0.824 (N = 124)
# 29  Frac. Fácil LV h3 p5 c4   0.583 (N = 98)  0.721 (N = 124)
# 30  Frac. Fácil LV h3 p6 c4   0.519 (N = 98)  0.778 (N = 124)
# 31  Frac. Fácil LV h3 p7 c4   0.642 (N = 98)  0.575 (N = 124)
# 32  Frac. Fácil LV h3 p4 c5   0.229 (N = 64)   0.857 (N = 88)
# 33  Frac. Fácil LV h3 p5 c5   0.444 (N = 64)   0.829 (N = 88)
# 34  Frac. Fácil LV h3 p6 c5   0.509 (N = 64)   0.646 (N = 88)
# 35  Frac. Fácil LV h3 p7 c5   0.661 (N = 64)   0.207 (N = 88)
# 36  Frac. Fácil LV h4 p4 c3  0.333 (N = 139)  0.289 (N = 180)
# 37  Frac. Fácil LV h4 p5 c3  0.686 (N = 139)  0.096 (N = 180)
# 38  Frac. Fácil LV h4 p6 c3  0.692 (N = 139)  0.034 (N = 180)
# 39  Frac. Fácil LV h4 p7 c3  0.736 (N = 139)   0.08 (N = 180)
# 40  Frac. Fácil LV h4 p4 c4  0.699 (N = 102)  0.401 (N = 139)
# 41  Frac. Fácil LV h4 p5 c4  0.895 (N = 102)  0.306 (N = 139)
# 42  Frac. Fácil LV h4 p6 c4   0.86 (N = 102)  0.106 (N = 139)
# 43  Frac. Fácil LV h4 p7 c4  0.773 (N = 102)  0.374 (N = 139)
# 44  Frac. Fácil LV h4 p4 c5   0.783 (N = 62)   0.814 (N = 95)
# 45  Frac. Fácil LV h4 p5 c5   0.868 (N = 62)   0.391 (N = 95)
# 46  Frac. Fácil LV h4 p6 c5   0.822 (N = 62)   0.259 (N = 95)
# 47  Frac. Fácil LV h4 p7 c5    0.93 (N = 62)    0.12 (N = 95)
# 48  Frac. Fácil LV h5 p4 c3  0.556 (N = 141)  0.668 (N = 177)
# 49  Frac. Fácil LV h5 p5 c3  0.303 (N = 141)  0.385 (N = 177)
# 50  Frac. Fácil LV h5 p6 c3  0.621 (N = 141)  0.313 (N = 177)
# 51  Frac. Fácil LV h5 p7 c3  0.726 (N = 141)  0.248 (N = 177)
# 52  Frac. Fácil LV h5 p4 c4  0.743 (N = 101)  0.501 (N = 136)
# 53  Frac. Fácil LV h5 p5 c4  0.842 (N = 101)  0.177 (N = 136)
# 54  Frac. Fácil LV h5 p6 c4  0.831 (N = 101)  0.118 (N = 136)
# 55  Frac. Fácil LV h5 p7 c4  0.985 (N = 101)  0.186 (N = 136)
# 56  Frac. Fácil LV h5 p4 c5   0.401 (N = 66)  0.541 (N = 102)
# 57  Frac. Fácil LV h5 p5 c5   0.449 (N = 66)  0.176 (N = 102)
# 58  Frac. Fácil LV h5 p6 c5   0.334 (N = 66)  0.178 (N = 102)
# 59  Frac. Fácil LV h5 p7 c5   0.409 (N = 66)  0.124 (N = 102)
#
#             Francia       Inglaterra           Italia              All
# 0    0.196 (N = 89)  0.479 (N = 234)  0.396 (N = 134)  0.283 (N = 706)
# 1    0.149 (N = 89)  0.315 (N = 234)  0.727 (N = 134)  0.276 (N = 706)
# 2    0.169 (N = 89)  0.417 (N = 234)  0.658 (N = 134)   0.41 (N = 706)
# 3    0.222 (N = 89)  0.774 (N = 234)  0.622 (N = 134)  0.525 (N = 706)
# 4    0.321 (N = 58)  0.843 (N = 165)   0.279 (N = 88)   0.06 (N = 481)
# 5    0.213 (N = 58)  0.716 (N = 165)   0.507 (N = 88)  0.063 (N = 481)
# 6    0.306 (N = 58)  0.594 (N = 165)   0.378 (N = 88)  0.049 (N = 481)
# 7    0.271 (N = 58)  0.733 (N = 165)   0.624 (N = 88)  0.043 (N = 481)
# 8    0.329 (N = 40)  0.768 (N = 103)   0.495 (N = 56)   0.19 (N = 312)
# 9     0.19 (N = 40)  0.601 (N = 103)   0.445 (N = 56)  0.167 (N = 312)
# 10   0.341 (N = 40)  0.599 (N = 103)   0.642 (N = 56)   0.44 (N = 312)
# 11   0.328 (N = 40)  0.941 (N = 103)   0.868 (N = 56)  0.542 (N = 312)
# 12   0.883 (N = 99)  0.995 (N = 272)  0.362 (N = 151)  0.972 (N = 816)
# 13   0.773 (N = 99)  0.982 (N = 272)    0.3 (N = 151)  0.799 (N = 816)
# 14   0.787 (N = 99)  0.927 (N = 272)  0.499 (N = 151)  0.701 (N = 816)
# 15   0.267 (N = 99)  0.945 (N = 272)   0.37 (N = 151)  0.388 (N = 816)
# 16   0.557 (N = 71)  0.286 (N = 200)  0.782 (N = 112)  0.159 (N = 591)
# 17    0.43 (N = 71)  0.202 (N = 200)  0.404 (N = 112)  0.063 (N = 591)
# 18   0.664 (N = 71)  0.124 (N = 200)  0.511 (N = 112)  0.272 (N = 591)
# 19   0.185 (N = 71)  0.287 (N = 200)  0.761 (N = 112)  0.155 (N = 591)
# 20    0.91 (N = 48)  0.621 (N = 143)   0.974 (N = 81)  0.656 (N = 406)
# 21   0.904 (N = 48)  0.324 (N = 143)   0.694 (N = 81)  0.547 (N = 406)
# 22   0.934 (N = 48)  0.497 (N = 143)   0.746 (N = 81)  0.871 (N = 406)
# 23   0.441 (N = 48)  0.571 (N = 143)   0.664 (N = 81)  0.595 (N = 406)
# 24  0.744 (N = 105)  0.255 (N = 280)  0.512 (N = 159)  0.114 (N = 849)
# 25  0.495 (N = 105)  0.437 (N = 280)  0.179 (N = 159)  0.042 (N = 849)
# 26  0.473 (N = 105)  0.572 (N = 280)  0.266 (N = 159)  0.158 (N = 849)
# 27  0.032 (N = 105)  0.524 (N = 280)  0.234 (N = 159)   0.02 (N = 849)
# 28   0.907 (N = 75)  0.855 (N = 217)  0.633 (N = 118)  0.764 (N = 632)
# 29   0.656 (N = 75)  0.899 (N = 217)  0.617 (N = 118)  0.884 (N = 632)
# 30   0.508 (N = 75)  0.868 (N = 217)  0.743 (N = 118)   0.86 (N = 632)
# 31   0.018 (N = 75)  0.803 (N = 217)  0.567 (N = 118)   0.54 (N = 632)
# 32    0.67 (N = 58)  0.871 (N = 156)   0.946 (N = 81)  0.925 (N = 447)
# 33   0.478 (N = 58)  0.975 (N = 156)    0.87 (N = 81)  0.963 (N = 447)
# 34   0.595 (N = 58)  0.967 (N = 156)   0.958 (N = 81)  0.965 (N = 447)
# 35    0.08 (N = 58)  0.959 (N = 156)   0.813 (N = 81)   0.72 (N = 447)
# 36  0.669 (N = 106)  0.054 (N = 279)  0.637 (N = 165)  0.129 (N = 869)
# 37  0.414 (N = 106)  0.099 (N = 279)  0.136 (N = 165)  0.057 (N = 869)
# 38  0.376 (N = 106)    0.3 (N = 279)  0.097 (N = 165)  0.048 (N = 869)
# 39  0.089 (N = 106)  0.387 (N = 279)  0.378 (N = 165)  0.103 (N = 869)
# 40   0.937 (N = 83)  0.382 (N = 220)  0.697 (N = 122)  0.533 (N = 666)
# 41   0.753 (N = 83)  0.585 (N = 220)  0.703 (N = 122)  0.767 (N = 666)
# 42   0.663 (N = 83)   0.54 (N = 220)  0.785 (N = 122)  0.615 (N = 666)
# 43   0.433 (N = 83)  0.359 (N = 220)  0.746 (N = 122)  0.585 (N = 666)
# 44   0.858 (N = 58)  0.194 (N = 157)   0.972 (N = 80)  0.923 (N = 452)
# 45   0.699 (N = 58)  0.417 (N = 157)   0.992 (N = 80)   0.93 (N = 452)
# 46   0.749 (N = 58)  0.197 (N = 157)   0.995 (N = 80)  0.817 (N = 452)
# 47   0.579 (N = 58)   0.14 (N = 157)   0.977 (N = 80)  0.719 (N = 452)
# 48  0.617 (N = 109)  0.356 (N = 288)  0.746 (N = 169)  0.705 (N = 884)
# 49  0.245 (N = 109)  0.791 (N = 288)  0.556 (N = 169)  0.485 (N = 884)
# 50  0.372 (N = 109)  0.901 (N = 288)  0.472 (N = 169)  0.711 (N = 884)
# 51  0.233 (N = 109)  0.905 (N = 288)  0.526 (N = 169)  0.745 (N = 884)
# 52   0.972 (N = 83)  0.356 (N = 225)  0.854 (N = 124)  0.822 (N = 669)
# 53   0.871 (N = 83)  0.459 (N = 225)  0.508 (N = 124)   0.62 (N = 669)
# 54   0.814 (N = 83)  0.679 (N = 225)  0.719 (N = 124)  0.714 (N = 669)
# 55   0.599 (N = 83)  0.566 (N = 225)  0.929 (N = 124)  0.913 (N = 669)
# 56    0.99 (N = 58)  0.267 (N = 159)   0.785 (N = 89)  0.752 (N = 474)
# 57   0.899 (N = 58)  0.582 (N = 159)   0.909 (N = 89)  0.834 (N = 474)
# 58   0.807 (N = 58)  0.742 (N = 159)   0.764 (N = 89)   0.69 (N = 474)
# 59   0.412 (N = 58)  0.668 (N = 159)   0.931 (N = 89)  0.639 (N = 474)

# %%
dfs_resumen_lv[1]
# Out:
#                     Indicador         Alemania           Espana  \
# 0   Frac. Difícil LV h1 p4 c3  0.275 (N = 109)  0.564 (N = 140)
# 1   Frac. Difícil LV h1 p5 c3  0.682 (N = 109)  0.187 (N = 140)
# 2   Frac. Difícil LV h1 p6 c3  0.938 (N = 109)  0.286 (N = 140)
# 3   Frac. Difícil LV h1 p7 c3  0.842 (N = 109)  0.206 (N = 140)
# 4   Frac. Difícil LV h1 p4 c4   0.848 (N = 75)   0.266 (N = 95)
# 5   Frac. Difícil LV h1 p5 c4    0.72 (N = 75)   0.332 (N = 95)
# 6   Frac. Difícil LV h1 p6 c4   0.898 (N = 75)   0.414 (N = 95)
# 7   Frac. Difícil LV h1 p7 c4   0.861 (N = 75)   0.318 (N = 95)
# 8   Frac. Difícil LV h1 p4 c5   0.801 (N = 51)     0.8 (N = 62)
# 9   Frac. Difícil LV h1 p5 c5   0.876 (N = 51)   0.674 (N = 62)
# 10  Frac. Difícil LV h1 p6 c5   0.998 (N = 51)   0.585 (N = 62)
# 11  Frac. Difícil LV h1 p7 c5   0.991 (N = 51)   0.384 (N = 62)
# 12  Frac. Difícil LV h2 p4 c3  0.804 (N = 136)  0.762 (N = 158)
# 13  Frac. Difícil LV h2 p5 c3  0.234 (N = 136)  0.346 (N = 158)
# 14  Frac. Difícil LV h2 p6 c3  0.394 (N = 136)   0.56 (N = 158)
# 15  Frac. Difícil LV h2 p7 c3   0.26 (N = 136)  0.707 (N = 158)
# 16  Frac. Difícil LV h2 p4 c4   0.008 (N = 93)  0.825 (N = 115)
# 17  Frac. Difícil LV h2 p5 c4   0.097 (N = 93)  0.705 (N = 115)
# 18  Frac. Difícil LV h2 p6 c4   0.243 (N = 93)  0.439 (N = 115)
# 19  Frac. Difícil LV h2 p7 c4   0.406 (N = 93)  0.384 (N = 115)
# 20  Frac. Difícil LV h2 p4 c5    0.49 (N = 58)   0.129 (N = 76)
# 21  Frac. Difícil LV h2 p5 c5   0.967 (N = 58)   0.047 (N = 76)
# 22  Frac. Difícil LV h2 p6 c5   0.921 (N = 58)   0.086 (N = 76)
# 23  Frac. Difícil LV h2 p7 c5   0.688 (N = 58)   0.081 (N = 76)
# 24  Frac. Difícil LV h3 p4 c3  0.922 (N = 134)  0.611 (N = 171)
# 25  Frac. Difícil LV h3 p5 c3  0.962 (N = 134)  0.275 (N = 171)
# 26  Frac. Difícil LV h3 p6 c3  0.968 (N = 134)  0.656 (N = 171)
# 27  Frac. Difícil LV h3 p7 c3  0.992 (N = 134)  0.661 (N = 171)
# 28  Frac. Difícil LV h3 p4 c4   0.688 (N = 98)  0.673 (N = 124)
# 29  Frac. Difícil LV h3 p5 c4   0.792 (N = 98)  0.235 (N = 124)
# 30  Frac. Difícil LV h3 p6 c4   0.718 (N = 98)   0.11 (N = 124)
# 31  Frac. Difícil LV h3 p7 c4   0.662 (N = 98)   0.12 (N = 124)
# 32  Frac. Difícil LV h3 p4 c5   0.116 (N = 64)   0.594 (N = 88)
# 33  Frac. Difícil LV h3 p5 c5   0.075 (N = 64)   0.286 (N = 88)
# 34  Frac. Difícil LV h3 p6 c5   0.089 (N = 64)   0.031 (N = 88)
# 35  Frac. Difícil LV h3 p7 c5   0.172 (N = 64)   0.042 (N = 88)
# 36  Frac. Difícil LV h4 p4 c3  0.378 (N = 139)  0.055 (N = 180)
# 37  Frac. Difícil LV h4 p5 c3  0.207 (N = 139)  0.004 (N = 180)
# 38  Frac. Difícil LV h4 p6 c3  0.125 (N = 139)  0.018 (N = 180)
# 39  Frac. Difícil LV h4 p7 c3  0.165 (N = 139)  0.073 (N = 180)
# 40  Frac. Difícil LV h4 p4 c4  0.553 (N = 102)  0.066 (N = 139)
# 41  Frac. Difícil LV h4 p5 c4  0.101 (N = 102)  0.026 (N = 139)
# 42  Frac. Difícil LV h4 p6 c4  0.173 (N = 102)  0.005 (N = 139)
# 43  Frac. Difícil LV h4 p7 c4  0.468 (N = 102)  0.015 (N = 139)
# 44  Frac. Difícil LV h4 p4 c5   0.522 (N = 62)   0.071 (N = 95)
# 45  Frac. Difícil LV h4 p5 c5   0.425 (N = 62)   0.195 (N = 95)
# 46  Frac. Difícil LV h4 p6 c5   0.549 (N = 62)   0.128 (N = 95)
# 47  Frac. Difícil LV h4 p7 c5   0.801 (N = 62)   0.041 (N = 95)
# 48  Frac. Difícil LV h5 p4 c3  0.928 (N = 141)  0.286 (N = 177)
# 49  Frac. Difícil LV h5 p5 c3  0.808 (N = 141)  0.006 (N = 177)
# 50  Frac. Difícil LV h5 p6 c3  0.446 (N = 141)  0.067 (N = 177)
# 51  Frac. Difícil LV h5 p7 c3  0.184 (N = 141)  0.031 (N = 177)
# 52  Frac. Difícil LV h5 p4 c4  0.779 (N = 101)  0.106 (N = 136)
# 53  Frac. Difícil LV h5 p5 c4  0.868 (N = 101)  0.028 (N = 136)
# 54  Frac. Difícil LV h5 p6 c4  0.528 (N = 101)  0.046 (N = 136)
# 55  Frac. Difícil LV h5 p7 c4  0.197 (N = 101)  0.006 (N = 136)
# 56  Frac. Difícil LV h5 p4 c5   0.932 (N = 66)  0.038 (N = 102)
# 57  Frac. Difícil LV h5 p5 c5   0.771 (N = 66)  0.149 (N = 102)
# 58  Frac. Difícil LV h5 p6 c5   0.843 (N = 66)  0.225 (N = 102)
# 59  Frac. Difícil LV h5 p7 c5    0.75 (N = 66)  0.061 (N = 102)
#
#             Francia       Inglaterra           Italia              All
# 0    0.558 (N = 89)  0.398 (N = 234)  0.837 (N = 134)   0.43 (N = 706)
# 1    0.626 (N = 89)  0.112 (N = 234)  0.396 (N = 134)  0.135 (N = 706)
# 2    0.687 (N = 89)  0.165 (N = 234)  0.472 (N = 134)  0.457 (N = 706)
# 3     0.56 (N = 89)  0.276 (N = 234)  0.706 (N = 134)  0.477 (N = 706)
# 4    0.414 (N = 58)  0.184 (N = 165)   0.526 (N = 88)  0.162 (N = 481)
# 5    0.233 (N = 58)  0.165 (N = 165)   0.379 (N = 88)  0.081 (N = 481)
# 6    0.273 (N = 58)  0.355 (N = 165)    0.73 (N = 88)  0.401 (N = 481)
# 7    0.263 (N = 58)  0.532 (N = 165)   0.909 (N = 88)  0.438 (N = 481)
# 8    0.316 (N = 40)   0.01 (N = 103)   0.345 (N = 56)  0.156 (N = 312)
# 9    0.068 (N = 40)  0.021 (N = 103)   0.325 (N = 56)   0.08 (N = 312)
# 10    0.16 (N = 40)  0.016 (N = 103)   0.583 (N = 56)  0.242 (N = 312)
# 11   0.259 (N = 40)  0.141 (N = 103)   0.488 (N = 56)  0.287 (N = 312)
# 12   0.516 (N = 99)  0.848 (N = 272)  0.179 (N = 151)  0.781 (N = 816)
# 13   0.647 (N = 99)  0.553 (N = 272)  0.028 (N = 151)   0.16 (N = 816)
# 14   0.687 (N = 99)  0.388 (N = 272)  0.121 (N = 151)  0.282 (N = 816)
# 15   0.808 (N = 99)  0.586 (N = 272)  0.121 (N = 151)  0.387 (N = 816)
# 16   0.841 (N = 71)  0.821 (N = 200)  0.547 (N = 112)   0.65 (N = 591)
# 17   0.856 (N = 71)  0.413 (N = 200)   0.11 (N = 112)  0.302 (N = 591)
# 18   0.941 (N = 71)   0.14 (N = 200)  0.729 (N = 112)  0.422 (N = 591)
# 19   0.814 (N = 71)  0.501 (N = 200)  0.852 (N = 112)   0.47 (N = 591)
# 20   0.751 (N = 48)  0.459 (N = 143)   0.582 (N = 81)  0.458 (N = 406)
# 21   0.825 (N = 48)  0.472 (N = 143)   0.136 (N = 81)  0.414 (N = 406)
# 22   0.839 (N = 48)  0.352 (N = 143)   0.545 (N = 81)  0.478 (N = 406)
# 23   0.428 (N = 48)  0.205 (N = 143)   0.761 (N = 81)  0.119 (N = 406)
# 24  0.906 (N = 105)  0.613 (N = 280)  0.182 (N = 159)  0.789 (N = 849)
# 25  0.873 (N = 105)  0.195 (N = 280)  0.192 (N = 159)   0.46 (N = 849)
# 26  0.714 (N = 105)  0.207 (N = 280)  0.396 (N = 159)  0.622 (N = 849)
# 27  0.534 (N = 105)  0.395 (N = 280)  0.278 (N = 159)  0.664 (N = 849)
# 28   0.654 (N = 75)  0.453 (N = 217)  0.057 (N = 118)  0.376 (N = 632)
# 29    0.61 (N = 75)  0.176 (N = 217)  0.021 (N = 118)  0.072 (N = 632)
# 30   0.474 (N = 75)  0.237 (N = 217)   0.22 (N = 118)  0.107 (N = 632)
# 31    0.12 (N = 75)  0.533 (N = 217)  0.555 (N = 118)  0.122 (N = 632)
# 32   0.868 (N = 58)  0.147 (N = 156)   0.444 (N = 81)  0.322 (N = 447)
# 33   0.809 (N = 58)  0.491 (N = 156)    0.03 (N = 81)  0.142 (N = 447)
# 34    0.92 (N = 58)  0.339 (N = 156)   0.238 (N = 81)   0.06 (N = 447)
# 35   0.321 (N = 58)   0.36 (N = 156)   0.405 (N = 81)  0.018 (N = 447)
# 36  0.924 (N = 106)  0.867 (N = 279)  0.092 (N = 165)  0.288 (N = 869)
# 37  0.645 (N = 106)  0.549 (N = 279)  0.052 (N = 165)  0.015 (N = 869)
# 38  0.684 (N = 106)  0.622 (N = 279)  0.405 (N = 165)  0.069 (N = 869)
# 39  0.689 (N = 106)  0.916 (N = 279)  0.578 (N = 165)  0.254 (N = 869)
# 40   0.939 (N = 83)  0.362 (N = 220)  0.075 (N = 122)  0.191 (N = 666)
# 41   0.388 (N = 83)  0.475 (N = 220)  0.011 (N = 122)  0.008 (N = 666)
# 42   0.316 (N = 83)  0.378 (N = 220)  0.228 (N = 122)  0.008 (N = 666)
# 43   0.224 (N = 83)  0.565 (N = 220)  0.413 (N = 122)  0.048 (N = 666)
# 44    0.77 (N = 58)  0.201 (N = 157)   0.732 (N = 80)   0.32 (N = 452)
# 45   0.438 (N = 58)  0.502 (N = 157)   0.148 (N = 80)  0.207 (N = 452)
# 46   0.172 (N = 58)  0.514 (N = 157)    0.91 (N = 80)  0.247 (N = 452)
# 47   0.507 (N = 58)  0.674 (N = 157)   0.953 (N = 80)  0.323 (N = 452)
# 48  0.837 (N = 109)  0.285 (N = 288)  0.079 (N = 169)  0.415 (N = 884)
# 49  0.488 (N = 109)  0.135 (N = 288)  0.122 (N = 169)  0.045 (N = 884)
# 50  0.339 (N = 109)  0.253 (N = 288)  0.411 (N = 169)  0.138 (N = 884)
# 51   0.47 (N = 109)  0.334 (N = 288)  0.354 (N = 169)  0.063 (N = 884)
# 52   0.623 (N = 83)  0.961 (N = 225)  0.154 (N = 124)  0.685 (N = 669)
# 53   0.314 (N = 83)  0.879 (N = 225)   0.01 (N = 124)  0.129 (N = 669)
# 54   0.554 (N = 83)  0.892 (N = 225)  0.058 (N = 124)  0.248 (N = 669)
# 55   0.959 (N = 83)  0.814 (N = 225)  0.457 (N = 124)   0.27 (N = 669)
# 56   0.876 (N = 58)  0.104 (N = 159)   0.901 (N = 89)  0.506 (N = 474)
# 57   0.554 (N = 58)  0.046 (N = 159)   0.191 (N = 89)  0.114 (N = 474)
# 58    0.31 (N = 58)  0.307 (N = 159)   0.778 (N = 89)  0.577 (N = 474)
# 59   0.902 (N = 58)  0.668 (N = 159)   0.755 (N = 89)  0.707 (N = 474)
