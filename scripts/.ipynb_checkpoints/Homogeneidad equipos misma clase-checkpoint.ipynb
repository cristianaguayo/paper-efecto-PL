# %% [markdown]
# # Preanálisis

# %%
# Librerías de siempre
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import datetime
from time import time
import statsmodels.api as sm
import itertools
from random import shuffle
from statsmodels.formula.api import ols
from scipy import stats

# %%
def leer_efectos(datadir,
                 ligas):
    dict_replaces = {'_mean': '',
                     '_':' ',
                     'dificil':'Difícil',
                     'dificl' : 'Difícil',
                     'facil': 'Fácil',
                     'regular' : 'Regular',
                     'prom': 'Promedio',
                     'posicion': 'Posición',
                     'primer' : 'Primer',
                     'ronda' : 'Ronda',
                     'gral': 'Gral.',
                     'categoria': 'Categoría',
                     'local': 'Local',
                     'visita': 'Visita',
                     'general' : 'Gral.',
                     'corr' : 'Correg.',
                     'perc' : '%',
                     ' p': ' Primeros ',
                     ' c': ' Corte ',
                     'lv' : 'LV',
                     'elo' : 'ELO',
                     'Primer Fácil C': 'Primer Fácil LV C',
                     'Primer Difícil C': 'Primer Difícil LV C'}
    count = 0
    for j in range(len(ligas)):
        print("Leyendo: %s                             " % ligas[j], end = '\t\r')
        df_efecto = pd.read_excel(os.path.join(datadir, ligas[j] + '.xlsx'),
                                  sheet_name = ligas[j])
        cols_categoria = [i for i in df_efecto.columns if 'categoria' in i]
        for col in cols_categoria:
            df_efecto[col] = df_efecto[col].astype('category')
            df_efecto[col].cat.reorder_categories(['regular', 'facil','dificil'], inplace = True)
        if count < 1:
            lista_columnas = [i for i in df_efecto.columns.tolist() if i not in ['equipo','position','Torneo','Pais']
                             and '.' not in i]
#             lista_columnas = [i for i in df_efecto.columns.tolist() if 'perc' in i 
#                               and '.' not in i]
            variables = lista_columnas
            for key, value in dict_replaces.items():
                variables = [i.replace(key,value) for i in variables]
            dict_columns = dict(zip(variables, lista_columnas))
            dfs_efecto = []
            count = count + 1
        dfs_efecto.append(df_efecto)
    return dfs_efecto, variables, dict_columns

# %%
datadir = os.path.join(os.path.pardir,'datos','regresiones')
ligas = ['Alemania','Espana','Francia','Inglaterra','Italia']
# ligas = ['inglaterra-upgrade']
# dfs_efecto, variables, dict_columns = leer_efectos(datadir,
#                                                    ligas)

# %%
def significancia_variables(mod,var,replace_spaces = True, std_err = True):
    coef = "%.3f" % (np.round(mod.params[var], decimals = 3))
    se = "%.3f" % (np.round(mod.bse[var], decimals = 3))
    if mod.params[var] > 0:
        output = '~' + str(coef)                 
    else:
        output = str(coef)
    if std_err:
        output = output + ' (' + str(se) + ')'   
    pval = np.round(mod.pvalues[var], 3)
    if pval < 0.01:
        output = output + '***'
    elif pval < 0.05 and pval >= 0.01:
        output = output + '**~'
    elif pval < 0.1 and pval >=0.05:
        output = output + '*~~'
    else:
        output = output + '~~~'
    if replace_spaces:
        output = output.replace("~"," ")
    return output

# %% [markdown]
# ## ANOVA de 1 vía para posiciones
#
# La idea de esto es ver si hay diferencias en términos de posición entre los equipos que son asignados como fáciles o difíciles

# %%
def anova_1via_categorias(datadir,ligas):
    dfs_efecto, variables, dict_columns = leer_efectos(datadir = datadir,
                                                       ligas = ligas)
    reverse_dict = inv_map = {v: k for k, v in dict_columns.items()}
    ys = [i for i in dfs_efecto[0].columns.tolist() if 'position' in i or 'points' in i]
    dfs_resumen = []
    for y in ys:
#         print(y)
        formula = '%s ~ C(equipo)' % y
        data = []
        for i in range(len(ligas)):
            resultados = []
            liga = ligas[i]
            df_efecto = dfs_efecto[i]
            if i < 1:
                cols_categorias = [j for j in df_efecto.columns if 'categoria' in j]
                columna_var = []
                for col in cols_categorias:
                    for cat in ['facil','dificil']:
                        columna_var.append('%s %s' % (reverse_dict[col], cat))  
                data.append(columna_var)
            for col in cols_categorias:
                for cat in ['facil','dificil']:
                    model = ols(formula, data = df_efecto[df_efecto[col] == cat]).fit()
                    aov_table = sm.stats.anova_lm(model, typ=2)
                    resultados.append(np.round(aov_table['PR(>F)'][0], decimals = 3))
            data.append(resultados)
        colnames = ['Categoria'] + ligas
        data_dict = dict(zip(colnames, data))
        df_resumen = pd.DataFrame(data_dict)
        dfs_resumen.append(df_resumen)
    return dfs_resumen

# %%
dfs_resumen = anova_1via_categorias(datadir,ligas)
# Out:
# Leyendo: Italia

# %%
#Posicion final
dfs_resumen[0]
# Out:
#                               Categoria  Alemania  Espana  Francia  \
# 0           Categoría ELO Corte 3 facil     0.125   0.191    0.370
# 1         Categoría ELO Corte 3 dificil     0.003   0.000    0.056
# 2           Categoría ELO Corte 4 facil     0.189   0.198    0.278
# 3         Categoría ELO Corte 4 dificil     0.004   0.000    0.013
# 4           Categoría ELO Corte 5 facil     0.123   0.159    0.342
# 5         Categoría ELO Corte 5 dificil     0.000   0.000    0.000
# 6      Categoría Gral. h1 Corte 3 facil     0.169   0.048    0.323
# 7    Categoría Gral. h1 Corte 3 dificil     0.011   0.000    0.006
# 8      Categoría Local h1 Corte 3 facil     0.292   0.037    0.007
# 9    Categoría Local h1 Corte 3 dificil     0.000   0.000    0.000
# 10    Categoría Visita h1 Corte 3 facil     0.024   0.037    0.052
# 11  Categoría Visita h1 Corte 3 dificil     0.003   0.000    0.003
# 12     Categoría Gral. h1 Corte 4 facil     0.084   0.029    0.139
# 13   Categoría Gral. h1 Corte 4 dificil     0.003   0.000    0.002
# 14     Categoría Local h1 Corte 4 facil     0.218   0.132    0.081
# 15   Categoría Local h1 Corte 4 dificil     0.000   0.000    0.001
# 16    Categoría Visita h1 Corte 4 facil     0.007   0.050    0.117
# 17  Categoría Visita h1 Corte 4 dificil     0.000   0.000    0.000
# 18     Categoría Gral. h1 Corte 5 facil     0.056   0.011    0.036
# 19   Categoría Gral. h1 Corte 5 dificil     0.000   0.000    0.000
# 20     Categoría Local h1 Corte 5 facil     0.136   0.010    0.074
# 21   Categoría Local h1 Corte 5 dificil     0.000   0.000    0.000
# 22    Categoría Visita h1 Corte 5 facil     0.013   0.004    0.088
# 23  Categoría Visita h1 Corte 5 dificil     0.000   0.000    0.001
# 24     Categoría Gral. h2 Corte 3 facil     0.288   0.256    0.057
# 25   Categoría Gral. h2 Corte 3 dificil     0.000   0.000    0.002
# 26     Categoría Local h2 Corte 3 facil     0.156   0.137    0.025
# 27   Categoría Local h2 Corte 3 dificil     0.000   0.000    0.001
# 28    Categoría Visita h2 Corte 3 facil     0.167   0.185    0.071
# 29  Categoría Visita h2 Corte 3 dificil     0.000   0.000    0.006
# ..                                  ...       ...     ...      ...
# 66     Categoría Gral. h4 Corte 4 facil     0.000   0.000    0.000
# 67   Categoría Gral. h4 Corte 4 dificil     0.040   0.000    0.400
# 68     Categoría Local h4 Corte 4 facil     0.235   0.160    0.016
# 69   Categoría Local h4 Corte 4 dificil     0.000   0.000    0.000
# 70    Categoría Visita h4 Corte 4 facil     0.126   0.068    0.169
# 71  Categoría Visita h4 Corte 4 dificil     0.000   0.000    0.000
# 72     Categoría Gral. h4 Corte 5 facil     0.000   0.000    0.000
# 73   Categoría Gral. h4 Corte 5 dificil     0.008   0.000    0.494
# 74     Categoría Local h4 Corte 5 facil     0.105   0.155    0.006
# 75   Categoría Local h4 Corte 5 dificil     0.000   0.000    0.000
# 76    Categoría Visita h4 Corte 5 facil     0.092   0.176    0.056
# 77  Categoría Visita h4 Corte 5 dificil     0.000   0.000    0.002
# 78     Categoría Gral. h5 Corte 3 facil     0.018   0.076    0.117
# 79   Categoría Gral. h5 Corte 3 dificil     0.403   0.058    0.520
# 80     Categoría Local h5 Corte 3 facil     0.119   0.030    0.122
# 81   Categoría Local h5 Corte 3 dificil     0.003   0.000    0.000
# 82    Categoría Visita h5 Corte 3 facil     0.148   0.130    0.173
# 83  Categoría Visita h5 Corte 3 dificil     0.002   0.000    0.007
# 84     Categoría Gral. h5 Corte 4 facil     0.000   0.000    0.112
# 85   Categoría Gral. h5 Corte 4 dificil     0.260   0.002    0.492
# 86     Categoría Local h5 Corte 4 facil     0.164   0.007    0.057
# 87   Categoría Local h5 Corte 4 dificil     0.000   0.000    0.000
# 88    Categoría Visita h5 Corte 4 facil     0.108   0.084    0.131
# 89  Categoría Visita h5 Corte 4 dificil     0.000   0.000    0.046
# 90     Categoría Gral. h5 Corte 5 facil     0.000   0.000    0.049
# 91   Categoría Gral. h5 Corte 5 dificil     0.434   0.000    0.600
# 92     Categoría Local h5 Corte 5 facil     0.221   0.002    0.010
# 93   Categoría Local h5 Corte 5 dificil     0.000   0.000    0.000
# 94    Categoría Visita h5 Corte 5 facil     0.084   0.015    0.153
# 95  Categoría Visita h5 Corte 5 dificil     0.000   0.000    0.070
#
#     Inglaterra  Italia
# 0        0.337   0.686
# 1        0.000   0.112
# 2        0.067   0.717
# 3        0.000   0.002
# 4        0.056   0.388
# 5        0.000   0.000
# 6        0.646   0.485
# 7        0.000   0.071
# 8        0.071   0.051
# 9        0.000   0.000
# 10       0.046   0.329
# 11       0.000   0.004
# 12       0.617   0.310
# 13       0.000   0.000
# 14       0.149   0.065
# 15       0.000   0.000
# 16       0.023   0.331
# 17       0.000   0.000
# 18       0.307   0.154
# 19       0.000   0.000
# 20       0.014   0.018
# 21       0.000   0.000
# 22       0.071   0.144
# 23       0.000   0.000
# 24       0.386   0.331
# 25       0.000   0.424
# 26       0.199   0.239
# 27       0.000   0.005
# 28       0.058   0.034
# 29       0.002   0.138
# ..         ...     ...
# 66       0.000   0.000
# 67       0.017   0.008
# 68       0.239   0.136
# 69       0.000   0.000
# 70       0.036   0.176
# 71       0.000   0.001
# 72       0.000   0.000
# 73       0.003   0.003
# 74       0.037   0.010
# 75       0.000   0.000
# 76       0.041   0.141
# 77       0.000   0.000
# 78       0.010   0.055
# 79       0.439   0.170
# 80       0.375   0.015
# 81       0.000   0.158
# 82       0.155   0.382
# 83       0.000   0.390
# 84       0.001   0.004
# 85       0.319   0.083
# 86       0.092   0.015
# 87       0.000   0.000
# 88       0.209   0.413
# 89       0.000   0.001
# 90       0.000   0.000
# 91       0.032   0.001
# 92       0.076   0.010
# 93       0.000   0.000
# 94       0.036   0.119
# 95       0.000   0.000
#
# [96 rows x 6 columns]
