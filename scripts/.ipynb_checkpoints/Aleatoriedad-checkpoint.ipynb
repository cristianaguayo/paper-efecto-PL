# %% [markdown]
# # Aleatoriedad en asignación de dificultades

# %%
import numpy as np
import pandas as pd
import os
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy import stats

# %%
def LeerBasesRegresion(datadir, ligas, column_condition):
    dfs = []
    # Primer caso:
    archivo = ligas[0] + '.xlsx'
    df = pd.read_excel(os.path.join(datadir, archivo))
    columns_filter = [i for i in df.columns if column_condition(i)]
    columns_to_keep = ['equipo','Torneo'] + columns_filter
    df = df[columns_to_keep]
    dfs.append(df)
    try:
        for liga in ligas[1:]:
            archivo = liga + '.xlsx'
            df = pd.read_excel(os.path.join(datadir, archivo))
            columns_to_keep = ['equipo','Torneo'] + [i for i in df.columns if column_condition(i)]
            df = df[columns_to_keep]
            dfs.append(df)
    except:
        pass
    return dfs, columns_filter

# %%
# def FiltrarRegulares(df, defin, c, h):
#     if defin == 'elo':
#         col = 'categoria_%s_c%s' % (defin, c)
#         df_filter = df[df[col] == 'regular']
#     elif defin == 'general':
#         col = 'categoria_%s_h%s_c%s' % (defin, h, c)
#         df_filter = df[df[col] == 'regular']
#     else:
#         col1 = 'categoria_local_h%s_c%s' % (h,c)
#         col2 = 'categoria_visita_h%s_c%s' % (h,c)
#         df_filter = df[(df[col1] == 'regular') & 
#                        (df[col2] == 'regular')]
#     return df_filter
def FiltrarRegulares(df, defin, c, h, filt):
    cats = ['facil','regular','dificil']
    if filt not in  ['regular', ""]:
        cats = [c for c in cats if c != filt]
    elif filt == 'regular':
        cats = [filt]
    else:
        pass
    if defin == 'elo':
        col = 'categoria_%s_c%s' % (defin, c)
        df_filter = df[df[col].isin(cats)]
    elif defin == 'general':
        col = 'categoria_%s_h%s_c%s' % (defin, h, c)
        df_filter = df[df[col].isin(cats)]
    else:
        col1 = 'categoria_local_h%s_c%s' % (h,c)
        col2 = 'categoria_visita_h%s_c%s' % (h,c)
        df_filter = df[(df[col1].isin(cats)) & 
                       (df[col2].isin(cats))]
    return df_filter

# %%
def SignificanciaVariablesManual(coef, se, pval, replace_spaces = True):
    coef = "%.3f" % (np.round(coef, decimals = 3))
    se = "%.3f" % (np.round(se, decimals = 3))
    if coef > 0:
        output = '_' + str(coef) + ' (' + str(se) + ')'                    
    else:
        output = str(coef) + ' (' + str(se) + ')'
    pval = np.round(pval, 3)
    if pval < 0.01:
        output = output + '***'
    elif pval < 0.05 and pval >= 0.01:
        output = output + '**_'
    elif pval < 0.1 and pval >=0.05:
        output = output + '*__'
    else:
        output = output + '___'
    if replace_spaces:
        output = output.replace("_"," ")
    return output

# %%
def ANOVA1ViaIndicadores(datadir, ligas, defin, filtro):
    dict_replaces = {'_mean': '',
                     '_':' ',
                     'dificil':'Difícil',
                     'dificl' : 'Difícil',
                     'facil': 'Fácil',
                     'regular' : 'Regular',
                     'prom': 'Promedio',
                     'posicion': 'Posición',
                     'primer' : 'Primer',
                     'ronda' : 'Ronda',
                     'gral': 'Gral.',
                     'elo' : 'ELO',
                     'categoria': 'Categoría',
                     'local': 'Local',
                     'visita': 'Visita',
                     'general' : 'Gral.',
                     'corr' : 'Correg.',
                     'perc' : 'Frac.',
                     ' h' : ' Ant. ',
                     ' p': ' Primeros ',
                     ' c': ' Corte ',
                     'lv' : 'LV',
                     'Primer Fácil C': 'Primer Fácil LV C',
                     'Primer Difícil C': 'Primer Difícil LV C'}
    if defin != 'lv':
        dfs, columns_filter = LeerBasesRegresion(datadir,
                                                 ligas,
                                                 lambda x: defin in x)
    else:
        dfs, columns_filter = LeerBasesRegresion(datadir,
                                                 ligas,
                                                 lambda x: defin in x or 'local' in x or 'visita' in x)        
    columns_facil = [i for i in columns_filter if 'facil' in i and 'perc' in i]
    columns_dificil = [i for i in columns_filter if 'dificil' in i and 'perc' in i]
    dictresumen_l = {'Indicador' : columns_facil}
    dfs_resumen = []
    # Columnas de facil
    for i in range(len(ligas)):
        liga = ligas[i]
        if liga != 'All':
            df_liga = dfs[i]
        else:
            df_liga = pd.concat(dfs, ignore_index = True)
        resultados = []
        for var in columns_facil:
            if filtro != 'regular':
                if 'facil' in var:
                    filt = 'facil'
                else:
                    filt = 'dificil'
            else:
                filt = filtro
            if defin != 'elo':
                aux = var.split('_h')[1].split('_p')
                h, c = aux[0], aux[1].split('_c')[1]
            else:
                h, c = None, var.split('_c')[1]
            formula = var + ' ~ C(equipo)'
            df_anova = FiltrarRegulares(df_liga, defin, c, h, filt)
            n_obs = df_anova.shape[0]
            model = ols(formula,
                        data =  df_anova).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            out = '%s (N = %s)' % (np.round(aov_table['PR(>F)'][0], decimals = 3), n_obs)
            resultados.append(out)
        dictresumen_l[liga] = resultados
    df_facil = pd.DataFrame(data = dictresumen_l)
    df_facil['Indicador'] = df_facil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_facil)
    dictresumen_v = {'Indicador' : columns_dificil}
    for i in range(len(ligas)):
        liga = ligas[i]
        liga = ligas[i]
        if liga != 'All':
            df_liga = dfs[i]
        else:
            df_liga = pd.concat(dfs, ignore_index = True)
        resultados = []
        for var in columns_dificil:
            if filtro != 'regular':
                if 'facil' in var:
                    filt = 'facil'
                else:
                    filt = 'dificil'
            else:
                filt = filtro
            if defin != 'elo':
                aux = var.split('_h')[1].split('_p')
                h, c = aux[0], aux[1].split('_c')[1]
            else:
                h, c = None, var.split('_c')[1]
            formula = var + ' ~ C(equipo)'
            df_anova = FiltrarRegulares(df_liga, defin, c, h, filt)
            n_obs = df_anova.shape[0]
            model = ols(formula,
                        data = df_anova).fit()
            aov_table = sm.stats.anova_lm(model, typ=2)
            out = '%s (N = %s)' % (np.round(aov_table['PR(>F)'][0], decimals = 3), n_obs)
            resultados.append(out)
        dictresumen_v[liga] = resultados
    df_dificil = pd.DataFrame(data = dictresumen_v)
    df_dificil['Indicador'] = df_dificil['Indicador'].replace(to_replace = dict_replaces, regex=True)
    dfs_resumen.append(df_dificil)
    return dfs_resumen

# %% [markdown]
# ## Aleatoriedad para indicadores según puntaje ELO

# %%
filtro = 'regular'

# %%
# %%time
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
outputdir = os.path.join(os.path.pardir,'resultados','aleatoriedad-inicio')
dfs_resumen_elo = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       defin = 'elo',
                                       filtro = filtro)

outputfile = 'aleatoriedad-elo-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_elo, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()
# Out:
# CPU times: user 14.1 s, sys: 201 ms, total: 14.3 s
# Wall time: 8.9 s

# %%
dfs_resumen_elo[0]
# Out:
#                 Indicador         Alemania           Espana          Francia  \
# 0   Frac. Fácil ELO p4 c3  0.072 (N = 225)   0.04 (N = 255)  0.035 (N = 170)
# 1   Frac. Fácil ELO p5 c3  0.005 (N = 225)  0.328 (N = 255)  0.076 (N = 170)
# 2   Frac. Fácil ELO p6 c3  0.019 (N = 225)  0.088 (N = 255)   0.12 (N = 170)
# 3   Frac. Fácil ELO p7 c3  0.001 (N = 225)  0.134 (N = 255)  0.103 (N = 170)
# 4   Frac. Fácil ELO p4 c4  0.092 (N = 210)  0.166 (N = 240)  0.419 (N = 160)
# 5   Frac. Fácil ELO p5 c4  0.001 (N = 210)  0.619 (N = 240)   0.72 (N = 160)
# 6   Frac. Fácil ELO p6 c4  0.011 (N = 210)   0.24 (N = 240)  0.923 (N = 160)
# 7   Frac. Fácil ELO p7 c4    0.0 (N = 210)  0.228 (N = 240)  0.682 (N = 160)
# 8   Frac. Fácil ELO p4 c5  0.381 (N = 195)  0.057 (N = 225)  0.629 (N = 150)
# 9   Frac. Fácil ELO p5 c5  0.042 (N = 195)  0.086 (N = 225)  0.631 (N = 150)
# 10  Frac. Fácil ELO p6 c5  0.139 (N = 195)  0.018 (N = 225)  0.698 (N = 150)
# 11  Frac. Fácil ELO p7 c5  0.019 (N = 195)  0.019 (N = 225)  0.509 (N = 150)
#
#          Inglaterra           Italia               All
# 0   0.175 (N = 429)  0.371 (N = 253)  0.002 (N = 1332)
# 1   0.448 (N = 429)  0.494 (N = 253)  0.015 (N = 1332)
# 2   0.597 (N = 429)  0.506 (N = 253)  0.026 (N = 1332)
# 3   0.955 (N = 429)  0.506 (N = 253)  0.018 (N = 1332)
# 4   0.828 (N = 404)  0.105 (N = 238)  0.075 (N = 1252)
# 5   0.955 (N = 404)  0.077 (N = 238)  0.058 (N = 1252)
# 6   0.994 (N = 404)  0.101 (N = 238)  0.121 (N = 1252)
# 7   0.986 (N = 404)  0.296 (N = 238)  0.014 (N = 1252)
# 8   0.614 (N = 379)  0.155 (N = 223)  0.131 (N = 1172)
# 9   0.922 (N = 379)  0.038 (N = 223)  0.064 (N = 1172)
# 10  0.754 (N = 379)   0.07 (N = 223)  0.025 (N = 1172)
# 11  0.756 (N = 379)  0.288 (N = 223)  0.006 (N = 1172)

# %%
dfs_resumen_elo[1]
# Out:
#                   Indicador         Alemania           Espana  \
# 0   Frac. Difícil ELO p4 c3  0.951 (N = 225)  0.082 (N = 255)
# 1   Frac. Difícil ELO p5 c3   0.58 (N = 225)  0.036 (N = 255)
# 2   Frac. Difícil ELO p6 c3  0.628 (N = 225)  0.041 (N = 255)
# 3   Frac. Difícil ELO p7 c3  0.773 (N = 225)  0.023 (N = 255)
# 4   Frac. Difícil ELO p4 c4  0.536 (N = 210)  0.043 (N = 240)
# 5   Frac. Difícil ELO p5 c4  0.122 (N = 210)  0.056 (N = 240)
# 6   Frac. Difícil ELO p6 c4  0.104 (N = 210)  0.013 (N = 240)
# 7   Frac. Difícil ELO p7 c4  0.171 (N = 210)  0.024 (N = 240)
# 8   Frac. Difícil ELO p4 c5   0.45 (N = 195)  0.032 (N = 225)
# 9   Frac. Difícil ELO p5 c5  0.218 (N = 195)  0.149 (N = 225)
# 10  Frac. Difícil ELO p6 c5  0.519 (N = 195)  0.061 (N = 225)
# 11  Frac. Difícil ELO p7 c5   0.59 (N = 195)  0.037 (N = 225)
#
#             Francia       Inglaterra           Italia               All
# 0   0.366 (N = 170)  0.953 (N = 429)  0.445 (N = 253)  0.792 (N = 1332)
# 1   0.439 (N = 170)  0.405 (N = 429)  0.068 (N = 253)  0.072 (N = 1332)
# 2   0.152 (N = 170)  0.136 (N = 429)  0.353 (N = 253)  0.044 (N = 1332)
# 3   0.177 (N = 170)  0.161 (N = 429)  0.424 (N = 253)  0.071 (N = 1332)
# 4     0.1 (N = 160)  0.948 (N = 404)  0.732 (N = 238)  0.603 (N = 1252)
# 5   0.137 (N = 160)   0.43 (N = 404)  0.153 (N = 238)  0.033 (N = 1252)
# 6   0.134 (N = 160)  0.202 (N = 404)  0.649 (N = 238)  0.027 (N = 1252)
# 7   0.446 (N = 160)  0.253 (N = 404)  0.776 (N = 238)  0.112 (N = 1252)
# 8   0.505 (N = 150)  0.717 (N = 379)  0.761 (N = 223)  0.537 (N = 1172)
# 9    0.42 (N = 150)  0.425 (N = 379)  0.394 (N = 223)  0.229 (N = 1172)
# 10  0.308 (N = 150)  0.323 (N = 379)  0.324 (N = 223)  0.145 (N = 1172)
# 11  0.372 (N = 150)  0.356 (N = 379)  0.289 (N = 223)  0.132 (N = 1172)

# %% [markdown]
# ## Aleatoriedad para indicadores según definición general

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
dfs_resumen_general = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       defin = 'general')

outputfile = 'aleatoriedad-general-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_general, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_general[0]
# Out:
#                      Indicador         Alemania           Espana  \
# 0   Frac. Fácil Gral. h1 p4 c3  0.427 (N = 202)  0.432 (N = 225)
# 1   Frac. Fácil Gral. h1 p5 c3  0.143 (N = 202)  0.238 (N = 225)
# 2   Frac. Fácil Gral. h1 p6 c3  0.453 (N = 202)  0.156 (N = 225)
# 3   Frac. Fácil Gral. h1 p7 c3  0.358 (N = 202)   0.12 (N = 225)
# 4   Frac. Fácil Gral. h1 p4 c4  0.101 (N = 187)  0.443 (N = 210)
# 5   Frac. Fácil Gral. h1 p5 c4   0.01 (N = 187)  0.316 (N = 210)
# 6   Frac. Fácil Gral. h1 p6 c4  0.136 (N = 187)  0.283 (N = 210)
# 7   Frac. Fácil Gral. h1 p7 c4  0.048 (N = 187)  0.344 (N = 210)
# 8   Frac. Fácil Gral. h1 p4 c5  0.638 (N = 172)  0.429 (N = 195)
# 9   Frac. Fácil Gral. h1 p5 c5  0.384 (N = 172)  0.088 (N = 195)
# 10  Frac. Fácil Gral. h1 p6 c5  0.864 (N = 172)  0.116 (N = 195)
# 11  Frac. Fácil Gral. h1 p7 c5  0.549 (N = 172)  0.036 (N = 195)
# 12  Frac. Fácil Gral. h2 p4 c3  0.141 (N = 217)  0.536 (N = 235)
# 13  Frac. Fácil Gral. h2 p5 c3  0.033 (N = 217)  0.341 (N = 235)
# 14  Frac. Fácil Gral. h2 p6 c3   0.35 (N = 217)  0.289 (N = 235)
# 15  Frac. Fácil Gral. h2 p7 c3   0.52 (N = 217)  0.486 (N = 235)
# 16  Frac. Fácil Gral. h2 p4 c4  0.057 (N = 202)  0.781 (N = 220)
# 17  Frac. Fácil Gral. h2 p5 c4   0.03 (N = 202)  0.681 (N = 220)
# 18  Frac. Fácil Gral. h2 p6 c4  0.049 (N = 202)  0.689 (N = 220)
# 19  Frac. Fácil Gral. h2 p7 c4  0.014 (N = 202)  0.518 (N = 220)
# 20  Frac. Fácil Gral. h2 p4 c5  0.016 (N = 187)  0.421 (N = 205)
# 21  Frac. Fácil Gral. h2 p5 c5  0.001 (N = 187)  0.314 (N = 205)
# 22  Frac. Fácil Gral. h2 p6 c5  0.013 (N = 187)  0.271 (N = 205)
# 23  Frac. Fácil Gral. h2 p7 c5  0.004 (N = 187)  0.326 (N = 205)
# 24  Frac. Fácil Gral. h3 p4 c3  0.545 (N = 221)  0.457 (N = 242)
# 25  Frac. Fácil Gral. h3 p5 c3   0.45 (N = 221)  0.334 (N = 242)
# 26  Frac. Fácil Gral. h3 p6 c3  0.634 (N = 221)  0.221 (N = 242)
# 27  Frac. Fácil Gral. h3 p7 c3  0.193 (N = 221)  0.676 (N = 242)
# 28  Frac. Fácil Gral. h3 p4 c4  0.724 (N = 206)  0.465 (N = 227)
# 29  Frac. Fácil Gral. h3 p5 c4  0.651 (N = 206)  0.407 (N = 227)
# 30  Frac. Fácil Gral. h3 p6 c4   0.53 (N = 206)  0.544 (N = 227)
# 31  Frac. Fácil Gral. h3 p7 c4   0.15 (N = 206)  0.909 (N = 227)
# 32  Frac. Fácil Gral. h3 p4 c5   0.48 (N = 191)  0.359 (N = 212)
# 33  Frac. Fácil Gral. h3 p5 c5  0.065 (N = 191)  0.304 (N = 212)
# 34  Frac. Fácil Gral. h3 p6 c5  0.087 (N = 191)  0.501 (N = 212)
# 35  Frac. Fácil Gral. h3 p7 c5   0.07 (N = 191)  0.817 (N = 212)
# 36  Frac. Fácil Gral. h4 p4 c3  0.477 (N = 222)  0.946 (N = 249)
# 37  Frac. Fácil Gral. h4 p5 c3  0.524 (N = 222)  0.946 (N = 249)
# 38  Frac. Fácil Gral. h4 p6 c3  0.399 (N = 222)   0.67 (N = 249)
# 39  Frac. Fácil Gral. h4 p7 c3  0.287 (N = 222)  0.619 (N = 249)
# 40  Frac. Fácil Gral. h4 p4 c4  0.753 (N = 207)  0.935 (N = 234)
# 41  Frac. Fácil Gral. h4 p5 c4  0.888 (N = 207)  0.764 (N = 234)
# 42  Frac. Fácil Gral. h4 p6 c4  0.899 (N = 207)  0.358 (N = 234)
# 43  Frac. Fácil Gral. h4 p7 c4  0.793 (N = 207)  0.469 (N = 234)
# 44  Frac. Fácil Gral. h4 p4 c5  0.805 (N = 192)  0.887 (N = 219)
# 45  Frac. Fácil Gral. h4 p5 c5  0.963 (N = 192)  0.625 (N = 219)
# 46  Frac. Fácil Gral. h4 p6 c5  0.984 (N = 192)  0.167 (N = 219)
# 47  Frac. Fácil Gral. h4 p7 c5   0.97 (N = 192)  0.265 (N = 219)
# 48  Frac. Fácil Gral. h5 p4 c3  0.929 (N = 223)  0.714 (N = 249)
# 49  Frac. Fácil Gral. h5 p5 c3  0.966 (N = 223)  0.791 (N = 249)
# 50  Frac. Fácil Gral. h5 p6 c3  0.746 (N = 223)  0.732 (N = 249)
# 51  Frac. Fácil Gral. h5 p7 c3  0.559 (N = 223)  0.315 (N = 249)
# 52  Frac. Fácil Gral. h5 p4 c4  0.752 (N = 208)  0.517 (N = 234)
# 53  Frac. Fácil Gral. h5 p5 c4  0.964 (N = 208)  0.226 (N = 234)
# 54  Frac. Fácil Gral. h5 p6 c4  0.507 (N = 208)  0.072 (N = 234)
# 55  Frac. Fácil Gral. h5 p7 c4  0.353 (N = 208)  0.047 (N = 234)
# 56  Frac. Fácil Gral. h5 p4 c5  0.434 (N = 193)  0.904 (N = 219)
# 57  Frac. Fácil Gral. h5 p5 c5  0.848 (N = 193)  0.642 (N = 219)
# 58  Frac. Fácil Gral. h5 p6 c5  0.716 (N = 193)  0.417 (N = 219)
# 59  Frac. Fácil Gral. h5 p7 c5  0.476 (N = 193)  0.262 (N = 219)
#
#             Francia       Inglaterra           Italia               All
# 0    0.37 (N = 150)  0.708 (N = 380)  0.399 (N = 219)  0.533 (N = 1176)
# 1   0.377 (N = 150)  0.767 (N = 380)  0.215 (N = 219)  0.243 (N = 1176)
# 2    0.79 (N = 150)  0.972 (N = 380)  0.432 (N = 219)  0.789 (N = 1176)
# 3   0.657 (N = 150)  0.984 (N = 380)  0.582 (N = 219)  0.757 (N = 1176)
# 4   0.619 (N = 140)  0.465 (N = 355)  0.418 (N = 204)  0.323 (N = 1096)
# 5   0.652 (N = 140)  0.693 (N = 355)  0.083 (N = 204)  0.117 (N = 1096)
# 6   0.924 (N = 140)  0.943 (N = 355)    0.2 (N = 204)  0.646 (N = 1096)
# 7    0.81 (N = 140)  0.978 (N = 355)  0.474 (N = 204)   0.71 (N = 1096)
# 8   0.852 (N = 130)  0.261 (N = 330)  0.299 (N = 189)  0.383 (N = 1016)
# 9   0.908 (N = 130)  0.853 (N = 330)  0.017 (N = 189)  0.233 (N = 1016)
# 10  0.968 (N = 130)  0.909 (N = 330)  0.025 (N = 189)  0.583 (N = 1016)
# 11  0.902 (N = 130)  0.967 (N = 330)  0.394 (N = 189)  0.734 (N = 1016)
# 12  0.382 (N = 155)  0.211 (N = 402)  0.078 (N = 235)  0.099 (N = 1244)
# 13  0.464 (N = 155)  0.207 (N = 402)  0.076 (N = 235)  0.034 (N = 1244)
# 14  0.729 (N = 155)  0.265 (N = 402)  0.119 (N = 235)  0.188 (N = 1244)
# 15  0.315 (N = 155)  0.697 (N = 402)  0.154 (N = 235)  0.409 (N = 1244)
# 16  0.661 (N = 145)   0.06 (N = 377)  0.066 (N = 220)  0.067 (N = 1164)
# 17  0.848 (N = 145)  0.075 (N = 377)  0.038 (N = 220)  0.052 (N = 1164)
# 18  0.813 (N = 145)  0.055 (N = 377)  0.112 (N = 220)  0.069 (N = 1164)
# 19  0.781 (N = 145)  0.255 (N = 377)   0.43 (N = 220)  0.167 (N = 1164)
# 20   0.56 (N = 135)  0.013 (N = 352)  0.168 (N = 205)  0.003 (N = 1084)
# 21  0.783 (N = 135)  0.057 (N = 352)  0.187 (N = 205)  0.003 (N = 1084)
# 22  0.657 (N = 135)  0.047 (N = 352)  0.199 (N = 205)  0.007 (N = 1084)
# 23  0.314 (N = 135)  0.152 (N = 352)  0.545 (N = 205)  0.018 (N = 1084)
# 24  0.806 (N = 158)  0.647 (N = 409)  0.229 (N = 238)  0.685 (N = 1268)
# 25  0.911 (N = 158)  0.667 (N = 409)  0.259 (N = 238)  0.656 (N = 1268)
# 26   0.89 (N = 158)  0.643 (N = 409)  0.206 (N = 238)  0.562 (N = 1268)
# 27  0.566 (N = 158)  0.956 (N = 409)  0.141 (N = 238)  0.586 (N = 1268)
# 28  0.414 (N = 148)  0.228 (N = 384)  0.148 (N = 223)  0.343 (N = 1188)
# 29  0.706 (N = 148)  0.559 (N = 384)  0.173 (N = 223)  0.598 (N = 1188)
# 30  0.673 (N = 148)  0.285 (N = 384)  0.228 (N = 223)  0.423 (N = 1188)
# 31  0.364 (N = 148)  0.781 (N = 384)  0.365 (N = 223)  0.608 (N = 1188)
# 32  0.898 (N = 138)  0.497 (N = 359)  0.433 (N = 208)   0.53 (N = 1108)
# 33  0.947 (N = 138)  0.558 (N = 359)   0.22 (N = 208)  0.245 (N = 1108)
# 34  0.913 (N = 138)  0.115 (N = 359)  0.342 (N = 208)  0.155 (N = 1108)
# 35  0.737 (N = 138)  0.149 (N = 359)  0.645 (N = 208)  0.369 (N = 1108)
# 36  0.345 (N = 160)  0.023 (N = 411)  0.365 (N = 242)  0.246 (N = 1284)
# 37  0.377 (N = 160)  0.071 (N = 411)  0.599 (N = 242)  0.422 (N = 1284)
# 38  0.335 (N = 160)  0.155 (N = 411)  0.715 (N = 242)   0.39 (N = 1284)
# 39   0.13 (N = 160)  0.224 (N = 411)  0.532 (N = 242)  0.194 (N = 1284)
# 40  0.593 (N = 150)  0.113 (N = 386)  0.454 (N = 227)  0.625 (N = 1204)
# 41  0.713 (N = 150)  0.167 (N = 386)  0.525 (N = 227)  0.691 (N = 1204)
# 42  0.781 (N = 150)  0.149 (N = 386)  0.938 (N = 227)  0.731 (N = 1204)
# 43  0.145 (N = 150)  0.157 (N = 386)  0.791 (N = 227)  0.323 (N = 1204)
# 44  0.896 (N = 140)  0.576 (N = 361)   0.74 (N = 212)  0.953 (N = 1124)
# 45  0.886 (N = 140)  0.704 (N = 361)  0.629 (N = 212)   0.95 (N = 1124)
# 46  0.929 (N = 140)  0.533 (N = 361)  0.982 (N = 212)  0.947 (N = 1124)
# 47   0.39 (N = 140)  0.567 (N = 361)  0.891 (N = 212)   0.73 (N = 1124)
# 48  0.413 (N = 161)  0.258 (N = 415)  0.208 (N = 244)  0.612 (N = 1292)
# 49  0.215 (N = 161)  0.434 (N = 415)  0.321 (N = 244)  0.738 (N = 1292)
# 50  0.589 (N = 161)  0.231 (N = 415)  0.364 (N = 244)  0.597 (N = 1292)
# 51  0.496 (N = 161)   0.48 (N = 415)  0.277 (N = 244)  0.458 (N = 1292)
# 52  0.412 (N = 151)  0.388 (N = 390)  0.509 (N = 229)  0.646 (N = 1212)
# 53  0.605 (N = 151)  0.442 (N = 390)  0.342 (N = 229)  0.657 (N = 1212)
# 54  0.853 (N = 151)  0.297 (N = 390)  0.401 (N = 229)  0.338 (N = 1212)
# 55  0.546 (N = 151)  0.567 (N = 390)  0.364 (N = 229)  0.275 (N = 1212)
# 56   0.21 (N = 141)  0.679 (N = 365)  0.591 (N = 214)  0.788 (N = 1132)
# 57  0.177 (N = 141)   0.64 (N = 365)  0.483 (N = 214)  0.708 (N = 1132)
# 58  0.626 (N = 141)  0.321 (N = 365)  0.531 (N = 214)  0.611 (N = 1132)
# 59  0.231 (N = 141)  0.888 (N = 365)  0.516 (N = 214)  0.602 (N = 1132)

# %%
dfs_resumen_general[1]
# Out:
#                        Indicador         Alemania           Espana  \
# 0   Frac. Difícil Gral. h1 p4 c3  0.736 (N = 225)  0.068 (N = 255)
# 1   Frac. Difícil Gral. h1 p5 c3  0.488 (N = 225)  0.037 (N = 255)
# 2   Frac. Difícil Gral. h1 p6 c3  0.429 (N = 225)  0.037 (N = 255)
# 3   Frac. Difícil Gral. h1 p7 c3  0.628 (N = 225)  0.101 (N = 255)
# 4   Frac. Difícil Gral. h1 p4 c4  0.452 (N = 210)  0.157 (N = 240)
# 5   Frac. Difícil Gral. h1 p5 c4  0.172 (N = 210)  0.305 (N = 240)
# 6   Frac. Difícil Gral. h1 p6 c4  0.422 (N = 210)  0.176 (N = 240)
# 7   Frac. Difícil Gral. h1 p7 c4  0.627 (N = 210)  0.295 (N = 240)
# 8   Frac. Difícil Gral. h1 p4 c5  0.429 (N = 195)  0.008 (N = 225)
# 9   Frac. Difícil Gral. h1 p5 c5  0.248 (N = 195)  0.044 (N = 225)
# 10  Frac. Difícil Gral. h1 p6 c5  0.432 (N = 195)  0.062 (N = 225)
# 11  Frac. Difícil Gral. h1 p7 c5  0.662 (N = 195)  0.076 (N = 225)
# 12  Frac. Difícil Gral. h2 p4 c3  0.707 (N = 225)  0.108 (N = 255)
# 13  Frac. Difícil Gral. h2 p5 c3  0.052 (N = 225)  0.037 (N = 255)
# 14  Frac. Difícil Gral. h2 p6 c3  0.323 (N = 225)  0.121 (N = 255)
# 15  Frac. Difícil Gral. h2 p7 c3   0.19 (N = 225)  0.276 (N = 255)
# 16  Frac. Difícil Gral. h2 p4 c4  0.676 (N = 210)  0.176 (N = 240)
# 17  Frac. Difícil Gral. h2 p5 c4  0.432 (N = 210)  0.114 (N = 240)
# 18  Frac. Difícil Gral. h2 p6 c4  0.167 (N = 210)  0.146 (N = 240)
# 19  Frac. Difícil Gral. h2 p7 c4  0.291 (N = 210)  0.114 (N = 240)
# 20  Frac. Difícil Gral. h2 p4 c5   0.45 (N = 195)  0.215 (N = 225)
# 21  Frac. Difícil Gral. h2 p5 c5  0.264 (N = 195)  0.439 (N = 225)
# 22  Frac. Difícil Gral. h2 p6 c5  0.457 (N = 195)  0.383 (N = 225)
# 23  Frac. Difícil Gral. h2 p7 c5  0.397 (N = 195)  0.284 (N = 225)
# 24  Frac. Difícil Gral. h3 p4 c3  0.555 (N = 225)   0.13 (N = 255)
# 25  Frac. Difícil Gral. h3 p5 c3  0.122 (N = 225)  0.168 (N = 255)
# 26  Frac. Difícil Gral. h3 p6 c3  0.076 (N = 225)  0.345 (N = 255)
# 27  Frac. Difícil Gral. h3 p7 c3  0.098 (N = 225)  0.218 (N = 255)
# 28  Frac. Difícil Gral. h3 p4 c4  0.341 (N = 210)  0.016 (N = 240)
# 29  Frac. Difícil Gral. h3 p5 c4  0.049 (N = 210)  0.011 (N = 240)
# 30  Frac. Difícil Gral. h3 p6 c4  0.022 (N = 210)  0.045 (N = 240)
# 31  Frac. Difícil Gral. h3 p7 c4  0.019 (N = 210)  0.032 (N = 240)
# 32  Frac. Difícil Gral. h3 p4 c5  0.661 (N = 195)  0.105 (N = 225)
# 33  Frac. Difícil Gral. h3 p5 c5  0.218 (N = 195)  0.085 (N = 225)
# 34  Frac. Difícil Gral. h3 p6 c5  0.128 (N = 195)  0.267 (N = 225)
# 35  Frac. Difícil Gral. h3 p7 c5  0.024 (N = 195)  0.149 (N = 225)
# 36  Frac. Difícil Gral. h4 p4 c3  0.707 (N = 225)  0.683 (N = 255)
# 37  Frac. Difícil Gral. h4 p5 c3  0.445 (N = 225)  0.406 (N = 255)
# 38  Frac. Difícil Gral. h4 p6 c3  0.156 (N = 225)  0.606 (N = 255)
# 39  Frac. Difícil Gral. h4 p7 c3  0.048 (N = 225)  0.848 (N = 255)
# 40  Frac. Difícil Gral. h4 p4 c4  0.643 (N = 210)   0.36 (N = 240)
# 41  Frac. Difícil Gral. h4 p5 c4  0.651 (N = 210)  0.131 (N = 240)
# 42  Frac. Difícil Gral. h4 p6 c4    0.5 (N = 210)   0.19 (N = 240)
# 43  Frac. Difícil Gral. h4 p7 c4  0.658 (N = 210)  0.382 (N = 240)
# 44  Frac. Difícil Gral. h4 p4 c5  0.941 (N = 195)  0.441 (N = 225)
# 45  Frac. Difícil Gral. h4 p5 c5  0.929 (N = 195)  0.078 (N = 225)
# 46  Frac. Difícil Gral. h4 p6 c5  0.747 (N = 195)  0.053 (N = 225)
# 47  Frac. Difícil Gral. h4 p7 c5  0.805 (N = 195)  0.305 (N = 225)
# 48  Frac. Difícil Gral. h5 p4 c3  0.358 (N = 225)  0.169 (N = 255)
# 49  Frac. Difícil Gral. h5 p5 c3  0.562 (N = 225)  0.027 (N = 255)
# 50  Frac. Difícil Gral. h5 p6 c3  0.355 (N = 225)   0.49 (N = 255)
# 51  Frac. Difícil Gral. h5 p7 c3  0.082 (N = 225)   0.47 (N = 255)
# 52  Frac. Difícil Gral. h5 p4 c4  0.149 (N = 210)  0.092 (N = 240)
# 53  Frac. Difícil Gral. h5 p5 c4  0.138 (N = 210)  0.054 (N = 240)
# 54  Frac. Difícil Gral. h5 p6 c4   0.11 (N = 210)  0.243 (N = 240)
# 55  Frac. Difícil Gral. h5 p7 c4  0.096 (N = 210)  0.101 (N = 240)
# 56  Frac. Difícil Gral. h5 p4 c5  0.478 (N = 195)  0.531 (N = 225)
# 57  Frac. Difícil Gral. h5 p5 c5  0.311 (N = 195)  0.335 (N = 225)
# 58  Frac. Difícil Gral. h5 p6 c5   0.05 (N = 195)  0.349 (N = 225)
# 59  Frac. Difícil Gral. h5 p7 c5  0.271 (N = 195)  0.181 (N = 225)
#
#             Francia       Inglaterra           Italia               All
# 0   0.526 (N = 170)  0.984 (N = 429)  0.389 (N = 253)  0.743 (N = 1332)
# 1   0.726 (N = 170)   0.44 (N = 429)  0.048 (N = 253)  0.105 (N = 1332)
# 2   0.693 (N = 170)   0.18 (N = 429)  0.156 (N = 253)  0.072 (N = 1332)
# 3   0.746 (N = 170)  0.069 (N = 429)  0.079 (N = 253)  0.063 (N = 1332)
# 4   0.455 (N = 160)  0.993 (N = 404)   0.86 (N = 238)  0.898 (N = 1252)
# 5   0.535 (N = 160)  0.555 (N = 404)  0.567 (N = 238)  0.356 (N = 1252)
# 6   0.549 (N = 160)  0.449 (N = 404)  0.742 (N = 238)  0.437 (N = 1252)
# 7   0.789 (N = 160)  0.275 (N = 404)  0.386 (N = 238)  0.416 (N = 1252)
# 8   0.833 (N = 150)  0.805 (N = 379)  0.803 (N = 223)  0.607 (N = 1172)
# 9    0.66 (N = 150)  0.329 (N = 379)   0.44 (N = 223)   0.15 (N = 1172)
# 10  0.639 (N = 150)  0.231 (N = 379)  0.526 (N = 223)    0.2 (N = 1172)
# 11  0.765 (N = 150)  0.245 (N = 379)  0.518 (N = 223)  0.289 (N = 1172)
# 12  0.432 (N = 170)  0.906 (N = 429)  0.697 (N = 253)  0.773 (N = 1332)
# 13  0.381 (N = 170)  0.678 (N = 429)  0.231 (N = 253)  0.079 (N = 1332)
# 14  0.368 (N = 170)  0.271 (N = 429)  0.589 (N = 253)  0.162 (N = 1332)
# 15  0.421 (N = 170)  0.195 (N = 429)  0.589 (N = 253)  0.202 (N = 1332)
# 16  0.539 (N = 160)  0.856 (N = 404)  0.741 (N = 238)  0.804 (N = 1252)
# 17  0.559 (N = 160)  0.544 (N = 404)  0.144 (N = 238)  0.219 (N = 1252)
# 18  0.527 (N = 160)  0.469 (N = 404)  0.222 (N = 238)  0.159 (N = 1252)
# 19   0.42 (N = 160)  0.321 (N = 404)  0.315 (N = 238)  0.136 (N = 1252)
# 20  0.356 (N = 150)  0.397 (N = 379)  0.645 (N = 223)  0.427 (N = 1172)
# 21   0.39 (N = 150)   0.13 (N = 379)  0.572 (N = 223)  0.225 (N = 1172)
# 22  0.165 (N = 150)  0.277 (N = 379)  0.611 (N = 223)   0.25 (N = 1172)
# 23  0.541 (N = 150)  0.113 (N = 379)  0.591 (N = 223)  0.208 (N = 1172)
# 24  0.975 (N = 170)  0.858 (N = 429)  0.505 (N = 253)  0.811 (N = 1332)
# 25  0.989 (N = 170)  0.358 (N = 429)  0.043 (N = 253)  0.153 (N = 1332)
# 26  0.577 (N = 170)  0.161 (N = 429)  0.063 (N = 253)  0.047 (N = 1332)
# 27  0.805 (N = 170)  0.047 (N = 429)  0.031 (N = 253)  0.016 (N = 1332)
# 28  0.811 (N = 160)  0.492 (N = 404)  0.336 (N = 238)  0.135 (N = 1252)
# 29  0.618 (N = 160)  0.222 (N = 404)  0.046 (N = 238)  0.004 (N = 1252)
# 30   0.07 (N = 160)   0.25 (N = 404)  0.154 (N = 238)  0.003 (N = 1252)
# 31  0.377 (N = 160)  0.245 (N = 404)  0.051 (N = 238)  0.002 (N = 1252)
# 32  0.752 (N = 150)  0.266 (N = 379)  0.698 (N = 223)  0.426 (N = 1172)
# 33   0.45 (N = 150)    0.1 (N = 379)  0.464 (N = 223)  0.053 (N = 1172)
# 34  0.064 (N = 150)  0.124 (N = 379)  0.767 (N = 223)  0.064 (N = 1172)
# 35  0.379 (N = 150)  0.413 (N = 379)  0.687 (N = 223)  0.072 (N = 1172)
# 36  0.912 (N = 170)  0.966 (N = 429)  0.431 (N = 253)  0.966 (N = 1332)
# 37  0.773 (N = 170)  0.881 (N = 429)  0.788 (N = 253)  0.863 (N = 1332)
# 38  0.705 (N = 170)  0.916 (N = 429)  0.592 (N = 253)  0.733 (N = 1332)
# 39  0.452 (N = 170)  0.824 (N = 429)  0.478 (N = 253)  0.434 (N = 1332)
# 40  0.763 (N = 160)  0.663 (N = 404)  0.489 (N = 238)   0.74 (N = 1252)
# 41  0.737 (N = 160)  0.617 (N = 404)  0.566 (N = 238)  0.589 (N = 1252)
# 42  0.799 (N = 160)  0.449 (N = 404)  0.456 (N = 238)  0.391 (N = 1252)
# 43  0.317 (N = 160)  0.387 (N = 404)  0.551 (N = 238)  0.312 (N = 1252)
# 44   0.63 (N = 150)  0.617 (N = 379)  0.699 (N = 223)  0.881 (N = 1172)
# 45  0.671 (N = 150)  0.482 (N = 379)   0.69 (N = 223)  0.623 (N = 1172)
# 46  0.669 (N = 150)  0.571 (N = 379)  0.521 (N = 223)   0.44 (N = 1172)
# 47  0.092 (N = 150)  0.516 (N = 379)  0.582 (N = 223)  0.365 (N = 1172)
# 48  0.545 (N = 170)   0.86 (N = 429)  0.338 (N = 253)  0.496 (N = 1332)
# 49  0.645 (N = 170)  0.802 (N = 429)    0.5 (N = 253)  0.493 (N = 1332)
# 50  0.501 (N = 170)  0.179 (N = 429)  0.366 (N = 253)  0.221 (N = 1332)
# 51   0.58 (N = 170)  0.534 (N = 429)  0.604 (N = 253)  0.385 (N = 1332)
# 52  0.299 (N = 160)  0.994 (N = 404)  0.346 (N = 238)   0.45 (N = 1252)
# 53  0.414 (N = 160)  0.992 (N = 404)  0.473 (N = 238)   0.47 (N = 1252)
# 54  0.431 (N = 160)  0.926 (N = 404)  0.537 (N = 238)  0.429 (N = 1252)
# 55  0.588 (N = 160)   0.98 (N = 404)  0.546 (N = 238)  0.489 (N = 1252)
# 56  0.631 (N = 150)  0.959 (N = 379)  0.727 (N = 223)  0.902 (N = 1172)
# 57  0.713 (N = 150)  0.978 (N = 379)  0.617 (N = 223)  0.779 (N = 1172)
# 58  0.364 (N = 150)  0.975 (N = 379)  0.386 (N = 223)  0.214 (N = 1172)
# 59   0.27 (N = 150)  0.997 (N = 379)  0.527 (N = 223)  0.412 (N = 1172)

# %%
datadir = os.path.join(os.path.pardir, 'datos', 'regresiones')
ligas = ['Alemania','Espana','Francia', 'Inglaterra','Italia', 'All']
dfs_resumen_lv = ANOVA1ViaIndicadores(datadir,
                                       ligas,
                                       defin = 'lv')

outputfile = 'aleatoriedad-localvisita-%s.xlsx' % filtro
writer = pd.ExcelWriter(os.path.join(outputdir, outputfile), engine='xlsxwriter')
for df, sheet in zip(dfs_resumen_lv, ['Facil','Dificil']):
    df.to_excel(writer, sheet_name = sheet, index = False)
writer.save()

# %%
dfs_resumen_lv[0]
# Out:
#                   Indicador         Alemania           Espana  \
# 0   Frac. Fácil LV h1 p4 c3  0.031 (N = 174)  0.628 (N = 195)
# 1   Frac. Fácil LV h1 p5 c3  0.021 (N = 174)  0.524 (N = 195)
# 2   Frac. Fácil LV h1 p6 c3  0.343 (N = 174)  0.347 (N = 195)
# 3   Frac. Fácil LV h1 p7 c3  0.326 (N = 174)  0.326 (N = 195)
# 4   Frac. Fácil LV h1 p4 c4  0.316 (N = 150)  0.295 (N = 173)
# 5   Frac. Fácil LV h1 p5 c4  0.361 (N = 150)  0.141 (N = 173)
# 6   Frac. Fácil LV h1 p6 c4  0.492 (N = 150)  0.189 (N = 173)
# 7   Frac. Fácil LV h1 p7 c4  0.186 (N = 150)  0.036 (N = 173)
# 8   Frac. Fácil LV h1 p4 c5  0.637 (N = 129)   0.12 (N = 154)
# 9   Frac. Fácil LV h1 p5 c5  0.579 (N = 129)  0.107 (N = 154)
# 10  Frac. Fácil LV h1 p6 c5  0.742 (N = 129)  0.137 (N = 154)
# 11  Frac. Fácil LV h1 p7 c5  0.173 (N = 129)  0.017 (N = 154)
# 12  Frac. Fácil LV h2 p4 c3  0.452 (N = 196)  0.454 (N = 211)
# 13  Frac. Fácil LV h2 p5 c3  0.327 (N = 196)  0.167 (N = 211)
# 14  Frac. Fácil LV h2 p6 c3   0.55 (N = 196)  0.069 (N = 211)
# 15  Frac. Fácil LV h2 p7 c3  0.436 (N = 196)  0.151 (N = 211)
# 16  Frac. Fácil LV h2 p4 c4  0.153 (N = 172)   0.18 (N = 188)
# 17  Frac. Fácil LV h2 p5 c4  0.234 (N = 172)  0.143 (N = 188)
# 18  Frac. Fácil LV h2 p6 c4  0.631 (N = 172)  0.163 (N = 188)
# 19  Frac. Fácil LV h2 p7 c4  0.496 (N = 172)  0.157 (N = 188)
# 20  Frac. Fácil LV h2 p4 c5  0.419 (N = 149)   0.63 (N = 166)
# 21  Frac. Fácil LV h2 p5 c5   0.59 (N = 149)  0.338 (N = 166)
# 22  Frac. Fácil LV h2 p6 c5  0.548 (N = 149)  0.504 (N = 166)
# 23  Frac. Fácil LV h2 p7 c5  0.458 (N = 149)  0.349 (N = 166)
# 24  Frac. Fácil LV h3 p4 c3   0.26 (N = 197)  0.292 (N = 221)
# 25  Frac. Fácil LV h3 p5 c3  0.261 (N = 197)   0.05 (N = 221)
# 26  Frac. Fácil LV h3 p6 c3   0.74 (N = 197)  0.076 (N = 221)
# 27  Frac. Fácil LV h3 p7 c3   0.76 (N = 197)  0.014 (N = 221)
# 28  Frac. Fácil LV h3 p4 c4  0.171 (N = 174)  0.765 (N = 195)
# 29  Frac. Fácil LV h3 p5 c4  0.172 (N = 174)  0.508 (N = 195)
# 30  Frac. Fácil LV h3 p6 c4  0.239 (N = 174)  0.559 (N = 195)
# 31  Frac. Fácil LV h3 p7 c4  0.252 (N = 174)  0.289 (N = 195)
# 32  Frac. Fácil LV h3 p4 c5  0.199 (N = 154)  0.828 (N = 176)
# 33  Frac. Fácil LV h3 p5 c5  0.193 (N = 154)  0.805 (N = 176)
# 34  Frac. Fácil LV h3 p6 c5   0.09 (N = 154)  0.461 (N = 176)
# 35  Frac. Fácil LV h3 p7 c5  0.089 (N = 154)  0.141 (N = 176)
# 36  Frac. Fácil LV h4 p4 c3  0.216 (N = 197)  0.365 (N = 230)
# 37  Frac. Fácil LV h4 p5 c3  0.353 (N = 197)   0.27 (N = 230)
# 38  Frac. Fácil LV h4 p6 c3  0.405 (N = 197)  0.138 (N = 230)
# 39  Frac. Fácil LV h4 p7 c3  0.414 (N = 197)  0.291 (N = 230)
# 40  Frac. Fácil LV h4 p4 c4  0.118 (N = 175)  0.412 (N = 206)
# 41  Frac. Fácil LV h4 p5 c4  0.289 (N = 175)  0.296 (N = 206)
# 42  Frac. Fácil LV h4 p6 c4  0.214 (N = 175)   0.09 (N = 206)
# 43  Frac. Fácil LV h4 p7 c4  0.232 (N = 175)  0.435 (N = 206)
# 44  Frac. Fácil LV h4 p4 c5  0.452 (N = 156)  0.543 (N = 184)
# 45  Frac. Fácil LV h4 p5 c5  0.317 (N = 156)  0.425 (N = 184)
# 46  Frac. Fácil LV h4 p6 c5  0.162 (N = 156)  0.177 (N = 184)
# 47  Frac. Fácil LV h4 p7 c5  0.339 (N = 156)  0.044 (N = 184)
# 48  Frac. Fácil LV h5 p4 c3  0.344 (N = 197)    0.4 (N = 227)
# 49  Frac. Fácil LV h5 p5 c3  0.162 (N = 197)  0.202 (N = 227)
# 50  Frac. Fácil LV h5 p6 c3  0.442 (N = 197)  0.186 (N = 227)
# 51  Frac. Fácil LV h5 p7 c3  0.513 (N = 197)  0.188 (N = 227)
# 52  Frac. Fácil LV h5 p4 c4  0.295 (N = 175)  0.385 (N = 204)
# 53  Frac. Fácil LV h5 p5 c4  0.502 (N = 175)  0.095 (N = 204)
# 54  Frac. Fácil LV h5 p6 c4  0.344 (N = 175)  0.074 (N = 204)
# 55  Frac. Fácil LV h5 p7 c4   0.78 (N = 175)  0.185 (N = 204)
# 56  Frac. Fácil LV h5 p4 c5   0.42 (N = 153)  0.574 (N = 183)
# 57  Frac. Fácil LV h5 p5 c5  0.358 (N = 153)  0.368 (N = 183)
# 58  Frac. Fácil LV h5 p6 c5  0.068 (N = 153)  0.224 (N = 183)
# 59  Frac. Fácil LV h5 p7 c5  0.417 (N = 153)  0.336 (N = 183)
#
#             Francia       Inglaterra           Italia               All
# 0   0.112 (N = 130)  0.112 (N = 333)  0.728 (N = 191)  0.067 (N = 1023)
# 1    0.03 (N = 130)  0.545 (N = 333)  0.791 (N = 191)  0.096 (N = 1023)
# 2   0.164 (N = 130)  0.449 (N = 333)  0.723 (N = 191)   0.35 (N = 1023)
# 3   0.077 (N = 130)  0.697 (N = 333)  0.743 (N = 191)  0.373 (N = 1023)
# 4   0.281 (N = 111)  0.442 (N = 291)  0.569 (N = 165)   0.184 (N = 890)
# 5   0.023 (N = 111)  0.602 (N = 291)  0.638 (N = 165)   0.092 (N = 890)
# 6   0.299 (N = 111)  0.493 (N = 291)  0.706 (N = 165)   0.419 (N = 890)
# 7   0.133 (N = 111)  0.582 (N = 291)  0.974 (N = 165)   0.221 (N = 890)
# 8    0.355 (N = 97)  0.233 (N = 254)  0.578 (N = 148)   0.165 (N = 782)
# 9    0.029 (N = 97)  0.447 (N = 254)  0.419 (N = 148)   0.058 (N = 782)
# 10   0.452 (N = 97)  0.476 (N = 254)  0.705 (N = 148)   0.444 (N = 782)
# 11   0.507 (N = 97)  0.751 (N = 254)  0.953 (N = 148)   0.292 (N = 782)
# 12  0.457 (N = 138)  0.805 (N = 368)  0.107 (N = 211)   0.27 (N = 1124)
# 13  0.203 (N = 138)   0.98 (N = 368)  0.184 (N = 211)  0.153 (N = 1124)
# 14  0.489 (N = 138)  0.947 (N = 368)  0.348 (N = 211)  0.311 (N = 1124)
# 15  0.025 (N = 138)  0.957 (N = 368)  0.362 (N = 211)  0.084 (N = 1124)
# 16  0.195 (N = 121)  0.152 (N = 326)  0.143 (N = 187)   0.004 (N = 994)
# 17  0.089 (N = 121)  0.332 (N = 326)   0.07 (N = 187)   0.003 (N = 994)
# 18  0.536 (N = 121)  0.367 (N = 326)  0.214 (N = 187)   0.155 (N = 994)
# 19  0.028 (N = 121)  0.393 (N = 326)   0.45 (N = 187)   0.041 (N = 994)
# 20  0.679 (N = 108)  0.267 (N = 290)  0.446 (N = 170)    0.26 (N = 883)
# 21  0.446 (N = 108)  0.365 (N = 290)  0.197 (N = 170)   0.109 (N = 883)
# 22  0.766 (N = 108)  0.594 (N = 290)  0.384 (N = 170)   0.512 (N = 883)
# 23  0.115 (N = 108)  0.694 (N = 290)   0.38 (N = 170)   0.232 (N = 883)
# 24  0.488 (N = 142)  0.163 (N = 376)  0.408 (N = 215)  0.091 (N = 1151)
# 25  0.162 (N = 142)  0.655 (N = 376)  0.213 (N = 215)  0.032 (N = 1151)
# 26  0.294 (N = 142)  0.608 (N = 376)  0.361 (N = 215)  0.174 (N = 1151)
# 27  0.006 (N = 142)  0.612 (N = 376)  0.372 (N = 215)  0.032 (N = 1151)
# 28   0.71 (N = 124)  0.631 (N = 336)   0.55 (N = 189)  0.492 (N = 1018)
# 29  0.518 (N = 124)   0.87 (N = 336)  0.447 (N = 189)  0.389 (N = 1018)
# 30  0.573 (N = 124)  0.778 (N = 336)  0.664 (N = 189)  0.551 (N = 1018)
# 31  0.008 (N = 124)  0.665 (N = 336)  0.615 (N = 189)  0.129 (N = 1018)
# 32  0.884 (N = 112)  0.608 (N = 302)  0.399 (N = 169)    0.66 (N = 913)
# 33  0.481 (N = 112)  0.901 (N = 302)  0.321 (N = 169)    0.63 (N = 913)
# 34  0.803 (N = 112)  0.757 (N = 302)  0.519 (N = 169)   0.462 (N = 913)
# 35  0.123 (N = 112)  0.829 (N = 302)  0.552 (N = 169)   0.175 (N = 913)
# 36  0.282 (N = 144)   0.06 (N = 375)  0.496 (N = 220)  0.057 (N = 1166)
# 37  0.191 (N = 144)   0.27 (N = 375)  0.087 (N = 220)  0.039 (N = 1166)
# 38  0.267 (N = 144)  0.403 (N = 375)  0.091 (N = 220)  0.043 (N = 1166)
# 39  0.021 (N = 144)  0.513 (N = 375)  0.387 (N = 220)  0.058 (N = 1166)
# 40  0.176 (N = 131)  0.214 (N = 337)  0.258 (N = 194)  0.033 (N = 1043)
# 41  0.057 (N = 131)  0.553 (N = 337)  0.202 (N = 194)  0.081 (N = 1043)
# 42  0.173 (N = 131)  0.501 (N = 337)  0.354 (N = 194)  0.095 (N = 1043)
# 43  0.019 (N = 131)  0.324 (N = 337)  0.426 (N = 194)  0.083 (N = 1043)
# 44  0.666 (N = 114)  0.162 (N = 302)  0.242 (N = 169)   0.305 (N = 925)
# 45  0.318 (N = 114)  0.649 (N = 302)  0.152 (N = 169)   0.308 (N = 925)
# 46   0.73 (N = 114)  0.584 (N = 302)  0.481 (N = 169)   0.387 (N = 925)
# 47  0.174 (N = 114)  0.437 (N = 302)  0.648 (N = 169)   0.213 (N = 925)
# 48  0.208 (N = 148)  0.284 (N = 382)  0.287 (N = 222)   0.17 (N = 1176)
# 49  0.066 (N = 148)  0.791 (N = 382)  0.325 (N = 222)   0.12 (N = 1176)
# 50  0.165 (N = 148)  0.878 (N = 382)  0.387 (N = 222)  0.366 (N = 1176)
# 51  0.015 (N = 148)  0.818 (N = 382)  0.494 (N = 222)  0.253 (N = 1176)
# 52  0.278 (N = 132)  0.489 (N = 342)  0.625 (N = 195)  0.329 (N = 1048)
# 53  0.114 (N = 132)   0.55 (N = 342)  0.479 (N = 195)  0.174 (N = 1048)
# 54  0.294 (N = 132)  0.756 (N = 342)  0.875 (N = 195)  0.446 (N = 1048)
# 55  0.009 (N = 132)  0.605 (N = 342)  0.935 (N = 195)  0.493 (N = 1048)
# 56  0.182 (N = 116)  0.273 (N = 305)    0.5 (N = 175)   0.267 (N = 932)
# 57  0.058 (N = 116)  0.676 (N = 305)  0.354 (N = 175)   0.216 (N = 932)
# 58  0.109 (N = 116)  0.812 (N = 305)  0.423 (N = 175)   0.165 (N = 932)
# 59  0.003 (N = 116)  0.625 (N = 305)  0.739 (N = 175)     0.2 (N = 932)

# %%
dfs_resumen_lv[1]
# Out:
#                     Indicador         Alemania           Espana  \
# 0   Frac. Difícil LV h1 p4 c3  0.415 (N = 204)  0.683 (N = 242)
# 1   Frac. Difícil LV h1 p5 c3  0.871 (N = 204)   0.32 (N = 242)
# 2   Frac. Difícil LV h1 p6 c3  0.899 (N = 204)  0.158 (N = 242)
# 3   Frac. Difícil LV h1 p7 c3  0.968 (N = 204)  0.434 (N = 242)
# 4   Frac. Difícil LV h1 p4 c4  0.906 (N = 187)  0.034 (N = 218)
# 5   Frac. Difícil LV h1 p5 c4  0.525 (N = 187)   0.07 (N = 218)
# 6   Frac. Difícil LV h1 p6 c4  0.616 (N = 187)   0.13 (N = 218)
# 7   Frac. Difícil LV h1 p7 c4  0.605 (N = 187)  0.145 (N = 218)
# 8   Frac. Difícil LV h1 p4 c5  0.878 (N = 170)  0.446 (N = 197)
# 9   Frac. Difícil LV h1 p5 c5  0.817 (N = 170)  0.493 (N = 197)
# 10  Frac. Difícil LV h1 p6 c5  0.867 (N = 170)  0.401 (N = 197)
# 11  Frac. Difícil LV h1 p7 c5  0.935 (N = 170)   0.28 (N = 197)
# 12  Frac. Difícil LV h2 p4 c3  0.842 (N = 208)  0.656 (N = 246)
# 13  Frac. Difícil LV h2 p5 c3  0.573 (N = 208)  0.239 (N = 246)
# 14  Frac. Difícil LV h2 p6 c3  0.646 (N = 208)  0.372 (N = 246)
# 15  Frac. Difícil LV h2 p7 c3  0.138 (N = 208)   0.62 (N = 246)
# 16  Frac. Difícil LV h2 p4 c4  0.587 (N = 187)  0.563 (N = 226)
# 17  Frac. Difícil LV h2 p5 c4  0.645 (N = 187)  0.572 (N = 226)
# 18  Frac. Difícil LV h2 p6 c4  0.822 (N = 187)  0.397 (N = 226)
# 19  Frac. Difícil LV h2 p7 c4  0.754 (N = 187)  0.678 (N = 226)
# 20  Frac. Difícil LV h2 p4 c5  0.527 (N = 171)   0.59 (N = 204)
# 21  Frac. Difícil LV h2 p5 c5  0.819 (N = 171)  0.857 (N = 204)
# 22  Frac. Difícil LV h2 p6 c5  0.595 (N = 171)  0.839 (N = 204)
# 23  Frac. Difícil LV h2 p7 c5  0.686 (N = 171)  0.753 (N = 204)
# 24  Frac. Difícil LV h3 p4 c3  0.969 (N = 206)  0.198 (N = 249)
# 25  Frac. Difícil LV h3 p5 c3  0.825 (N = 206)  0.069 (N = 249)
# 26  Frac. Difícil LV h3 p6 c3  0.759 (N = 206)  0.294 (N = 249)
# 27  Frac. Difícil LV h3 p7 c3  0.548 (N = 206)  0.314 (N = 249)
# 28  Frac. Difícil LV h3 p4 c4  0.876 (N = 191)  0.938 (N = 228)
# 29  Frac. Difícil LV h3 p5 c4  0.741 (N = 191)   0.95 (N = 228)
# 30  Frac. Difícil LV h3 p6 c4  0.644 (N = 191)  0.891 (N = 228)
# 31  Frac. Difícil LV h3 p7 c4  0.389 (N = 191)  0.801 (N = 228)
# 32  Frac. Difícil LV h3 p4 c5  0.893 (N = 175)  0.929 (N = 204)
# 33  Frac. Difícil LV h3 p5 c5   0.46 (N = 175)  0.777 (N = 204)
# 34  Frac. Difícil LV h3 p6 c5  0.643 (N = 175)  0.765 (N = 204)
# 35  Frac. Difícil LV h3 p7 c5  0.578 (N = 175)  0.596 (N = 204)
# 36  Frac. Difícil LV h4 p4 c3  0.742 (N = 212)  0.171 (N = 250)
# 37  Frac. Difícil LV h4 p5 c3  0.606 (N = 212)  0.079 (N = 250)
# 38  Frac. Difícil LV h4 p6 c3  0.487 (N = 212)    0.2 (N = 250)
# 39  Frac. Difícil LV h4 p7 c3  0.287 (N = 212)  0.293 (N = 250)
# 40  Frac. Difícil LV h4 p4 c4  0.677 (N = 194)  0.626 (N = 233)
# 41  Frac. Difícil LV h4 p5 c4  0.481 (N = 194)  0.667 (N = 233)
# 42  Frac. Difícil LV h4 p6 c4  0.217 (N = 194)  0.428 (N = 233)
# 43  Frac. Difícil LV h4 p7 c4  0.173 (N = 194)  0.318 (N = 233)
# 44  Frac. Difícil LV h4 p4 c5   0.51 (N = 172)  0.504 (N = 209)
# 45  Frac. Difícil LV h4 p5 c5  0.225 (N = 172)  0.355 (N = 209)
# 46  Frac. Difícil LV h4 p6 c5  0.182 (N = 172)    0.4 (N = 209)
# 47  Frac. Difícil LV h4 p7 c5  0.052 (N = 172)  0.162 (N = 209)
# 48  Frac. Difícil LV h5 p4 c3  0.894 (N = 213)  0.593 (N = 247)
# 49  Frac. Difícil LV h5 p5 c3  0.816 (N = 213)  0.289 (N = 247)
# 50  Frac. Difícil LV h5 p6 c3  0.611 (N = 213)  0.585 (N = 247)
# 51  Frac. Difícil LV h5 p7 c3  0.424 (N = 213)   0.17 (N = 247)
# 52  Frac. Difícil LV h5 p4 c4  0.883 (N = 194)  0.382 (N = 229)
# 53  Frac. Difícil LV h5 p5 c4  0.577 (N = 194)  0.246 (N = 229)
# 54  Frac. Difícil LV h5 p6 c4  0.294 (N = 194)  0.197 (N = 229)
# 55  Frac. Difícil LV h5 p7 c4  0.331 (N = 194)   0.05 (N = 229)
# 56  Frac. Difícil LV h5 p4 c5  0.794 (N = 178)  0.437 (N = 215)
# 57  Frac. Difícil LV h5 p5 c5  0.653 (N = 178)  0.306 (N = 215)
# 58  Frac. Difícil LV h5 p6 c5  0.429 (N = 178)  0.238 (N = 215)
# 59  Frac. Difícil LV h5 p7 c5  0.382 (N = 178)  0.111 (N = 215)
#
#             Francia       Inglaterra           Italia               All
# 0   0.492 (N = 157)  0.944 (N = 401)  0.389 (N = 241)  0.862 (N = 1245)
# 1   0.446 (N = 157)  0.844 (N = 401)  0.027 (N = 241)  0.488 (N = 1245)
# 2   0.619 (N = 157)  0.547 (N = 401)  0.072 (N = 241)  0.431 (N = 1245)
# 3   0.801 (N = 157)  0.384 (N = 401)  0.028 (N = 241)  0.602 (N = 1245)
# 4   0.649 (N = 145)  0.864 (N = 370)  0.812 (N = 219)  0.733 (N = 1139)
# 5   0.455 (N = 145)  0.432 (N = 370)  0.274 (N = 219)   0.13 (N = 1139)
# 6    0.35 (N = 145)  0.421 (N = 370)  0.763 (N = 219)  0.314 (N = 1139)
# 7   0.606 (N = 145)  0.469 (N = 370)  0.419 (N = 219)  0.348 (N = 1139)
# 8   0.531 (N = 131)  0.823 (N = 338)  0.586 (N = 203)  0.866 (N = 1039)
# 9   0.242 (N = 131)  0.321 (N = 338)  0.185 (N = 203)  0.283 (N = 1039)
# 10  0.308 (N = 131)  0.196 (N = 338)  0.377 (N = 203)  0.304 (N = 1039)
# 11  0.347 (N = 131)  0.233 (N = 338)  0.419 (N = 203)  0.313 (N = 1039)
# 12   0.45 (N = 159)  0.938 (N = 408)  0.348 (N = 238)   0.93 (N = 1259)
# 13   0.58 (N = 159)  0.547 (N = 408)  0.027 (N = 238)  0.259 (N = 1259)
# 14   0.53 (N = 159)  0.352 (N = 408)  0.121 (N = 238)  0.316 (N = 1259)
# 15  0.761 (N = 159)  0.185 (N = 408)  0.067 (N = 238)  0.183 (N = 1259)
# 16  0.646 (N = 147)  0.886 (N = 375)  0.535 (N = 221)  0.909 (N = 1156)
# 17  0.833 (N = 147)  0.064 (N = 375)  0.181 (N = 221)  0.369 (N = 1156)
# 18  0.818 (N = 147)  0.086 (N = 375)  0.386 (N = 221)  0.451 (N = 1156)
# 19  0.733 (N = 147)  0.142 (N = 375)  0.652 (N = 221)  0.655 (N = 1156)
# 20  0.591 (N = 134)  0.523 (N = 350)   0.56 (N = 203)  0.748 (N = 1062)
# 21  0.702 (N = 134)  0.025 (N = 350)  0.355 (N = 203)  0.422 (N = 1062)
# 22  0.709 (N = 134)  0.137 (N = 350)  0.101 (N = 203)    0.4 (N = 1062)
# 23  0.771 (N = 134)  0.047 (N = 350)  0.275 (N = 203)  0.336 (N = 1062)
# 24  0.695 (N = 163)  0.974 (N = 408)  0.349 (N = 242)  0.949 (N = 1268)
# 25  0.529 (N = 163)  0.291 (N = 408)  0.134 (N = 242)  0.226 (N = 1268)
# 26  0.118 (N = 163)  0.233 (N = 408)  0.255 (N = 242)  0.196 (N = 1268)
# 27  0.091 (N = 163)  0.133 (N = 408)  0.264 (N = 242)  0.094 (N = 1268)
# 28  0.675 (N = 150)   0.87 (N = 384)  0.566 (N = 226)  0.987 (N = 1179)
# 29  0.466 (N = 150)  0.075 (N = 384)  0.043 (N = 226)  0.347 (N = 1179)
# 30  0.112 (N = 150)  0.154 (N = 384)  0.043 (N = 226)  0.182 (N = 1179)
# 31  0.138 (N = 150)  0.176 (N = 384)  0.114 (N = 226)  0.153 (N = 1179)
# 32  0.869 (N = 141)  0.367 (N = 350)  0.664 (N = 207)  0.967 (N = 1077)
# 33   0.79 (N = 141)  0.055 (N = 350)  0.064 (N = 207)  0.245 (N = 1077)
# 34  0.142 (N = 141)  0.369 (N = 350)  0.057 (N = 207)  0.258 (N = 1077)
# 35  0.325 (N = 141)  0.294 (N = 350)  0.127 (N = 207)  0.253 (N = 1077)
# 36  0.817 (N = 162)  0.856 (N = 408)  0.251 (N = 243)  0.725 (N = 1275)
# 37  0.356 (N = 162)  0.137 (N = 408)  0.021 (N = 243)  0.028 (N = 1275)
# 38  0.342 (N = 162)  0.096 (N = 408)  0.441 (N = 243)  0.122 (N = 1275)
# 39    0.1 (N = 162)  0.119 (N = 408)  0.478 (N = 243)  0.074 (N = 1275)
# 40  0.935 (N = 152)  0.814 (N = 386)  0.322 (N = 226)  0.925 (N = 1191)
# 41  0.448 (N = 152)  0.093 (N = 386)  0.069 (N = 226)  0.192 (N = 1191)
# 42  0.082 (N = 152)  0.101 (N = 386)   0.39 (N = 226)  0.073 (N = 1191)
# 43  0.069 (N = 152)  0.126 (N = 386)  0.333 (N = 226)  0.039 (N = 1191)
# 44  0.743 (N = 143)  0.737 (N = 354)  0.627 (N = 208)  0.863 (N = 1086)
# 45  0.517 (N = 143)  0.108 (N = 354)  0.151 (N = 208)  0.094 (N = 1086)
# 46  0.179 (N = 143)  0.347 (N = 354)   0.28 (N = 208)  0.118 (N = 1086)
# 47  0.519 (N = 143)  0.418 (N = 354)  0.445 (N = 208)  0.085 (N = 1086)
# 48  0.728 (N = 161)  0.941 (N = 410)  0.294 (N = 244)  0.955 (N = 1275)
# 49  0.208 (N = 161)  0.562 (N = 410)  0.127 (N = 244)  0.333 (N = 1275)
# 50  0.227 (N = 161)  0.505 (N = 410)  0.626 (N = 244)  0.618 (N = 1275)
# 51  0.122 (N = 161)   0.44 (N = 410)  0.688 (N = 244)  0.245 (N = 1275)
# 52  0.596 (N = 151)  0.898 (N = 387)  0.326 (N = 226)  0.856 (N = 1187)
# 53  0.071 (N = 151)  0.135 (N = 387)  0.039 (N = 226)  0.025 (N = 1187)
# 54  0.187 (N = 151)  0.143 (N = 387)  0.146 (N = 226)   0.04 (N = 1187)
# 55  0.431 (N = 151)  0.068 (N = 387)  0.399 (N = 226)  0.028 (N = 1187)
# 56  0.367 (N = 142)   0.43 (N = 354)  0.759 (N = 210)  0.718 (N = 1099)
# 57  0.151 (N = 142)  0.048 (N = 354)  0.268 (N = 210)  0.072 (N = 1099)
# 58  0.128 (N = 142)  0.163 (N = 354)  0.277 (N = 210)  0.083 (N = 1099)
# 59  0.404 (N = 142)  0.153 (N = 354)  0.321 (N = 210)  0.063 (N = 1099)
