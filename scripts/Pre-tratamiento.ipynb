# %%
# Librerías de siempre
import pandas as pd
import numpy as np
import os
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
def formatear_base(df):
    equipos = df['Local'].value_counts().index.tolist()
    equipos = pd.DataFrame(equipos, columns=['equipo'])
    equipos['i'] = equipos.index
    dict_equipos = dict(zip(equipos['i'].tolist(), equipos['equipo'].tolist()))
    df = pd.merge(df, equipos, left_on='Local', right_on='equipo', how='left')
    df = df.rename(columns = {'i': 'i_local'}).drop('equipo', 1)
    df = pd.merge(df, equipos, left_on='Visita', right_on='equipo', how='left')
    df = df.rename(columns = {'i': 'i_visita'}).drop('equipo', 1)
    return df

# %%
def tabla_final_torneo(db):
    torneo = db['Torneo'].drop_duplicates().tolist()[0]
    df = db.copy().reset_index(drop=True)
    df = formatear_base(df)
    tabla = df[['Local','i_local']].drop_duplicates()
    tabla = tabla.set_index(['i_local'])
    tabla.columns = ['equipo']
    conditions = [
            (df['goles L'] > df['goles V']),
            (df['goles L'] < df['goles V'])]
    choices = ['local', 'visita']
    df = df.join(pd.get_dummies(np.select(conditions, choices, default = 'empate')))
    ghome = df.groupby('i_local')
    gaway = df.groupby('i_visita')
    df_home = pd.DataFrame({'wins_h': ghome['local'].sum(),
                            'draws_h': ghome['empate'].sum(),
                            'losses_h': ghome['visita'].sum(),
                            'gf_h': ghome['goles L'].sum(),
                            'ga_h': ghome['goles V'].sum(),
                            'gd_h': ghome['goles L'].sum() - ghome['goles V'].sum(),
                            'promoccup': ghome['Occupation'].mean()})
    df_away = pd.DataFrame({'wins_a': gaway['visita'].sum(),
                            'draws_a': gaway['empate'].sum(),
                            'losses_a': gaway['local'].sum(),
                            'gf_a': gaway['goles V'].sum(),
                            'ga_a': gaway['goles L'].sum(),
                            'gd_a': gaway['goles V'].sum() - gaway['goles L'].sum()})
    tabla = tabla.join(df_home, how='left').join(df_away,how = 'left').fillna(0)
    tabla['wins'] = tabla.wins_h + tabla.wins_a
    tabla['draws'] = tabla.draws_h + tabla.draws_a
    tabla['losses'] = tabla.losses_h + tabla.losses_a
    tabla['gf'] = tabla.gf_h + tabla.gf_a
    tabla['ga'] = tabla.ga_h + tabla.ga_a
    tabla['gd'] = tabla.gd_h + tabla.gd_a
    tabla['points'] = (tabla['wins']*3 + tabla['draws']).astype(int)
    tabla = tabla.sort_values(by=['points','gd'], ascending = False).reset_index(drop=True)
    tabla['position'] = (tabla.index + 1).astype(int)
    tabla['Torneo'] = torneo
    return tabla[['equipo','Torneo','position','points', 'promoccup']]

# %%
def ConstruirDatosPreTratamiento(regdir,
                                 ligasdir,
                                 ligas = ['Alemania','Espana','Francia','Inglaterra','Italia']):
    dfs_pretrat = []
    for liga in ligas:
        archivo = liga + '.xlsx'
        df = pd.read_excel(os.path.join(regdir, archivo))
        torneos = df['Torneo'].drop_duplicates().tolist()
        df_ant = pd.read_excel(os.path.join(ligasdir, archivo))
        torneos_ant = df_ant['Torneo'].drop_duplicates().tolist()[:-1]
        dicttorant = dict(zip(torneos,torneos_ant))
        df['Torneo ant'] = [dicttorant[t] for t in df['Torneo'].tolist()]
        
        df_ant['Occupation'] = np.where(df_ant['Capacity'] > 0,
                                        np.minimum(df_ant['Attendance']/df_ant['Capacity'], 1),
                                        np.nan) 
        dfs_tablas = []
        for torneo in torneos_ant:
            test = tabla_final_torneo(df_ant[df_ant['Torneo'] == torneo].reset_index(drop=True))
            dfs_tablas.append(test)
        df_tablas_ant = pd.concat(dfs_tablas, ignore_index = True)
        df_tablas_ant.columns = ['equipo','Torneo ant','position_ant','points_ant', 'promoccup_ant']
        df = df.merge(df_tablas_ant,
              how = 'left',
              left_on = ['equipo','Torneo ant'],
              right_on = ['equipo', 'Torneo ant'])
        df = df[['equipo','Torneo'] + [i for i in df.columns if 'perc_' in i and 'corr' not in i] + [i for i in df.columns if '_ant' in i]]
        df = df.dropna().reset_index(drop=True)
        dfs_pretrat.append(df)
    return dfs_pretrat

# %%
regdir = os.path.join(os.path.pardir,
                      'datos',
                      'regresiones')
ligasdir = os.path.join(os.path.pardir,
                        'datos',
                        'ligas')
dfs_pretrat = ConstruirDatosPreTratamiento(regdir, ligasdir)

# %%
dfs_pretrat[0].columns.tolist()
# Out:
# ['equipo',
#  'Torneo',
#  'perc_facil_elo_p4_c3',
#  'perc_dificil_elo_p4_c3',
#  'perc_facil_elo_p5_c3',
#  'perc_dificil_elo_p5_c3',
#  'perc_facil_elo_p6_c3',
#  'perc_dificil_elo_p6_c3',
#  'perc_facil_elo_p7_c3',
#  'perc_dificil_elo_p7_c3',
#  'perc_facil_elo_p4_c4',
#  'perc_dificil_elo_p4_c4',
#  'perc_facil_elo_p5_c4',
#  'perc_dificil_elo_p5_c4',
#  'perc_facil_elo_p6_c4',
#  'perc_dificil_elo_p6_c4',
#  'perc_facil_elo_p7_c4',
#  'perc_dificil_elo_p7_c4',
#  'perc_facil_elo_p4_c5',
#  'perc_dificil_elo_p4_c5',
#  'perc_facil_elo_p5_c5',
#  'perc_dificil_elo_p5_c5',
#  'perc_facil_elo_p6_c5',
#  'perc_dificil_elo_p6_c5',
#  'perc_facil_elo_p7_c5',
#  'perc_dificil_elo_p7_c5',
#  'perc_facil_general_h1_p4_c3',
#  'perc_dificil_general_h1_p4_c3',
#  'perc_facil_lv_h1_p4_c3',
#  'perc_dificil_lv_h1_p4_c3',
#  'perc_facil_general_h1_p5_c3',
#  'perc_dificil_general_h1_p5_c3',
#  'perc_facil_lv_h1_p5_c3',
#  'perc_dificil_lv_h1_p5_c3',
#  'perc_facil_general_h1_p6_c3',
#  'perc_dificil_general_h1_p6_c3',
#  'perc_facil_lv_h1_p6_c3',
#  'perc_dificil_lv_h1_p6_c3',
#  'perc_facil_general_h1_p7_c3',
#  'perc_dificil_general_h1_p7_c3',
#  'perc_facil_lv_h1_p7_c3',
#  'perc_dificil_lv_h1_p7_c3',
#  'perc_facil_general_h1_p4_c4',
#  'perc_dificil_general_h1_p4_c4',
#  'perc_facil_lv_h1_p4_c4',
#  'perc_dificil_lv_h1_p4_c4',
#  'perc_facil_general_h1_p5_c4',
#  'perc_dificil_general_h1_p5_c4',
#  'perc_facil_lv_h1_p5_c4',
#  'perc_dificil_lv_h1_p5_c4',
#  'perc_facil_general_h1_p6_c4',
#  'perc_dificil_general_h1_p6_c4',
#  'perc_facil_lv_h1_p6_c4',
#  'perc_dificil_lv_h1_p6_c4',
#  'perc_facil_general_h1_p7_c4',
#  'perc_dificil_general_h1_p7_c4',
#  'perc_facil_lv_h1_p7_c4',
#  'perc_dificil_lv_h1_p7_c4',
#  'perc_facil_general_h1_p4_c5',
#  'perc_dificil_general_h1_p4_c5',
#  'perc_facil_lv_h1_p4_c5',
#  'perc_dificil_lv_h1_p4_c5',
#  'perc_facil_general_h1_p5_c5',
#  'perc_dificil_general_h1_p5_c5',
#  'perc_facil_lv_h1_p5_c5',
#  'perc_dificil_lv_h1_p5_c5',
#  'perc_facil_general_h1_p6_c5',
#  'perc_dificil_general_h1_p6_c5',
#  'perc_facil_lv_h1_p6_c5',
#  'perc_dificil_lv_h1_p6_c5',
#  'perc_facil_general_h1_p7_c5',
#  'perc_dificil_general_h1_p7_c5',
#  'perc_facil_lv_h1_p7_c5',
#  'perc_dificil_lv_h1_p7_c5',
#  'perc_facil_general_h2_p4_c3',
#  'perc_dificil_general_h2_p4_c3',
#  'perc_facil_lv_h2_p4_c3',
#  'perc_dificil_lv_h2_p4_c3',
#  'perc_facil_general_h2_p5_c3',
#  'perc_dificil_general_h2_p5_c3',
#  'perc_facil_lv_h2_p5_c3',
#  'perc_dificil_lv_h2_p5_c3',
#  'perc_facil_general_h2_p6_c3',
#  'perc_dificil_general_h2_p6_c3',
#  'perc_facil_lv_h2_p6_c3',
#  'perc_dificil_lv_h2_p6_c3',
#  'perc_facil_general_h2_p7_c3',
#  'perc_dificil_general_h2_p7_c3',
#  'perc_facil_lv_h2_p7_c3',
#  'perc_dificil_lv_h2_p7_c3',
#  'perc_facil_general_h2_p4_c4',
#  'perc_dificil_general_h2_p4_c4',
#  'perc_facil_lv_h2_p4_c4',
#  'perc_dificil_lv_h2_p4_c4',
#  'perc_facil_general_h2_p5_c4',
#  'perc_dificil_general_h2_p5_c4',
#  'perc_facil_lv_h2_p5_c4',
#  'perc_dificil_lv_h2_p5_c4',
#  'perc_facil_general_h2_p6_c4',
#  'perc_dificil_general_h2_p6_c4',
#  'perc_facil_lv_h2_p6_c4',
#  'perc_dificil_lv_h2_p6_c4',
#  'perc_facil_general_h2_p7_c4',
#  'perc_dificil_general_h2_p7_c4',
#  'perc_facil_lv_h2_p7_c4',
#  'perc_dificil_lv_h2_p7_c4',
#  'perc_facil_general_h2_p4_c5',
#  'perc_dificil_general_h2_p4_c5',
#  'perc_facil_lv_h2_p4_c5',
#  'perc_dificil_lv_h2_p4_c5',
#  'perc_facil_general_h2_p5_c5',
#  'perc_dificil_general_h2_p5_c5',
#  'perc_facil_lv_h2_p5_c5',
#  'perc_dificil_lv_h2_p5_c5',
#  'perc_facil_general_h2_p6_c5',
#  'perc_dificil_general_h2_p6_c5',
#  'perc_facil_lv_h2_p6_c5',
#  'perc_dificil_lv_h2_p6_c5',
#  'perc_facil_general_h2_p7_c5',
#  'perc_dificil_general_h2_p7_c5',
#  'perc_facil_lv_h2_p7_c5',
#  'perc_dificil_lv_h2_p7_c5',
#  'perc_facil_general_h3_p4_c3',
#  'perc_dificil_general_h3_p4_c3',
#  'perc_facil_lv_h3_p4_c3',
#  'perc_dificil_lv_h3_p4_c3',
#  'perc_facil_general_h3_p5_c3',
#  'perc_dificil_general_h3_p5_c3',
#  'perc_facil_lv_h3_p5_c3',
#  'perc_dificil_lv_h3_p5_c3',
#  'perc_facil_general_h3_p6_c3',
#  'perc_dificil_general_h3_p6_c3',
#  'perc_facil_lv_h3_p6_c3',
#  'perc_dificil_lv_h3_p6_c3',
#  'perc_facil_general_h3_p7_c3',
#  'perc_dificil_general_h3_p7_c3',
#  'perc_facil_lv_h3_p7_c3',
#  'perc_dificil_lv_h3_p7_c3',
#  'perc_facil_general_h3_p4_c4',
#  'perc_dificil_general_h3_p4_c4',
#  'perc_facil_lv_h3_p4_c4',
#  'perc_dificil_lv_h3_p4_c4',
#  'perc_facil_general_h3_p5_c4',
#  'perc_dificil_general_h3_p5_c4',
#  'perc_facil_lv_h3_p5_c4',
#  'perc_dificil_lv_h3_p5_c4',
#  'perc_facil_general_h3_p6_c4',
#  'perc_dificil_general_h3_p6_c4',
#  'perc_facil_lv_h3_p6_c4',
#  'perc_dificil_lv_h3_p6_c4',
#  'perc_facil_general_h3_p7_c4',
#  'perc_dificil_general_h3_p7_c4',
#  'perc_facil_lv_h3_p7_c4',
#  'perc_dificil_lv_h3_p7_c4',
#  'perc_facil_general_h3_p4_c5',
#  'perc_dificil_general_h3_p4_c5',
#  'perc_facil_lv_h3_p4_c5',
#  'perc_dificil_lv_h3_p4_c5',
#  'perc_facil_general_h3_p5_c5',
#  'perc_dificil_general_h3_p5_c5',
#  'perc_facil_lv_h3_p5_c5',
#  'perc_dificil_lv_h3_p5_c5',
#  'perc_facil_general_h3_p6_c5',
#  'perc_dificil_general_h3_p6_c5',
#  'perc_facil_lv_h3_p6_c5',
#  'perc_dificil_lv_h3_p6_c5',
#  'perc_facil_general_h3_p7_c5',
#  'perc_dificil_general_h3_p7_c5',
#  'perc_facil_lv_h3_p7_c5',
#  'perc_dificil_lv_h3_p7_c5',
#  'perc_facil_general_h4_p4_c3',
#  'perc_dificil_general_h4_p4_c3',
#  'perc_facil_lv_h4_p4_c3',
#  'perc_dificil_lv_h4_p4_c3',
#  'perc_facil_general_h4_p5_c3',
#  'perc_dificil_general_h4_p5_c3',
#  'perc_facil_lv_h4_p5_c3',
#  'perc_dificil_lv_h4_p5_c3',
#  'perc_facil_general_h4_p6_c3',
#  'perc_dificil_general_h4_p6_c3',
#  'perc_facil_lv_h4_p6_c3',
#  'perc_dificil_lv_h4_p6_c3',
#  'perc_facil_general_h4_p7_c3',
#  'perc_dificil_general_h4_p7_c3',
#  'perc_facil_lv_h4_p7_c3',
#  'perc_dificil_lv_h4_p7_c3',
#  'perc_facil_general_h4_p4_c4',
#  'perc_dificil_general_h4_p4_c4',
#  'perc_facil_lv_h4_p4_c4',
#  'perc_dificil_lv_h4_p4_c4',
#  'perc_facil_general_h4_p5_c4',
#  'perc_dificil_general_h4_p5_c4',
#  'perc_facil_lv_h4_p5_c4',
#  'perc_dificil_lv_h4_p5_c4',
#  'perc_facil_general_h4_p6_c4',
#  'perc_dificil_general_h4_p6_c4',
#  'perc_facil_lv_h4_p6_c4',
#  'perc_dificil_lv_h4_p6_c4',
#  'perc_facil_general_h4_p7_c4',
#  'perc_dificil_general_h4_p7_c4',
#  'perc_facil_lv_h4_p7_c4',
#  'perc_dificil_lv_h4_p7_c4',
#  'perc_facil_general_h4_p4_c5',
#  'perc_dificil_general_h4_p4_c5',
#  'perc_facil_lv_h4_p4_c5',
#  'perc_dificil_lv_h4_p4_c5',
#  'perc_facil_general_h4_p5_c5',
#  'perc_dificil_general_h4_p5_c5',
#  'perc_facil_lv_h4_p5_c5',
#  'perc_dificil_lv_h4_p5_c5',
#  'perc_facil_general_h4_p6_c5',
#  'perc_dificil_general_h4_p6_c5',
#  'perc_facil_lv_h4_p6_c5',
#  'perc_dificil_lv_h4_p6_c5',
#  'perc_facil_general_h4_p7_c5',
#  'perc_dificil_general_h4_p7_c5',
#  'perc_facil_lv_h4_p7_c5',
#  'perc_dificil_lv_h4_p7_c5',
#  'perc_facil_general_h5_p4_c3',
#  'perc_dificil_general_h5_p4_c3',
#  'perc_facil_lv_h5_p4_c3',
#  'perc_dificil_lv_h5_p4_c3',
#  'perc_facil_general_h5_p5_c3',
#  'perc_dificil_general_h5_p5_c3',
#  'perc_facil_lv_h5_p5_c3',
#  'perc_dificil_lv_h5_p5_c3',
#  'perc_facil_general_h5_p6_c3',
#  'perc_dificil_general_h5_p6_c3',
#  'perc_facil_lv_h5_p6_c3',
#  'perc_dificil_lv_h5_p6_c3',
#  'perc_facil_general_h5_p7_c3',
#  'perc_dificil_general_h5_p7_c3',
#  'perc_facil_lv_h5_p7_c3',
#  'perc_dificil_lv_h5_p7_c3',
#  'perc_facil_general_h5_p4_c4',
#  'perc_dificil_general_h5_p4_c4',
#  'perc_facil_lv_h5_p4_c4',
#  'perc_dificil_lv_h5_p4_c4',
#  'perc_facil_general_h5_p5_c4',
#  'perc_dificil_general_h5_p5_c4',
#  'perc_facil_lv_h5_p5_c4',
#  'perc_dificil_lv_h5_p5_c4',
#  'perc_facil_general_h5_p6_c4',
#  'perc_dificil_general_h5_p6_c4',
#  'perc_facil_lv_h5_p6_c4',
#  'perc_dificil_lv_h5_p6_c4',
#  'perc_facil_general_h5_p7_c4',
#  'perc_dificil_general_h5_p7_c4',
#  'perc_facil_lv_h5_p7_c4',
#  'perc_dificil_lv_h5_p7_c4',
#  'perc_facil_general_h5_p4_c5',
#  'perc_dificil_general_h5_p4_c5',
#  'perc_facil_lv_h5_p4_c5',
#  'perc_dificil_lv_h5_p4_c5',
#  'perc_facil_general_h5_p5_c5',
#  'perc_dificil_general_h5_p5_c5',
#  'perc_facil_lv_h5_p5_c5',
#  'perc_dificil_lv_h5_p5_c5',
#  'perc_facil_general_h5_p6_c5',
#  'perc_dificil_general_h5_p6_c5',
#  'perc_facil_lv_h5_p6_c5',
#  'perc_dificil_lv_h5_p6_c5',
#  'perc_facil_general_h5_p7_c5',
#  'perc_dificil_general_h5_p7_c5',
#  'perc_facil_lv_h5_p7_c5',
#  'perc_dificil_lv_h5_p7_c5',
#  'position_ant',
#  'points_ant',
#  'promoccup_ant']

# %%
tablas_text = """
"""

# Y = ['position_ant', 'points_ant', 'promoccup_ant']
# Y_print = ['Posición anterior', 'Puntos anterior', 'Prom. ocupación anterior']
Y = ['points_ant']
Y_print = ['Puntos anterior']
X = ['perc_facil_general_h%s_p%s_c%s',
     'perc_dificil_general_h%s_p%s_c%s',
     'perc_facil_lv_h%s_p%s_c%s',
     'perc_dificil_lv_h%s_p%s_c%s',
     'perc_facil_elo_p%s_c%s',
     'perc_dificil_elo_p%s_c%s']
X_print = ['Frac. Fácil General',
           'Frac. Difícil General',
           'Frac. Fácil LV',
           'Frac. Difícil LV',
           'Frac. Fácil ELO',
           'Frac. Difícil ELO']
X_sheet = ['FFG',
           'FDG',
           'FFLV',
           'FDLV',
           'FFELO',
           'FDELO']
ligas = ['Alemania','Espana','Francia','Inglaterra','Italia']

dfs_res = []
sheets = []
for h in range(1,6):
    for k in range(len(Y)):
        y = Y[k]
        means = []
        for j in range(len(X)):
            agregar = True
            x = X[j]
            if 'h' in x:
                sheets.append(X_sheet[j] + ' %s anterior' % h)
            else:
                sheets.append(X_sheet[j])
            for i in range(len(ligas)):
                resultados = []
                liga = ligas[i]
                df = dfs_pretrat[i]
                rl = []
                for r in [4,5,6,7]:
                    for l in [3,4,5]:
                        if h > 1 and 'h' not in x:
                            agregar = False
                            pass
                        elif h < 2 and 'h' not in x:
                            x_ = x % (r,l)
                            rl.append("$r = %s, l = %s$" % (r,l))
                        else:
                            x_ = x % (h,r,l)
                            rl.append("$h = %s, r = %s, l = %s$" % (h,r,l))
                        formula = '%s ~ C(%s)' % (y,x_)
                        model = ols(formula, data = df).fit()
                        aov_table = sm.stats.anova_lm(model, typ=2)
                        resultados.append(np.round(aov_table['PR(>F)'][0], decimals = 3))
                if agregar:
                    if i < 1:
                        df_res = pd.DataFrame({liga : resultados}, index = rl)
                    else:
                        df_res[liga] = resultados
            if agregar:
                tablas_text = tablas_text + df_res.to_latex()
                dfs_res.append(df_res)
                print('----------------------------------------------------------------------------------------')
                print('Análisis y = %s, x = %s para %s torneos anteriores' % (Y_print[k], X_print[j], h))
                print(df_res.to_latex())
outputdir = os.path.join(os.path.pardir, 'resultados','pretratamiento')
writer = pd.ExcelWriter(os.path.join(outputdir,'puntos-anterior.xlsx'), engine='xlsxwriter')
for df, sheet in zip(dfs_res, sheets):
    df.to_excel(writer, sheet_name = sheet)
writer.save()
#             means.append(df_res.mean().tolist())
#         df_means = pd.DataFrame(data = means, columns = ligas, index = X_print)
#         print('---------------------------------PROMEDIOS------------------------------------------')
#         print(df_means.to_latex())
# with open(os.path.join(os.path.pardir,'Tablas', 'tablaspretreatment.txt'),'w') as tf:
#     tf.write(tablas_text)
# Out:
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil General para 1 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 1, r = 4, l = 3\$ &     0.745 &   0.014 &    0.833 &       0.805 &   0.250 \\
# \$h = 1, r = 4, l = 4\$ &     0.599 &   0.021 &    0.887 &       0.912 &   0.055 \\
# \$h = 1, r = 4, l = 5\$ &     0.918 &   0.025 &    0.818 &       0.914 &   0.005 \\
# \$h = 1, r = 5, l = 3\$ &     0.676 &   0.035 &    0.542 &       0.300 &   0.065 \\
# \$h = 1, r = 5, l = 4\$ &     0.310 &   0.056 &    0.814 &       0.466 &   0.037 \\
# \$h = 1, r = 5, l = 5\$ &     0.642 &   0.066 &    0.918 &       0.797 &   0.007 \\
# \$h = 1, r = 6, l = 3\$ &     0.325 &   0.107 &    0.392 &       0.023 &   0.257 \\
# \$h = 1, r = 6, l = 4\$ &     0.196 &   0.046 &    0.349 &       0.147 &   0.006 \\
# \$h = 1, r = 6, l = 5\$ &     0.628 &   0.013 &    0.521 &       0.822 &   0.037 \\
# \$h = 1, r = 7, l = 3\$ &     0.949 &   0.902 &    0.703 &       0.174 &   0.074 \\
# \$h = 1, r = 7, l = 4\$ &     0.571 &   0.512 &    0.745 &       0.029 &   0.415 \\
# \$h = 1, r = 7, l = 5\$ &     0.844 &   0.181 &    0.236 &       0.700 &   0.138 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil General para 1 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 1, r = 4, l = 3\$ &     0.024 &   0.052 &    0.183 &       0.036 &   0.002 \\
# \$h = 1, r = 4, l = 4\$ &     0.022 &   0.015 &    0.007 &       0.015 &   0.005 \\
# \$h = 1, r = 4, l = 5\$ &     0.126 &   0.013 &    0.046 &       0.118 &   0.000 \\
# \$h = 1, r = 5, l = 3\$ &     0.019 &   0.013 &    0.077 &       0.083 &   0.000 \\
# \$h = 1, r = 5, l = 4\$ &     0.002 &   0.007 &    0.002 &       0.013 &   0.000 \\
# \$h = 1, r = 5, l = 5\$ &     0.009 &   0.014 &    0.039 &       0.033 &   0.000 \\
# \$h = 1, r = 6, l = 3\$ &     0.034 &   0.009 &    0.329 &       0.082 &   0.002 \\
# \$h = 1, r = 6, l = 4\$ &     0.032 &   0.009 &    0.031 &       0.099 &   0.001 \\
# \$h = 1, r = 6, l = 5\$ &     0.186 &   0.020 &    0.196 &       0.140 &   0.000 \\
# \$h = 1, r = 7, l = 3\$ &     0.003 &   0.092 &    0.016 &       0.041 &   0.000 \\
# \$h = 1, r = 7, l = 4\$ &     0.004 &   0.201 &    0.001 &       0.022 &   0.000 \\
# \$h = 1, r = 7, l = 5\$ &     0.200 &   0.330 &    0.016 &       0.028 &   0.000 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil LV para 1 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 1, r = 4, l = 3\$ &     0.624 &   0.004 &    0.312 &       0.024 &   0.106 \\
# \$h = 1, r = 4, l = 4\$ &     0.849 &   0.012 &    0.957 &       0.297 &   0.069 \\
# \$h = 1, r = 4, l = 5\$ &     0.409 &   0.077 &    0.594 &       0.358 &   0.109 \\
# \$h = 1, r = 5, l = 3\$ &     0.528 &   0.028 &    0.467 &       0.163 &   0.636 \\
# \$h = 1, r = 5, l = 4\$ &     0.630 &   0.002 &    0.983 &       0.916 &   0.347 \\
# \$h = 1, r = 5, l = 5\$ &     0.254 &   0.015 &    0.887 &       0.836 &   0.001 \\
# \$h = 1, r = 6, l = 3\$ &     0.661 &   0.012 &    0.160 &       0.514 &   0.742 \\
# \$h = 1, r = 6, l = 4\$ &     0.141 &   0.000 &    0.070 &       0.316 &   0.179 \\
# \$h = 1, r = 6, l = 5\$ &     0.384 &   0.009 &    0.348 &       0.517 &   0.063 \\
# \$h = 1, r = 7, l = 3\$ &     0.788 &   0.146 &    0.105 &       0.758 &   0.586 \\
# \$h = 1, r = 7, l = 4\$ &     0.325 &   0.091 &    0.148 &       0.367 &   0.153 \\
# \$h = 1, r = 7, l = 5\$ &     0.287 &   0.091 &    0.148 &       0.507 &   0.041 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil LV para 1 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 1, r = 4, l = 3\$ &     0.017 &   0.014 &    0.163 &       0.056 &   0.001 \\
# \$h = 1, r = 4, l = 4\$ &     0.035 &   0.039 &    0.089 &       0.013 &   0.000 \\
# \$h = 1, r = 4, l = 5\$ &     0.027 &   0.066 &    0.013 &       0.011 &   0.000 \\
# \$h = 1, r = 5, l = 3\$ &     0.025 &   0.007 &    0.077 &       0.042 &   0.000 \\
# \$h = 1, r = 5, l = 4\$ &     0.043 &   0.025 &    0.290 &       0.008 &   0.000 \\
# \$h = 1, r = 5, l = 5\$ &     0.004 &   0.017 &    0.129 &       0.020 &   0.000 \\
# \$h = 1, r = 6, l = 3\$ &     0.065 &   0.001 &    0.309 &       0.027 &   0.000 \\
# \$h = 1, r = 6, l = 4\$ &     0.008 &   0.015 &    0.271 &       0.010 &   0.000 \\
# \$h = 1, r = 6, l = 5\$ &     0.001 &   0.031 &    0.094 &       0.044 &   0.000 \\
# \$h = 1, r = 7, l = 3\$ &     0.016 &   0.029 &    0.042 &       0.004 &   0.000 \\
# \$h = 1, r = 7, l = 4\$ &     0.009 &   0.039 &    0.019 &       0.001 &   0.000 \\
# \$h = 1, r = 7, l = 5\$ &     0.004 &   0.041 &    0.005 &       0.019 &   0.000 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil ELO para 1 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$r = 4, l = 3\$ &     0.706 &   0.021 &    0.162 &       0.537 &   0.012 \\
# \$r = 4, l = 4\$ &     0.324 &   0.336 &    0.072 &       0.645 &   0.036 \\
# \$r = 4, l = 5\$ &     0.327 &   0.302 &    0.270 &       0.539 &   0.010 \\
# \$r = 5, l = 3\$ &     0.465 &   0.023 &    0.201 &       0.475 &   0.042 \\
# \$r = 5, l = 4\$ &     0.796 &   0.368 &    0.259 &       0.688 &   0.098 \\
# \$r = 5, l = 5\$ &     0.716 &   0.249 &    0.646 &       0.663 &   0.006 \\
# \$r = 6, l = 3\$ &     0.691 &   0.385 &    0.799 &       0.393 &   0.077 \\
# \$r = 6, l = 4\$ &     0.184 &   0.495 &    0.226 &       0.414 &   0.089 \\
# \$r = 6, l = 5\$ &     0.232 &   0.330 &    0.139 &       0.689 &   0.001 \\
# \$r = 7, l = 3\$ &     0.863 &   0.615 &    0.897 &       0.875 &   0.355 \\
# \$r = 7, l = 4\$ &     0.253 &   0.570 &    0.588 &       0.487 &   0.056 \\
# \$r = 7, l = 5\$ &     0.315 &   0.579 &    0.331 &       0.386 &   0.004 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil ELO para 1 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$r = 4, l = 3\$ &     0.296 &   0.006 &    0.053 &       0.018 &   0.000 \\
# \$r = 4, l = 4\$ &     0.260 &   0.056 &    0.140 &       0.012 &   0.033 \\
# \$r = 4, l = 5\$ &     0.608 &   0.005 &    0.161 &       0.083 &   0.005 \\
# \$r = 5, l = 3\$ &     0.018 &   0.002 &    0.092 &       0.270 &   0.000 \\
# \$r = 5, l = 4\$ &     0.052 &   0.014 &    0.085 &       0.040 &   0.007 \\
# \$r = 5, l = 5\$ &     0.206 &   0.002 &    0.071 &       0.099 &   0.002 \\
# \$r = 6, l = 3\$ &     0.201 &   0.002 &    0.302 &       0.253 &   0.000 \\
# \$r = 6, l = 4\$ &     0.183 &   0.010 &    0.255 &       0.062 &   0.002 \\
# \$r = 6, l = 5\$ &     0.338 &   0.008 &    0.136 &       0.221 &   0.003 \\
# \$r = 7, l = 3\$ &     0.057 &   0.053 &    0.003 &       0.060 &   0.000 \\
# \$r = 7, l = 4\$ &     0.054 &   0.080 &    0.003 &       0.030 &   0.001 \\
# \$r = 7, l = 5\$ &     0.557 &   0.053 &    0.004 &       0.027 &   0.003 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil General para 2 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 2, r = 4, l = 3\$ &     0.395 &   0.277 &    0.344 &       0.329 &   0.453 \\
# \$h = 2, r = 4, l = 4\$ &     0.605 &   0.190 &    0.662 &       0.390 &   0.400 \\
# \$h = 2, r = 4, l = 5\$ &     0.861 &   0.054 &    0.278 &       0.745 &   0.233 \\
# \$h = 2, r = 5, l = 3\$ &     0.635 &   0.227 &    0.710 &       0.736 &   0.700 \\
# \$h = 2, r = 5, l = 4\$ &     0.923 &   0.213 &    0.636 &       0.906 &   0.711 \\
# \$h = 2, r = 5, l = 5\$ &     0.952 &   0.079 &    0.171 &       0.895 &   0.432 \\
# \$h = 2, r = 6, l = 3\$ &     0.539 &   0.559 &    0.158 &       0.501 &   0.294 \\
# \$h = 2, r = 6, l = 4\$ &     0.818 &   0.350 &    0.273 &       0.714 &   0.840 \\
# \$h = 2, r = 6, l = 5\$ &     0.906 &   0.107 &    0.083 &       0.326 &   0.542 \\
# \$h = 2, r = 7, l = 3\$ &     0.404 &   0.983 &    0.390 &       0.796 &   0.811 \\
# \$h = 2, r = 7, l = 4\$ &     0.194 &   0.506 &    0.627 &       0.818 &   0.523 \\
# \$h = 2, r = 7, l = 5\$ &     0.838 &   0.654 &    0.177 &       0.560 &   0.381 \\
# \bottomrule
# \end{tabular}
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil General para 2 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 2, r = 4, l = 3\$ &     0.659 &   0.041 &    0.256 &       0.014 &   0.011 \\
# \$h = 2, r = 4, l = 4\$ &     0.210 &   0.019 &    0.196 &       0.015 &   0.006 \\
# \$h = 2, r = 4, l = 5\$ &     0.703 &   0.024 &    0.109 &       0.025 &   0.116 \\
# \$h = 2, r = 5, l = 3\$ &     0.233 &   0.011 &    0.105 &       0.071 &   0.001 \\
# \$h = 2, r = 5, l = 4\$ &     0.038 &   0.008 &    0.086 &       0.064 &   0.001 \\
# \$h = 2, r = 5, l = 5\$ &     0.272 &   0.018 &    0.031 &       0.022 &   0.060 \\
# \$h = 2, r = 6, l = 3\$ &     0.434 &   0.012 &    0.166 &       0.059 &   0.002 \\
# \$h = 2, r = 6, l = 4\$ &     0.311 &   0.008 &    0.074 &       0.144 &   0.003 \\
# \$h = 2, r = 6, l = 5\$ &     0.692 &   0.005 &    0.057 &       0.085 &   0.037 \\
# \$h = 2, r = 7, l = 3\$ &     0.074 &   0.176 &    0.069 &       0.027 &   0.004 \\
# \$h = 2, r = 7, l = 4\$ &     0.190 &   0.088 &    0.005 &       0.099 &   0.001 \\
# \$h = 2, r = 7, l = 5\$ &     0.584 &   0.091 &    0.008 &       0.006 &   0.015 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil LV para 2 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 2, r = 4, l = 3\$ &     0.461 &   0.129 &    0.257 &       0.388 &   0.423 \\
# \$h = 2, r = 4, l = 4\$ &     0.275 &   0.221 &    0.225 &       0.263 &   0.160 \\
# \$h = 2, r = 4, l = 5\$ &     0.329 &   0.304 &    0.455 &       0.184 &   0.156 \\
# \$h = 2, r = 5, l = 3\$ &     0.666 &   0.080 &    0.423 &       0.418 &   0.179 \\
# \$h = 2, r = 5, l = 4\$ &     0.316 &   0.062 &    0.363 &       0.255 &   0.115 \\
# \$h = 2, r = 5, l = 5\$ &     0.304 &   0.189 &    0.689 &       0.254 &   0.438 \\
# \$h = 2, r = 6, l = 3\$ &     0.796 &   0.218 &    0.079 &       0.898 &   0.026 \\
# \$h = 2, r = 6, l = 4\$ &     0.633 &   0.125 &    0.148 &       0.581 &   0.012 \\
# \$h = 2, r = 6, l = 5\$ &     0.355 &   0.265 &    0.240 &       0.915 &   0.214 \\
# \$h = 2, r = 7, l = 3\$ &     0.725 &   0.239 &    0.022 &       0.621 &   0.103 \\
# \$h = 2, r = 7, l = 4\$ &     0.622 &   0.232 &    0.011 &       0.762 &   0.397 \\
# \$h = 2, r = 7, l = 5\$ &     0.125 &   0.623 &    0.489 &       0.602 &   0.777 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil LV para 2 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 2, r = 4, l = 3\$ &     0.045 &   0.016 &    0.113 &       0.008 &   0.011 \\
# \$h = 2, r = 4, l = 4\$ &     0.294 &   0.031 &    0.106 &       0.001 &   0.001 \\
# \$h = 2, r = 4, l = 5\$ &     0.137 &   0.112 &    0.147 &       0.012 &   0.001 \\
# \$h = 2, r = 5, l = 3\$ &     0.017 &   0.017 &    0.115 &       0.008 &   0.001 \\
# \$h = 2, r = 5, l = 4\$ &     0.093 &   0.006 &    0.187 &       0.001 &   0.000 \\
# \$h = 2, r = 5, l = 5\$ &     0.009 &   0.029 &    0.206 &       0.014 &   0.000 \\
# \$h = 2, r = 6, l = 3\$ &     0.017 &   0.003 &    0.252 &       0.003 &   0.008 \\
# \$h = 2, r = 6, l = 4\$ &     0.254 &   0.004 &    0.231 &       0.001 &   0.005 \\
# \$h = 2, r = 6, l = 5\$ &     0.054 &   0.091 &    0.034 &       0.016 &   0.001 \\
# \$h = 2, r = 7, l = 3\$ &     0.004 &   0.056 &    0.045 &       0.003 &   0.001 \\
# \$h = 2, r = 7, l = 4\$ &     0.067 &   0.155 &    0.003 &       0.000 &   0.000 \\
# \$h = 2, r = 7, l = 5\$ &     0.054 &   0.576 &    0.012 &       0.004 &   0.000 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil General para 3 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 3, r = 4, l = 3\$ &     0.298 &   0.958 &    0.826 &       0.893 &   0.947 \\
# \$h = 3, r = 4, l = 4\$ &     0.639 &   0.792 &    0.535 &       0.571 &   0.914 \\
# \$h = 3, r = 4, l = 5\$ &     0.884 &   0.780 &    0.305 &       0.175 &   0.440 \\
# \$h = 3, r = 5, l = 3\$ &     0.745 &   0.299 &    0.956 &       0.430 &   0.631 \\
# \$h = 3, r = 5, l = 4\$ &     0.498 &   0.155 &    0.798 &       0.224 &   0.313 \\
# \$h = 3, r = 5, l = 5\$ &     0.902 &   0.655 &    0.586 &       0.476 &   0.497 \\
# \$h = 3, r = 6, l = 3\$ &     0.602 &   0.743 &    0.684 &       0.501 &   0.216 \\
# \$h = 3, r = 6, l = 4\$ &     0.491 &   0.763 &    0.295 &       0.488 &   0.468 \\
# \$h = 3, r = 6, l = 5\$ &     0.924 &   0.975 &    0.090 &       0.947 &   0.525 \\
# \$h = 3, r = 7, l = 3\$ &     0.247 &   0.930 &    0.291 &       0.085 &   0.653 \\
# \$h = 3, r = 7, l = 4\$ &     0.413 &   0.910 &    0.176 &       0.935 &   0.542 \\
# \$h = 3, r = 7, l = 5\$ &     0.379 &   0.917 &    0.393 &       1.000 &   0.812 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil General para 3 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 3, r = 4, l = 3\$ &     0.123 &   0.255 &    0.025 &       0.032 &   0.061 \\
# \$h = 3, r = 4, l = 4\$ &     0.370 &   0.063 &    0.071 &       0.121 &   0.070 \\
# \$h = 3, r = 4, l = 5\$ &     0.804 &   0.101 &    0.241 &       0.026 &   0.026 \\
# \$h = 3, r = 5, l = 3\$ &     0.096 &   0.107 &    0.066 &       0.136 &   0.063 \\
# \$h = 3, r = 5, l = 4\$ &     0.145 &   0.052 &    0.041 &       0.447 &   0.051 \\
# \$h = 3, r = 5, l = 5\$ &     0.268 &   0.077 &    0.148 &       0.146 &   0.020 \\
# \$h = 3, r = 6, l = 3\$ &     0.051 &   0.074 &    0.683 &       0.327 &   0.154 \\
# \$h = 3, r = 6, l = 4\$ &     0.221 &   0.076 &    0.336 &       0.633 &   0.112 \\
# \$h = 3, r = 6, l = 5\$ &     0.562 &   0.251 &    0.585 &       0.217 &   0.016 \\
# \$h = 3, r = 7, l = 3\$ &     0.016 &   0.261 &    0.113 &       0.196 &   0.059 \\
# \$h = 3, r = 7, l = 4\$ &     0.019 &   0.381 &    0.029 &       0.620 &   0.057 \\
# \$h = 3, r = 7, l = 5\$ &     0.434 &   0.691 &    0.047 &       0.315 &   0.031 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil LV para 3 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 3, r = 4, l = 3\$ &     0.587 &   0.021 &    0.454 &       0.781 &   0.706 \\
# \$h = 3, r = 4, l = 4\$ &     0.605 &   0.066 &    0.649 &       0.439 &   0.603 \\
# \$h = 3, r = 4, l = 5\$ &     0.725 &   0.251 &    0.084 &       0.234 &   0.131 \\
# \$h = 3, r = 5, l = 3\$ &     0.843 &   0.003 &    0.520 &       0.842 &   0.678 \\
# \$h = 3, r = 5, l = 4\$ &     0.893 &   0.020 &    0.562 &       0.564 &   0.344 \\
# \$h = 3, r = 5, l = 5\$ &     0.975 &   0.055 &    0.239 &       0.556 &   0.494 \\
# \$h = 3, r = 6, l = 3\$ &     0.992 &   0.016 &    0.136 &       0.423 &   0.995 \\
# \$h = 3, r = 6, l = 4\$ &     0.906 &   0.022 &    0.420 &       0.837 &   0.101 \\
# \$h = 3, r = 6, l = 5\$ &     0.796 &   0.042 &    0.308 &       0.707 &   0.171 \\
# \$h = 3, r = 7, l = 3\$ &     0.895 &   0.007 &    0.233 &       0.865 &   0.986 \\
# \$h = 3, r = 7, l = 4\$ &     0.894 &   0.028 &    0.494 &       0.813 &   0.909 \\
# \$h = 3, r = 7, l = 5\$ &     0.824 &   0.454 &    0.140 &       0.148 &   0.637 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil LV para 3 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 3, r = 4, l = 3\$ &     0.151 &   0.164 &    0.356 &       0.005 &   0.010 \\
# \$h = 3, r = 4, l = 4\$ &     0.124 &   0.051 &    0.131 &       0.001 &   0.008 \\
# \$h = 3, r = 4, l = 5\$ &     0.039 &   0.006 &    0.064 &       0.001 &   0.001 \\
# \$h = 3, r = 5, l = 3\$ &     0.036 &   0.044 &    0.192 &       0.013 &   0.000 \\
# \$h = 3, r = 5, l = 4\$ &     0.058 &   0.005 &    0.150 &       0.005 &   0.006 \\
# \$h = 3, r = 5, l = 5\$ &     0.010 &   0.002 &    0.077 &       0.002 &   0.000 \\
# \$h = 3, r = 6, l = 3\$ &     0.042 &   0.034 &    0.505 &       0.011 &   0.000 \\
# \$h = 3, r = 6, l = 4\$ &     0.031 &   0.010 &    0.089 &       0.029 &   0.018 \\
# \$h = 3, r = 6, l = 5\$ &     0.037 &   0.002 &    0.137 &       0.006 &   0.000 \\
# \$h = 3, r = 7, l = 3\$ &     0.006 &   0.098 &    0.100 &       0.009 &   0.000 \\
# \$h = 3, r = 7, l = 4\$ &     0.010 &   0.096 &    0.003 &       0.028 &   0.016 \\
# \$h = 3, r = 7, l = 5\$ &     0.002 &   0.046 &    0.009 &       0.003 &   0.001 \\
# \bottomrule
# \end{tabular}
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil General para 4 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 4, r = 4, l = 3\$ &     0.270 &   0.640 &    0.895 &       0.330 &   0.283 \\
# \$h = 4, r = 4, l = 4\$ &     0.226 &   0.409 &    0.569 &       0.568 &   0.385 \\
# \$h = 4, r = 4, l = 5\$ &     0.050 &   0.407 &    0.597 &       0.755 &   0.423 \\
# \$h = 4, r = 5, l = 3\$ &     0.419 &   0.334 &    0.764 &       0.052 &   0.318 \\
# \$h = 4, r = 5, l = 4\$ &     0.556 &   0.059 &    0.292 &       0.527 &   0.373 \\
# \$h = 4, r = 5, l = 5\$ &     0.507 &   0.873 &    0.121 &       0.364 &   0.279 \\
# \$h = 4, r = 6, l = 3\$ &     0.348 &   0.347 &    0.037 &       0.085 &   0.494 \\
# \$h = 4, r = 6, l = 4\$ &     0.255 &   0.577 &    0.191 &       0.211 &   0.723 \\
# \$h = 4, r = 6, l = 5\$ &     0.227 &   0.327 &    0.104 &       0.495 &   0.215 \\
# \$h = 4, r = 7, l = 3\$ &     0.186 &   0.757 &    0.015 &       0.462 &   0.222 \\
# \$h = 4, r = 7, l = 4\$ &     0.115 &   0.772 &    0.098 &       0.144 &   0.567 \\
# \$h = 4, r = 7, l = 5\$ &     0.043 &   0.803 &    0.459 &       0.474 &   0.466 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil General para 4 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 4, r = 4, l = 3\$ &     0.933 &   0.017 &    0.781 &       0.526 &   0.439 \\
# \$h = 4, r = 4, l = 4\$ &     0.897 &   0.574 &    0.302 &       0.964 &   0.612 \\
# \$h = 4, r = 4, l = 5\$ &     0.204 &   0.405 &    0.117 &       0.698 &   0.635 \\
# \$h = 4, r = 5, l = 3\$ &     0.593 &   0.018 &    0.811 &       0.421 &   0.323 \\
# \$h = 4, r = 5, l = 4\$ &     0.808 &   0.472 &    0.211 &       0.717 &   0.801 \\
# \$h = 4, r = 5, l = 5\$ &     0.511 &   0.395 &    0.506 &       0.876 &   0.741 \\
# \$h = 4, r = 6, l = 3\$ &     0.760 &   0.100 &    0.443 &       0.854 &   0.040 \\
# \$h = 4, r = 6, l = 4\$ &     0.574 &   0.351 &    0.171 &       0.864 &   0.139 \\
# \$h = 4, r = 6, l = 5\$ &     0.247 &   0.176 &    0.350 &       0.751 &   0.460 \\
# \$h = 4, r = 7, l = 3\$ &     0.441 &   0.571 &    0.318 &       0.753 &   0.132 \\
# \$h = 4, r = 7, l = 4\$ &     0.814 &   0.822 &    0.447 &       0.356 &   0.551 \\
# \$h = 4, r = 7, l = 5\$ &     0.405 &   0.257 &    0.498 &       0.820 &   0.846 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil LV para 4 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 4, r = 4, l = 3\$ &     0.378 &   0.102 &    0.167 &       0.832 &   0.820 \\
# \$h = 4, r = 4, l = 4\$ &     0.198 &   0.068 &    0.188 &       0.222 &   0.671 \\
# \$h = 4, r = 4, l = 5\$ &     0.420 &   0.061 &    0.202 &       0.149 &   0.122 \\
# \$h = 4, r = 5, l = 3\$ &     0.308 &   0.269 &    0.180 &       0.385 &   0.205 \\
# \$h = 4, r = 5, l = 4\$ &     0.348 &   0.011 &    0.513 &       0.206 &   0.232 \\
# \$h = 4, r = 5, l = 5\$ &     0.963 &   0.006 &    0.597 &       0.229 &   0.252 \\
# \$h = 4, r = 6, l = 3\$ &     0.624 &   0.347 &    0.011 &       0.316 &   0.652 \\
# \$h = 4, r = 6, l = 4\$ &     0.882 &   0.002 &    0.089 &       0.134 &   0.561 \\
# \$h = 4, r = 6, l = 5\$ &     0.831 &   0.007 &    0.193 &       0.286 &   0.259 \\
# \$h = 4, r = 7, l = 3\$ &     0.177 &   0.769 &    0.010 &       0.219 &   0.345 \\
# \$h = 4, r = 7, l = 4\$ &     0.368 &   0.014 &    0.194 &       0.419 &   0.773 \\
# \$h = 4, r = 7, l = 5\$ &     0.777 &   0.025 &    0.379 &       0.546 &   0.320 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil LV para 4 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 4, r = 4, l = 3\$ &     0.092 &   0.063 &    0.606 &       0.002 &   0.003 \\
# \$h = 4, r = 4, l = 4\$ &     0.199 &   0.014 &    0.257 &       0.005 &   0.015 \\
# \$h = 4, r = 4, l = 5\$ &     0.017 &   0.036 &    0.352 &       0.016 &   0.005 \\
# \$h = 4, r = 5, l = 3\$ &     0.074 &   0.034 &    0.356 &       0.007 &   0.001 \\
# \$h = 4, r = 5, l = 4\$ &     0.023 &   0.005 &    0.192 &       0.043 &   0.011 \\
# \$h = 4, r = 5, l = 5\$ &     0.001 &   0.005 &    0.105 &       0.069 &   0.000 \\
# \$h = 4, r = 6, l = 3\$ &     0.063 &   0.009 &    0.255 &       0.005 &   0.001 \\
# \$h = 4, r = 6, l = 4\$ &     0.089 &   0.006 &    0.210 &       0.064 &   0.041 \\
# \$h = 4, r = 6, l = 5\$ &     0.011 &   0.002 &    0.346 &       0.120 &   0.001 \\
# \$h = 4, r = 7, l = 3\$ &     0.039 &   0.052 &    0.024 &       0.008 &   0.000 \\
# \$h = 4, r = 7, l = 4\$ &     0.008 &   0.098 &    0.013 &       0.070 &   0.069 \\
# \$h = 4, r = 7, l = 5\$ &     0.001 &   0.103 &    0.048 &       0.148 &   0.002 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil General para 5 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 5, r = 4, l = 3\$ &     0.841 &   0.261 &    0.797 &       0.295 &   0.662 \\
# \$h = 5, r = 4, l = 4\$ &     0.511 &   0.105 &    0.389 &       0.055 &   0.842 \\
# \$h = 5, r = 4, l = 5\$ &     0.999 &   0.230 &    0.236 &       0.226 &   0.815 \\
# \$h = 5, r = 5, l = 3\$ &     0.267 &   0.286 &    0.894 &       0.365 &   0.924 \\
# \$h = 5, r = 5, l = 4\$ &     0.365 &   0.399 &    0.913 &       0.297 &   0.993 \\
# \$h = 5, r = 5, l = 5\$ &     0.676 &   0.283 &    0.913 &       0.119 &   0.544 \\
# \$h = 5, r = 6, l = 3\$ &     0.204 &   0.237 &    0.355 &       0.583 &   0.775 \\
# \$h = 5, r = 6, l = 4\$ &     0.303 &   0.169 &    0.611 &       0.080 &   0.728 \\
# \$h = 5, r = 6, l = 5\$ &     0.459 &   0.638 &    0.866 &       0.373 &   0.620 \\
# \$h = 5, r = 7, l = 3\$ &     0.532 &   0.492 &    0.501 &       0.791 &   0.846 \\
# \$h = 5, r = 7, l = 4\$ &     0.490 &   0.517 &    0.438 &       0.472 &   0.871 \\
# \$h = 5, r = 7, l = 5\$ &     0.423 &   0.836 &    0.704 &       0.565 &   0.818 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil General para 5 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 5, r = 4, l = 3\$ &     0.438 &   0.554 &    0.272 &       0.704 &   0.144 \\
# \$h = 5, r = 4, l = 4\$ &     0.750 &   0.874 &    0.299 &       0.710 &   0.116 \\
# \$h = 5, r = 4, l = 5\$ &     0.492 &   0.789 &    0.259 &       0.772 &   0.294 \\
# \$h = 5, r = 5, l = 3\$ &     0.513 &   0.083 &    0.186 &       0.591 &   0.222 \\
# \$h = 5, r = 5, l = 4\$ &     0.465 &   0.740 &    0.318 &       0.730 &   0.065 \\
# \$h = 5, r = 5, l = 5\$ &     0.398 &   0.358 &    0.229 &       0.678 &   0.439 \\
# \$h = 5, r = 6, l = 3\$ &     0.557 &   0.030 &    0.614 &       0.267 &   0.298 \\
# \$h = 5, r = 6, l = 4\$ &     0.312 &   0.608 &    0.591 &       0.225 &   0.085 \\
# \$h = 5, r = 6, l = 5\$ &     0.503 &   0.164 &    0.199 &       0.288 &   0.304 \\
# \$h = 5, r = 7, l = 3\$ &     0.331 &   0.127 &    0.570 &       0.235 &   0.032 \\
# \$h = 5, r = 7, l = 4\$ &     0.267 &   0.059 &    0.223 &       0.391 &   0.128 \\
# \$h = 5, r = 7, l = 5\$ &     0.056 &   0.118 &    0.001 &       0.617 &   0.422 \\
# \bottomrule
# \end{tabular}
#
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Fácil LV para 5 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 5, r = 4, l = 3\$ &     0.467 &   0.436 &    0.010 &       0.492 &   0.966 \\
# \$h = 5, r = 4, l = 4\$ &     0.700 &   0.053 &    0.427 &       0.267 &   0.685 \\
# \$h = 5, r = 4, l = 5\$ &     0.454 &   0.006 &    0.517 &       0.185 &   0.397 \\
# \$h = 5, r = 5, l = 3\$ &     0.275 &   0.366 &    0.061 &       0.538 &   0.586 \\
# \$h = 5, r = 5, l = 4\$ &     0.580 &   0.121 &    0.756 &       0.239 &   0.392 \\
# \$h = 5, r = 5, l = 5\$ &     0.984 &   0.226 &    0.751 &       0.291 &   0.325 \\
# \$h = 5, r = 6, l = 3\$ &     0.178 &   0.294 &    0.017 &       0.045 &   0.574 \\
# \$h = 5, r = 6, l = 4\$ &     0.813 &   0.065 &    0.482 &       0.251 &   0.875 \\
# \$h = 5, r = 6, l = 5\$ &     0.198 &   0.214 &    0.486 &       0.741 &   0.538 \\
# \$h = 5, r = 7, l = 3\$ &     0.151 &   0.388 &    0.044 &       0.072 &   0.742 \\
# \$h = 5, r = 7, l = 4\$ &     0.825 &   0.171 &    0.092 &       0.518 &   0.765 \\
# \$h = 5, r = 7, l = 5\$ &     0.752 &   0.165 &    0.630 &       0.707 &   0.920 \\
# \bottomrule
# \end{tabular}
# ----------------------------------------------------------------------------------------
# Análisis y = Puntos anterior, x = Frac. Difícil LV para 5 torneos anteriores
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Alemania &  Espana &  Francia &  Inglaterra &  Italia \\
# \midrule
# \$h = 5, r = 4, l = 3\$ &     0.087 &   0.069 &    0.604 &       0.004 &   0.009 \\
# \$h = 5, r = 4, l = 4\$ &     0.310 &   0.031 &    0.690 &       0.024 &   0.004 \\
# \$h = 5, r = 4, l = 5\$ &     0.063 &   0.047 &    0.284 &       0.012 &   0.000 \\
# \$h = 5, r = 5, l = 3\$ &     0.056 &   0.032 &    0.567 &       0.004 &   0.001 \\
# \$h = 5, r = 5, l = 4\$ &     0.069 &   0.009 &    0.490 &       0.143 &   0.003 \\
# \$h = 5, r = 5, l = 5\$ &     0.010 &   0.004 &    0.197 &       0.047 &   0.000 \\
# \$h = 5, r = 6, l = 3\$ &     0.048 &   0.028 &    0.360 &       0.034 &   0.005 \\
# \$h = 5, r = 6, l = 4\$ &     0.037 &   0.004 &    0.638 &       0.129 &   0.020 \\
# \$h = 5, r = 6, l = 5\$ &     0.124 &   0.000 &    0.488 &       0.022 &   0.000 \\
# \$h = 5, r = 7, l = 3\$ &     0.017 &   0.083 &    0.082 &       0.144 &   0.003 \\
# \$h = 5, r = 7, l = 4\$ &     0.008 &   0.047 &    0.115 &       0.131 &   0.039 \\
# \$h = 5, r = 7, l = 5\$ &     0.024 &   0.215 &    0.037 &       0.047 &   0.001 \\
# \bottomrule
# \end{tabular}

# %%
len(dfs_res)

# %%
tablas_text = """
"""

Y = ['position_ant', 'points_ant', 'promoccup_ant']
Y_print = ['Posición anterior', 'Puntos anterior', 'Prom. ocupación anterior']
X = ['perc_facil_elo_p%s_c%s',
     'perc_dificil_elo_p%s_c%s']
X_print = ['Frac. Fácil ELO',
           'Frac. Difícil ELO']
ligas = ['Alemania','Espana','Francia','Inglaterra','Italia']


for k in range(len(Y)):
    y = Y[k]
    means = []
    for j in range(len(X)):
        x = X[j]
        print('----------------------------------------------------------------------------------------')
        print('Análisis y = %s, x = %s para %s' % (Y_print[k], X_print[j]))
        for i in range(len(ligas)):
            resultados = []
            liga = ligas[i]
            df = dfs_pretrat[i]
            rl = []
            for r in [4,5,6,7]:
                for l in [3,4,5]:
                    x_ = x % (r,l)
                    rl.append("$r = %s, l = %s$" % (r,l))
                    formula = '%s ~ C(%s)' % (y,x_)
                    model = ols(formula, data = df).fit()
                    aov_table = sm.stats.anova_lm(model, typ=2)
                    resultados.append(np.round(aov_table['PR(>F)'][0], decimals = 3))
            if i < 1:
                df_res = pd.DataFrame({liga : resultados}, index = rl)
            else:
                df_res[liga] = resultados
        tablas_text = tablas_text + df_res.to_latex()
        print(df_res.to_latex())
        means.append(df_res.mean().tolist())
    df_means = pd.DataFrame(data = means, columns = ligas, index = X_print)
    print('---------------------------------PROMEDIOS------------------------------------------')
    print(df_means.to_latex())

# %%
df_res.mean()

# %%
regdir = os.path.join(os.path.pardir,
                      'Datos',
                      'Bases construidas',
                      'Bases main',
                      'Bases efecto')

# %%
df_reg = pd.read_excel(os.path.join(regdir, 'Inglaterra.xlsx'))

# %%
variables =  + ['perc_dificil_general_p%s_c%s' % (r,l) for r in range(4,8) for l in range(3,6)]

# %%
indices = ["$r = %s, l = %s$" % (r,l) for r in range(4,8) for l in range(3,6)]

# %%
df_facil = df_reg[['perc_dificil_general_p%s_c%s' % (r,l) for r in range(4,8) for l in range(3,6)]].describe().round(decimals = 3).T

# %%
df_facil.index = indices

# %%
print(df_facil.drop(['count'], axis = 1).to_latex())
